# %%
import sys
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import urllib
from threading import Thread
from queue import Queue
import math
import requests
import time 
from datetime import timedelta
import pickle
from datetime import datetime

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
df = pd.DataFrame(columns=['author','date','activity', 'text', 'files'])
filne = "log_bootstrap.txt"
##with urllib2.urlopen("https://file.io/rSWakX") as f:
with open(filne, 'r+', encoding="utf-8") as f:
    lines = f.readlines()
    ##for i in range(0, 100):
  
    for i in range(0, len(lines)):
        line = lines[i]
        if line[:6] == "commit":
            sha = line[8:].strip()
            ##Author
            line = lines[i+1]
            if line[:6] == "Merge:":
                i = i + 1
                line = lines[i+1]
            divided = line.split("<")
            divided[1][:-2]          
            author = divided[1][:-2]
            ##Author
            line = lines[i+2]
            divided = line.split(":   ")
            date = divided[1].strip()
            line = lines[i+3]  
            text = ""
            if line in ['\n', '\r\n']:
                line = lines[i + 4]
                divided = line.split(":")
                activity = divided[0].strip()
            j = 5
            text += line
            while 1:
                line = lines[i+j]            
                if line in ['\n', '\r\n']:
                    break
                text += line    
                j = j + 1
            j = j + 1
            files = []
            while 1:
                line = lines[i+j]            
                if line in ['\n', '\r\n']:
                    break
                files.append(line)   
                j = j + 1
            print("...........")
            ##print sha
            ##print author
            ##print date
            ##print activity
            ##print files
            print(text)
            df.loc[sha] = pd.Series({'author': author, 'date': date, 'activity': activity, 'text': text, 'files': files})
# Out:
# ...........
#     Move htmllint to npm script.
#
# ...........
#     Change to markdown (#21815)
#
# ...........
#     Change header to use markdown (#21809)
#
#     Header will now display in the Contents section.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-ee993c202427> in <module>()
#      13             line = lines[i+1]
#      14             divided = line.split("<")
# ---> 15             divided[1][:-2]
#      16             author = divided[1][:-2]
#      17             ##Author
#
# IndexError: list index out of range

# %%
df.head()
# Out:
#                                                            author  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716            agl@google.com
# b6123cfbe90141464bb86400a5f26c835c50f37          rtrott@gmail.com
# 0c72c6d55452ffd0e7719b869bc54c3861595ab          rtrott@gmail.com
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250            gib@uk.ibm.com
# cab88d529da07a73174ffb5e93cd3652a4fe0dd  birunthan@mohanathas.com
#
#                                                              date activity  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716  Tue Jan 17 21:04:40 2017   crypto
# b6123cfbe90141464bb86400a5f26c835c50f37  Fri Jan 20 02:18:13 2017      url
# 0c72c6d55452ffd0e7719b869bc54c3861595ab  Thu Jan 19 20:19:07 2017     test
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250  Tue Jan 17 11:30:43 2017     test
# cab88d529da07a73174ffb5e93cd3652a4fe0dd  Thu Jan 19 07:38:50 2017      url
#
#                                                                                       text  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716      crypto: freelist_max_len is gone in OpenSS...
# b6123cfbe90141464bb86400a5f26c835c50f37      url: refactor lib/internal/url.js\n    \n ...
# 0c72c6d55452ffd0e7719b869bc54c3861595ab      test: fix flaky test-regress-GH-897\n    \...
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250      test: don't connect to :: (use localhost i...
# cab88d529da07a73174ffb5e93cd3652a4fe0dd      url: add return value to ToUnicode/ToAscii...
#
#                                                                                      files
# 57e2f2138c37e636e1f7684ab07cb36eea79716  [ lib/_tls_common.js | 4 +++-\n,  src/node_cry...
# b6123cfbe90141464bb86400a5f26c835c50f37  [ lib/internal/url.js | 10 ++++++----\n,  1 fi...
# 0c72c6d55452ffd0e7719b869bc54c3861595ab  [ test/parallel/test-regress-GH-897.js   | 20 ...
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250  [ test/gc/test-net-timeout.js                 ...
# cab88d529da07a73174ffb5e93cd3652a4fe0dd  [ src/node_url.cc | 58 +++++++++++++++++++++++...

# %%
len(df)
# Out:
# 4716

# %%
df['changes'] = pd.Series(df['files'].str[-1], index=df.index)

# %%
df['n_files'] = pd.Series(df['changes'].str.split().str[0] , index=df.index)
df['insertions'] = pd.Series(df['changes'].str.split(",").str[1].str.split().str[0] , index=df.index)
df['deletions'] = pd.Series(df['changes'].str.split(",").str[2].str.split().str[0] , index=df.index)

# %%
del df['changes']
df.head()
# Out:
#                                                            author  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716            agl@google.com
# b6123cfbe90141464bb86400a5f26c835c50f37          rtrott@gmail.com
# 0c72c6d55452ffd0e7719b869bc54c3861595ab          rtrott@gmail.com
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250            gib@uk.ibm.com
# cab88d529da07a73174ffb5e93cd3652a4fe0dd  birunthan@mohanathas.com
#
#                                                              date activity  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716  Tue Jan 17 21:04:40 2017   crypto
# b6123cfbe90141464bb86400a5f26c835c50f37  Fri Jan 20 02:18:13 2017      url
# 0c72c6d55452ffd0e7719b869bc54c3861595ab  Thu Jan 19 20:19:07 2017     test
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250  Tue Jan 17 11:30:43 2017     test
# cab88d529da07a73174ffb5e93cd3652a4fe0dd  Thu Jan 19 07:38:50 2017      url
#
#                                                                                       text  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716      crypto: freelist_max_len is gone in OpenSS...
# b6123cfbe90141464bb86400a5f26c835c50f37      url: refactor lib/internal/url.js\n    \n ...
# 0c72c6d55452ffd0e7719b869bc54c3861595ab      test: fix flaky test-regress-GH-897\n    \...
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250      test: don't connect to :: (use localhost i...
# cab88d529da07a73174ffb5e93cd3652a4fe0dd      url: add return value to ToUnicode/ToAscii...
#
#                                                                                      files  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716  [ lib/_tls_common.js | 4 +++-\n,  src/node_cry...
# b6123cfbe90141464bb86400a5f26c835c50f37  [ lib/internal/url.js | 10 ++++++----\n,  1 fi...
# 0c72c6d55452ffd0e7719b869bc54c3861595ab  [ test/parallel/test-regress-GH-897.js   | 20 ...
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250  [ test/gc/test-net-timeout.js                 ...
# cab88d529da07a73174ffb5e93cd3652a4fe0dd  [ src/node_url.cc | 58 +++++++++++++++++++++++...
#
#                                         n_files insertions deletions
# 57e2f2138c37e636e1f7684ab07cb36eea79716       2          7         1
# b6123cfbe90141464bb86400a5f26c835c50f37       1          6         4
# 0c72c6d55452ffd0e7719b869bc54c3861595ab       2         20        17
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250       2          2         4
# cab88d529da07a73174ffb5e93cd3652a4fe0dd       1         29        29

# %%
df['n_files'] = df.n_files.apply(pd.to_numeric, args=('coerce',))
df['insertions'] = df.insertions.apply(pd.to_numeric, args=('coerce',))
df['deletions'] = df.deletions.apply(pd.to_numeric, args=('coerce',))

# %%
df.head()
# Out:
#                                                            author  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716            agl@google.com
# b6123cfbe90141464bb86400a5f26c835c50f37          rtrott@gmail.com
# 0c72c6d55452ffd0e7719b869bc54c3861595ab          rtrott@gmail.com
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250            gib@uk.ibm.com
# cab88d529da07a73174ffb5e93cd3652a4fe0dd  birunthan@mohanathas.com
#
#                                                              date activity  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716  Tue Jan 17 21:04:40 2017   crypto
# b6123cfbe90141464bb86400a5f26c835c50f37  Fri Jan 20 02:18:13 2017      url
# 0c72c6d55452ffd0e7719b869bc54c3861595ab  Thu Jan 19 20:19:07 2017     test
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250  Tue Jan 17 11:30:43 2017     test
# cab88d529da07a73174ffb5e93cd3652a4fe0dd  Thu Jan 19 07:38:50 2017      url
#
#                                                                                       text  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716      crypto: freelist_max_len is gone in OpenSS...
# b6123cfbe90141464bb86400a5f26c835c50f37      url: refactor lib/internal/url.js\n    \n ...
# 0c72c6d55452ffd0e7719b869bc54c3861595ab      test: fix flaky test-regress-GH-897\n    \...
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250      test: don't connect to :: (use localhost i...
# cab88d529da07a73174ffb5e93cd3652a4fe0dd      url: add return value to ToUnicode/ToAscii...
#
#                                                                                      files  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716  [ lib/_tls_common.js | 4 +++-\n,  src/node_cry...
# b6123cfbe90141464bb86400a5f26c835c50f37  [ lib/internal/url.js | 10 ++++++----\n,  1 fi...
# 0c72c6d55452ffd0e7719b869bc54c3861595ab  [ test/parallel/test-regress-GH-897.js   | 20 ...
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250  [ test/gc/test-net-timeout.js                 ...
# cab88d529da07a73174ffb5e93cd3652a4fe0dd  [ src/node_url.cc | 58 +++++++++++++++++++++++...
#
#                                          n_files  insertions  deletions
# 57e2f2138c37e636e1f7684ab07cb36eea79716        2           7        1.0
# b6123cfbe90141464bb86400a5f26c835c50f37        1           6        4.0
# 0c72c6d55452ffd0e7719b869bc54c3861595ab        2          20       17.0
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250        2           2        4.0
# cab88d529da07a73174ffb5e93cd3652a4fe0dd        1          29       29.
df.head()
# Out:
#                                                            author  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716            agl@google.com
# b6123cfbe90141464bb86400a5f26c835c50f37          rtrott@gmail.com
# 0c72c6d55452ffd0e7719b869bc54c3861595ab          rtrott@gmail.com
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250            gib@uk.ibm.com
# cab88d529da07a73174ffb5e93cd3652a4fe0dd  birunthan@mohanathas.com
#
#                                                              date activity  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716  Tue Jan 17 21:04:40 2017   crypto
# b6123cfbe90141464bb86400a5f26c835c50f37  Fri Jan 20 02:18:13 2017      url
# 0c72c6d55452ffd0e7719b869bc54c3861595ab  Thu Jan 19 20:19:07 2017     test
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250  Tue Jan 17 11:30:43 2017     test
# cab88d529da07a73174ffb5e93cd3652a4fe0dd  Thu Jan 19 07:38:50 2017      url
#
#                                                                                       text  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716      crypto: freelist_max_len is gone in OpenSS...
# b6123cfbe90141464bb86400a5f26c835c50f37      url: refactor lib/internal/url.js\n    \n ...
# 0c72c6d55452ffd0e7719b869bc54c3861595ab      test: fix flaky test-regress-GH-897\n    \...
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250      test: don't connect to :: (use localhost i...
# cab88d529da07a73174ffb5e93cd3652a4fe0dd      url: add return value to ToUnicode/ToAscii...
#
#                                                                                      files  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716  [ lib/_tls_common.js | 4 +++-\n,  src/node_cry...
# b6123cfbe90141464bb86400a5f26c835c50f37  [ lib/internal/url.js | 10 ++++++----\n,  1 fi...
# 0c72c6d55452ffd0e7719b869bc54c3861595ab  [ test/parallel/test-regress-GH-897.js   | 20 ...
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250  [ test/gc/test-net-timeout.js                 ...
# cab88d529da07a73174ffb5e93cd3652a4fe0dd  [ src/node_url.cc | 58 +++++++++++++++++++++++...
#
#                                          n_files  insertions  deletions  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716        2           7        1.0
# b6123cfbe90141464bb86400a5f26c835c50f37        1           6        4.0
# 0c72c6d55452ffd0e7719b869bc54c3861595ab        2          20       17.0
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250        2           2        4.0
# cab88d529da07a73174ffb5e93cd3652a4fe0dd        1          29       29.0
#
#                                          pat_code  pat_doc  pat_test  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716         0        0         0
# b6123cfbe90141464bb86400a5f26c835c50f37         0        0         0
# 0c72c6d55452ffd0e7719b869bc54c3861595ab         0        0         0
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250         0        0         0
# cab88d529da07a73174ffb5e93cd3652a4fe0dd         0        0         0
#
#                                          pat_build
# 57e2f2138c37e636e1f7684ab07cb36eea79716          0
# b6123cfbe90141464bb86400a5f26c835c50f37          0
# 0c72c6d55452ffd0e7719b869bc54c3861595ab          0
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250          0
# cab88d529da07a73174ffb5e93cd3652a4fe0dd          0

# %%
import re
for index, row in df.iterrows():
    code = 0
    doc = 0
    test = 0
    build = 0
    for j in range(0, len(row['files'])):
        match_code = re.match(pattern_code, row['files'][j], flags=0)
        if match_code:
            code += 1
        match_doc = re.match(pattern_doc, row['files'][j], flags=0)
        if match_doc:
            doc += 1
        match_test = re.match(pattern_test, row['files'][j], flags=0)
        if match_test:
            test += 1
        match_build = re.match(pattern_build, row['files'][j], flags=0)
        if match_build:
            build += 1
    
    df.set_value(index, 'pat_code', code) 
    df.set_value(index, 'pat_doc', doc) 
    df.set_value(index, 'pat_test', test) 
    df.set_value(index, 'pat_build', build) 
df.head()
# Out:
#                                                            author  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716            agl@google.com
# b6123cfbe90141464bb86400a5f26c835c50f37          rtrott@gmail.com
# 0c72c6d55452ffd0e7719b869bc54c3861595ab          rtrott@gmail.com
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250            gib@uk.ibm.com
# cab88d529da07a73174ffb5e93cd3652a4fe0dd  birunthan@mohanathas.com
#
#                                                              date activity  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716  Tue Jan 17 21:04:40 2017   crypto
# b6123cfbe90141464bb86400a5f26c835c50f37  Fri Jan 20 02:18:13 2017      url
# 0c72c6d55452ffd0e7719b869bc54c3861595ab  Thu Jan 19 20:19:07 2017     test
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250  Tue Jan 17 11:30:43 2017     test
# cab88d529da07a73174ffb5e93cd3652a4fe0dd  Thu Jan 19 07:38:50 2017      url
#
#                                                                                       text  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716      crypto: freelist_max_len is gone in OpenSS...
# b6123cfbe90141464bb86400a5f26c835c50f37      url: refactor lib/internal/url.js\n    \n ...
# 0c72c6d55452ffd0e7719b869bc54c3861595ab      test: fix flaky test-regress-GH-897\n    \...
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250      test: don't connect to :: (use localhost i...
# cab88d529da07a73174ffb5e93cd3652a4fe0dd      url: add return value to ToUnicode/ToAscii...
#
#                                                                                      files  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716  [ lib/_tls_common.js | 4 +++-\n,  src/node_cry...
# b6123cfbe90141464bb86400a5f26c835c50f37  [ lib/internal/url.js | 10 ++++++----\n,  1 fi...
# 0c72c6d55452ffd0e7719b869bc54c3861595ab  [ test/parallel/test-regress-GH-897.js   | 20 ...
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250  [ test/gc/test-net-timeout.js                 ...
# cab88d529da07a73174ffb5e93cd3652a4fe0dd  [ src/node_url.cc | 58 +++++++++++++++++++++++...
#
#                                          n_files  insertions  deletions  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716        2           7        1.0
# b6123cfbe90141464bb86400a5f26c835c50f37        1           6        4.0
# 0c72c6d55452ffd0e7719b869bc54c3861595ab        2          20       17.0
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250        2           2        4.0
# cab88d529da07a73174ffb5e93cd3652a4fe0dd        1          29       29.0
#
#                                          pat_code  pat_doc  pat_test  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716         2        3         0
# b6123cfbe90141464bb86400a5f26c835c50f37         1        2         0
# 0c72c6d55452ffd0e7719b869bc54c3861595ab         2        3         2
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250         2        3         2
# cab88d529da07a73174ffb5e93cd3652a4fe0dd         1        2         0
#
#                                          pat_build
# 57e2f2138c37e636e1f7684ab07cb36eea79716          3
# b6123cfbe90141464bb86400a5f26c835c50f37          2
# 0c72c6d55452ffd0e7719b869bc54c3861595ab          3
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250          3
# cab88d529da07a73174ffb5e93cd3652a4fe0dd          2

# %%
df.insertions.describe()
# Out:
# count      4716.000000
# mean        732.071459
# std       10566.586003
# min           0.000000
# 25%           3.000000
# 50%          11.000000
# 75%          39.000000
# max      475138.000000
# Name: insertions, dtype: float64

# %%
comment_code = "(?:^|\W)cod(?:$|)"
comment_doc = "(?:^|\W)doc(?:$|)"
comment_test = "(?:^|\W)test(?:$|)"
comment_build = "(?:^|\W)build(?:$|)"

# %%
df['text_code'] = 0
df['text_doc'] = 0
df['text_test'] = 0
df['text_build'] = 0

# %%
match_code = re.findall(comment_code, df['text'][1], re.IGNORECASE)
match_doc = re.findall(comment_doc, df['text'][1], re.IGNORECASE)
match_test = re.findall(comment_test, df['text'][1], re.IGNORECASE)
match_build = re.findall(comment_build, df['text'][1], re.IGNORECASE)

# %%
for index, row in df.iterrows():   
    match_code = re.findall(comment_code, row['text'], re.IGNORECASE)
    match_doc = re.findall(comment_doc, row['text'], re.IGNORECASE)
    match_test = re.findall(comment_test, row['text'], re.IGNORECASE)
    match_build = re.findall(comment_build, row['text'], re.IGNORECASE)

    df.set_value(index, 'text_code', len(match_code)) 
    df.set_value(index, 'text_doc', len(match_doc)) 
    df.set_value(index, 'text_test', len(match_test))
    df.set_value(index, 'text_build', len(match_build)) 
df.head()
# Out:
#                                                            author  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716            agl@google.com
# b6123cfbe90141464bb86400a5f26c835c50f37          rtrott@gmail.com
# 0c72c6d55452ffd0e7719b869bc54c3861595ab          rtrott@gmail.com
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250            gib@uk.ibm.com
# cab88d529da07a73174ffb5e93cd3652a4fe0dd  birunthan@mohanathas.com
#
#                                                              date activity  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716  Tue Jan 17 21:04:40 2017   crypto
# b6123cfbe90141464bb86400a5f26c835c50f37  Fri Jan 20 02:18:13 2017      url
# 0c72c6d55452ffd0e7719b869bc54c3861595ab  Thu Jan 19 20:19:07 2017     test
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250  Tue Jan 17 11:30:43 2017     test
# cab88d529da07a73174ffb5e93cd3652a4fe0dd  Thu Jan 19 07:38:50 2017      url
#
#                                                                                       text  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716      crypto: freelist_max_len is gone in OpenSS...
# b6123cfbe90141464bb86400a5f26c835c50f37      url: refactor lib/internal/url.js\n    \n ...
# 0c72c6d55452ffd0e7719b869bc54c3861595ab      test: fix flaky test-regress-GH-897\n    \...
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250      test: don't connect to :: (use localhost i...
# cab88d529da07a73174ffb5e93cd3652a4fe0dd      url: add return value to ToUnicode/ToAscii...
#
#                                                                                      files  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716  [ lib/_tls_common.js | 4 +++-\n,  src/node_cry...
# b6123cfbe90141464bb86400a5f26c835c50f37  [ lib/internal/url.js | 10 ++++++----\n,  1 fi...
# 0c72c6d55452ffd0e7719b869bc54c3861595ab  [ test/parallel/test-regress-GH-897.js   | 20 ...
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250  [ test/gc/test-net-timeout.js                 ...
# cab88d529da07a73174ffb5e93cd3652a4fe0dd  [ src/node_url.cc | 58 +++++++++++++++++++++++...
#
#                                          n_files  insertions  deletions  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716        2           7        1.0
# b6123cfbe90141464bb86400a5f26c835c50f37        1           6        4.0
# 0c72c6d55452ffd0e7719b869bc54c3861595ab        2          20       17.0
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250        2           2        4.0
# cab88d529da07a73174ffb5e93cd3652a4fe0dd        1          29       29.0
#
#                                          pat_code  pat_doc  pat_test  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716         2        3         0
# b6123cfbe90141464bb86400a5f26c835c50f37         1        2         0
# 0c72c6d55452ffd0e7719b869bc54c3861595ab         2        3         2
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250         2        3         2
# cab88d529da07a73174ffb5e93cd3652a4fe0dd         1        2         0
#
#                                          pat_build  text_code  text_doc  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716          3          0         0
# b6123cfbe90141464bb86400a5f26c835c50f37          2          0         0
# 0c72c6d55452ffd0e7719b869bc54c3861595ab          3          0         0
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250          3          0         0
# cab88d529da07a73174ffb5e93cd3652a4fe0dd          2          0         0
#
#                                          text_test  text_build
# 57e2f2138c37e636e1f7684ab07cb36eea79716          0           1
# b6123cfbe90141464bb86400a5f26c835c50f37          0           0
# 0c72c6d55452ffd0e7719b869bc54c3861595ab         10           0
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250          2           0
# cab88d529da07a73174ffb5e93cd3652a4fe0dd          0           0

# %%
from textblob import TextBlob

# %%
df['subjectivity'] = 0
df['polarity'] = 0

# %%
for index, row in df.iterrows(): 
    textblob = TextBlob(row['text'])
    df.set_value(index, 'polarity', textblob.sentiment.polarity) 
    df.set_value(index, 'subjectivity', textblob.sentiment.subjectivity) 
df.head()
# Out:
#                                                            author  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716            agl@google.com
# b6123cfbe90141464bb86400a5f26c835c50f37          rtrott@gmail.com
# 0c72c6d55452ffd0e7719b869bc54c3861595ab          rtrott@gmail.com
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250            gib@uk.ibm.com
# cab88d529da07a73174ffb5e93cd3652a4fe0dd  birunthan@mohanathas.com
#
#                                                              date activity  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716  Tue Jan 17 21:04:40 2017   crypto
# b6123cfbe90141464bb86400a5f26c835c50f37  Fri Jan 20 02:18:13 2017      url
# 0c72c6d55452ffd0e7719b869bc54c3861595ab  Thu Jan 19 20:19:07 2017     test
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250  Tue Jan 17 11:30:43 2017     test
# cab88d529da07a73174ffb5e93cd3652a4fe0dd  Thu Jan 19 07:38:50 2017      url
#
#                                                                                       text  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716      crypto: freelist_max_len is gone in OpenSS...
# b6123cfbe90141464bb86400a5f26c835c50f37      url: refactor lib/internal/url.js\n    \n ...
# 0c72c6d55452ffd0e7719b869bc54c3861595ab      test: fix flaky test-regress-GH-897\n    \...
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250      test: don't connect to :: (use localhost i...
# cab88d529da07a73174ffb5e93cd3652a4fe0dd      url: add return value to ToUnicode/ToAscii...
#
#                                                                                      files  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716  [ lib/_tls_common.js | 4 +++-\n,  src/node_cry...
# b6123cfbe90141464bb86400a5f26c835c50f37  [ lib/internal/url.js | 10 ++++++----\n,  1 fi...
# 0c72c6d55452ffd0e7719b869bc54c3861595ab  [ test/parallel/test-regress-GH-897.js   | 20 ...
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250  [ test/gc/test-net-timeout.js                 ...
# cab88d529da07a73174ffb5e93cd3652a4fe0dd  [ src/node_url.cc | 58 +++++++++++++++++++++++...
#
#                                          n_files  insertions  deletions  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716        2           7        1.0
# b6123cfbe90141464bb86400a5f26c835c50f37        1           6        4.0
# 0c72c6d55452ffd0e7719b869bc54c3861595ab        2          20       17.0
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250        2           2        4.0
# cab88d529da07a73174ffb5e93cd3652a4fe0dd        1          29       29.0
#
#                                          pat_code  pat_doc  pat_test  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716         2        3         0
# b6123cfbe90141464bb86400a5f26c835c50f37         1        2         0
# 0c72c6d55452ffd0e7719b869bc54c3861595ab         2        3         2
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250         2        3         2
# cab88d529da07a73174ffb5e93cd3652a4fe0dd         1        2         0
#
#                                          pat_build  text_code  text_doc  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716          3          0         0
# b6123cfbe90141464bb86400a5f26c835c50f37          2          0         0
# 0c72c6d55452ffd0e7719b869bc54c3861595ab          3          0         0
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250          3          0         0
# cab88d529da07a73174ffb5e93cd3652a4fe0dd          2          0         0
#
#                                          text_test  text_build  subjectivity  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716          0           1             0
# b6123cfbe90141464bb86400a5f26c835c50f37          0           0             0
# 0c72c6d55452ffd0e7719b869bc54c3861595ab         10           0             0
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250          2           0             1
# cab88d529da07a73174ffb5e93cd3652a4fe0dd          0           0             0
#
#                                          polarity
# 57e2f2138c37e636e1f7684ab07cb36eea79716         0
# b6123cfbe90141464bb86400a5f26c835c50f37         0
# 0c72c6d55452ffd0e7719b869bc54c3861595ab         0
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250         0
# cab88d529da07a73174ffb5e93cd3652a4fe0dd         0

# %%
df.polarity.describe()
# Out:
# count    4716.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
# Name: polarity, dtype: float64

# %%
print('Class                                                                                        Amount')
for i in range(1,10):
    classCount = df.activity.value_counts()
print(classCount)
# Out:
# Class                                                                                        Amount
# test                                                1131
# doc                                                 1118
# src                                                  288
# deps                                                 237
# tools                                                202
# build                                                156
# buffer                                               108
# http                                                  80
# benchmark                                             75
# repl                                                  74
# crypto                                                64
# fs                                                    61
# util                                                  50
# lib                                                   45
# tls                                                   43
# net                                                   39
# url                                                   39
# inspector                                             38
# child_process                                         37
# stream                                                28
# timers                                                27
# cluster                                               27
# module                                                27
# node                                                  23
# path                                                  21
# readline                                              19
# dns                                                   19
# async_wrap                                            19
# zlib                                                  19
# process                                               17
#                                                     ...
# src,win                                                1
# Working on 6.0.0                                       1
# 2016-10-12, Version 6.8.0 (Current)                    1
# Working on v5.0.0                                      1
# bench                                                  1
# src,module                                             1
# 2015-07-09 io.js v2.3.4 Release                        1
# 2016-03-31 Version 0.10.44 (Maintenance) Release       1
# Working on v2.1.1                                      1
# Add CII Best Practices badge to README.md              1
# Working on v2.0.3                                      1
# 2015-12-16, Version 5.3.0 (Stable)                     1
# child_process, win                                     1
# 2016-09-27 Version 0.12.16 (Maintenance) Release       1
# stream, test                                           1
# _stream_wrap                                           1
# 2016-10-25, Version 7.0.0 (Current)                    1
# Revert "repl                                           1
# 2016-04-20, Version 5.11.0 (Stable) Release            1
# 2016-12-06, Version 7.2.1 (Current)                    1
# Working on v3.0.0                                      1
# doc,dgram                                              1
# unix,stream                                            1
# node_contextify                                        1
# build,src                                              1
# tls, crypto                                            1
# tls,crypto                                             1
# 2016-11-22, Version 7.2.0 (Current)                    1
# 2016-06-23 Version 0.12.15 (Maintenance) Release       1
# http{s}                                                1
# Name: activity, dtype: int64

# %%
print('User                                 Count')
for i in range(1,10):
    classCount = df.author.value_counts()
print(classCount)
# Out:
# User                                 Count
# rtrott@gmail.com                        609
# info@bnoordhuis.nl                      292
# jasnell@gmail.com                       178
# rod@vagg.org                            178
# cjihrig@gmail.com                       144
# mscdex@mscdex.net                       142
# anna@addaleax.net                       133
# thechargingvolcano@gmail.com            117
# fedor@indutny.com                       111
# fishrock123@rocketmail.com               97
# evanlucas@me.com                         91
# trev.norris@gmail.com                    82
# ofrobots@google.com                      73
# santiago.gimeno@gmail.com                66
# mborins@us.ibm.com                       60
# mic.besace@gmail.com                     57
# ohtsu@iij.ad.jp                          52
# me@silverwind.io                         48
# targos@protonmail.com                    46
# edsadr@gmail.com                         44
# vieuxtech@gmail.com                      42
# michael_dawson@ca.ibm.com                39
# eostroukhov@chromium.org                 38
# tflanagan@datacollaborative.com          37
# daniel.bevenius@gmail.com                35
# bugs@bergstroem.nu                       33
# vsemozhetbyt@gmail.com                   31
# chalkerx@gmail.com                       31
# reis@janeasystems.com                    30
# yorkiefixer@gmail.com                    28
#                                        ...
# sudaraka@sudaraka.org                     1
# dmh@dmh.org.uk                            1
# doug.wade@redfin.com                      1
# mike.tunnicliffe@uk.ibm.com               1
# jared.young@panasonic.aero                1
# smikes@cubane.com                         1
# brhugh@microsoft.com                      1
# ashita.nagesh@gmail.com                   1
# braydon@bitpay.com                        1
# stefanbu@ca.ibm.com                       1
# peter.w.geiss@gmail.com                   1
# michaelf614@gmail.com                     1
# tommydelved@gmail.com                     1
# dimhotepus@users.noreply.github.com       1
# kmccmk9@gmail.com                         1
# imran@imraniqbal.org                      1
# sartrey@163.com                           1
# github@pallxk.com                         1
# stevenson.sharp@gmail.com                 1
# m.goleb@gmail.com                         1
# alexander.penev@sap.com                   1
# johanneswueller@gmail.com                 1
# joeycozza@gmail.com                       1
# michael.wain@skybettingandgaming.com      1
# nelson@yoshokatana.com                    1
# doug@dougwade.io                          1
# wvenema@xebia.com                         1
# ncopa@alpinelinux.org                     1
# BrendonPierson@gmail.com                  1
# krswfmy@gmail.com                         1
# Name: author, dtype: int64

# %%
x = {'Count': pd.Series(df.activity.value_counts())
     }
activity_count = pd.DataFrame(x)
activity_count.head()
# Out:
#        Count
# test    1131
# doc     1118
# src      288
# deps     237
# tools    202

# %%
plt.figure(figsize=(18,10))
activity_count.query('Count > 5').plot(kind='bar', color="blue", alpha=.75)
plt.title("Distribution of Activities")
plt.show()

# %%
#####################

# %%
#####################

# %%
############################

# %%
dfTest = df[df.activity.isin(["Build","Tests", "Docs", "Release", "Core"])]

# %%
dfTest.describe()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#           n_files   insertions     deletions    pat_code     pat_doc  \
# count  378.000000   378.000000    312.000000  378.000000  378.000000
# mean     3.574074   117.076720    132.262821    3.280423    4.574074
# std      9.555426   785.713143    931.973549    9.215411    9.555426
# min      1.000000     1.000000      1.000000    0.000000    2.000000
# 25%      1.000000     2.000000           NaN    1.000000    2.000000
# 50%      1.000000     6.000000           NaN    1.000000    2.000000
# 75%      3.000000    20.750000           NaN    3.000000    4.000000
# max    129.000000  8708.000000  11415.000000  129.000000  130.000000
#
#          pat_test   pat_build   text_code    text_doc   text_test  text_build  \
# count  378.000000  378.000000  378.000000  378.000000  378.000000  378.000000
# mean     0.185185    4.574074    0.042328    0.097884    0.671958    0.476190
# std      0.615962    9.555426    0.354294    0.314876    1.029180    0.555383
# min      0.000000    2.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    2.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    4.000000    0.000000    0.000000    1.000000    1.000000
# max      8.000000  130.000000    6.000000    2.000000    7.000000    2.000000
#
#        subjectivity    polarity
# count    378.000000  378.000000
# mean       0.026455    0.002646
# std        0.160697    0.051434
# min        0.000000    0.000000
# 25%        0.000000    0.000000
# 50%        0.000000    0.000000
# 75%        0.000000    0.000000
# max        1.000000    1.000000

# %%
dfTest['deletions'] = dfTest['deletions'].fillna('0')
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
##LEAVE THINGS ABOVE, BUT NOT RUN THEM

# %%
#######

# %%
#######

# %%
#######

# %%
#######

# %%
#######

# %%
from sklearn import cross_validation
from sklearn.preprocessing import *
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import *
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import *
from sklearn.cross_validation import KFold
import random

# %%
dfTest = pd.read_csv('jQuery_Training.csv', index_col=0, encoding="utf-8")
dfFinal = dfTest.drop("activity", 1).drop("files", 1).drop("text", 1).drop("date", 1).drop("author", 1)
X = dfFinal.values
y = dfTest.activity.values

# %%
dfTest.head()
# Out:
#                                                            author  \
# 8816caf26c0acc7067cd5bad9c03cfb54e54979           alex@louden.com
# 10ac0e532a9376106c50f0c21a0d0fd0483b700         m.goleb@gmail.com
# d9145fa15d91ab6c804161ecd892d4d08b71aa2        broder93@gmail.com
# cb4cd71ef018854f75646270bacd4c4d3da9cde  richard.gibson@gmail.com
# 754e315f8a7760bcdc162712d2be7fee058fdc2         m.goleb@gmail.com
#
#                                                                    date  \
# 8816caf26c0acc7067cd5bad9c03cfb54e54979   Thu Jan 5 16:49:02 2017 +0800
# 10ac0e532a9376106c50f0c21a0d0fd0483b700  Fri Dec 30 12:17:00 2016 +0100
# d9145fa15d91ab6c804161ecd892d4d08b71aa2  Sat Dec 24 10:33:27 2016 +0000
# cb4cd71ef018854f75646270bacd4c4d3da9cde  Mon Dec 19 11:58:48 2016 -0500
# 754e315f8a7760bcdc162712d2be7fee058fdc2  Wed Nov 30 15:32:29 2016 +0100
#
#                                         activity  \
# 8816caf26c0acc7067cd5bad9c03cfb54e54979     Docs
# 10ac0e532a9376106c50f0c21a0d0fd0483b700    Build
# d9145fa15d91ab6c804161ecd892d4d08b71aa2    Tests
# cb4cd71ef018854f75646270bacd4c4d3da9cde    Build
# 754e315f8a7760bcdc162712d2be7fee058fdc2    Build
#
#                                                                                       text  \
# 8816caf26c0acc7067cd5bad9c03cfb54e54979           Docs: Correct typo in issue template\r\n
# 10ac0e532a9376106c50f0c21a0d0fd0483b700      Build: Drop support for building on Node.j...
# d9145fa15d91ab6c804161ecd892d4d08b71aa2      Tests: Added tests for symbol-separated ta...
# cb4cd71ef018854f75646270bacd4c4d3da9cde      Build: Use valid ecmaVersion\r\n    \r\n  ...
# 754e315f8a7760bcdc162712d2be7fee058fdc2      Build: Add most of the dist folder to .esl...
#
#                                                                                      files  \
# 8816caf26c0acc7067cd5bad9c03cfb54e54979  [' .github/ISSUE_TEMPLATE.md | 2 +-\n', ' 1 fi...
# 10ac0e532a9376106c50f0c21a0d0fd0483b700  [' .travis.yml  |  1 -\n', ' Gruntfile.js | 39...
# d9145fa15d91ab6c804161ecd892d4d08b71aa2  [' test/unit/core.js | 27 ++++++++++++++++++--...
# cb4cd71ef018854f75646270bacd4c4d3da9cde  [' test/node_smoke_tests/.eslintrc.json | 2 +-...
# 754e315f8a7760bcdc162712d2be7fee058fdc2  [' .eslintignore | 2 ++\n', ' 1 file changed, ...
#
#                                          n_files  insertions  deletions  \
# 8816caf26c0acc7067cd5bad9c03cfb54e54979      1.0         1.0        1.0
# 10ac0e532a9376106c50f0c21a0d0fd0483b700      2.0        11.0       29.0
# d9145fa15d91ab6c804161ecd892d4d08b71aa2      1.0        18.0        9.0
# cb4cd71ef018854f75646270bacd4c4d3da9cde      1.0         1.0        1.0
# 754e315f8a7760bcdc162712d2be7fee058fdc2      1.0         2.0        0.0
#
#                                          pat_code  pat_doc  pat_test  \
# 8816caf26c0acc7067cd5bad9c03cfb54e54979         1        2         0
# 10ac0e532a9376106c50f0c21a0d0fd0483b700         2        3         0
# d9145fa15d91ab6c804161ecd892d4d08b71aa2         1        2         0
# cb4cd71ef018854f75646270bacd4c4d3da9cde         1        2         0
# 754e315f8a7760bcdc162712d2be7fee058fdc2         0        2         0
#
#                                          pat_build  text_code  text_doc  \
# 8816caf26c0acc7067cd5bad9c03cfb54e54979          2          0         1
# 10ac0e532a9376106c50f0c21a0d0fd0483b700          3          0         0
# d9145fa15d91ab6c804161ecd892d4d08b71aa2          2          0         0
# cb4cd71ef018854f75646270bacd4c4d3da9cde          2          0         0
# 754e315f8a7760bcdc162712d2be7fee058fdc2          2          0         0
#
#                                          text_test  text_build  subjectivity  \
# 8816caf26c0acc7067cd5bad9c03cfb54e54979          0           0             0
# 10ac0e532a9376106c50f0c21a0d0fd0483b700          1           2             0
# d9145fa15d91ab6c804161ecd892d4d08b71aa2          2           0             0
# cb4cd71ef018854f75646270bacd4c4d3da9cde          1           1             0
# 754e315f8a7760bcdc162712d2be7fee058fdc2          0           1             0
#
#                                          polarity
# 8816caf26c0acc7067cd5bad9c03cfb54e54979         0
# 10ac0e532a9376106c50f0c21a0d0fd0483b700         0
# d9145fa15d91ab6c804161ecd892d4d08b71aa2         0
# cb4cd71ef018854f75646270bacd4c4d3da9cde         0
# 754e315f8a7760bcdc162712d2be7fee058fdc2         0

# %%
X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, test_size=0.25)
y_train
# Out:
# array(['Build', 'Core', 'Build', 'Build', 'Docs', 'Build', 'Build',
#        'Release', 'Tests', 'Build', 'Release', 'Tests', 'Build', 'Release',
#        'Tests', 'Tests', 'Build', 'Tests', 'Core', 'Tests', 'Build',
#        'Build', 'Release', 'Build', 'Build', 'Build', 'Build', 'Core',
#        'Core', 'Build', 'Build', 'Build', 'Tests', 'Build', 'Build',
#        'Tests', 'Tests', 'Release', 'Build', 'Tests', 'Tests', 'Build',
#        'Build', 'Build', 'Core', 'Tests', 'Build', 'Build', 'Docs',
#        'Tests', 'Build', 'Release', 'Tests', 'Release', 'Build', 'Tests',
#        'Release', 'Docs', 'Core', 'Core', 'Tests', 'Build', 'Tests',
#        'Build', 'Core', 'Tests', 'Build', 'Docs', 'Build', 'Build',
#        'Build', 'Tests', 'Tests', 'Build', 'Build', 'Core', 'Tests',
#        'Tests', 'Docs', 'Build', 'Docs', 'Build', 'Build', 'Docs', 'Build',
#        'Build', 'Core', 'Build', 'Core', 'Tests', 'Docs', 'Tests', 'Build',
#        'Build', 'Tests', 'Build', 'Build', 'Core', 'Core', 'Build',
#        'Build', 'Core', 'Core', 'Release', 'Core', 'Build', 'Release',
#        'Core', 'Tests', 'Release', 'Tests', 'Build', 'Release', 'Build',
#        'Build', 'Build', 'Tests', 'Build', 'Build', 'Tests', 'Tests',
#        'Tests', 'Build', 'Build', 'Build', 'Tests', 'Docs', 'Core',
#        'Build', 'Build', 'Tests', 'Build', 'Build', 'Tests', 'Build',
#        'Build', 'Release', 'Build', 'Build', 'Tests', 'Tests', 'Core',
#        'Build', 'Release', 'Tests', 'Build', 'Core', 'Tests', 'Core',
#        'Build', 'Build', 'Build', 'Release', 'Build', 'Tests', 'Build',
#        'Build', 'Tests', 'Build', 'Tests', 'Tests', 'Core', 'Build',
#        'Build', 'Build', 'Build', 'Tests', 'Release', 'Build', 'Tests',
#        'Tests', 'Tests', 'Tests', 'Tests', 'Tests', 'Tests', 'Build',
#        'Build', 'Core', 'Core', 'Core', 'Docs', 'Core', 'Core', 'Build',
#        'Docs', 'Core', 'Build', 'Tests', 'Build', 'Tests', 'Core', 'Build',
#        'Tests', 'Build', 'Build', 'Core', 'Build', 'Docs', 'Tests', 'Core',
#        'Tests', 'Build', 'Core', 'Docs', 'Build', 'Tests', 'Docs', 'Tests',
#        'Build', 'Tests', 'Tests', 'Tests', 'Core', 'Build', 'Build',
#        'Build', 'Build', 'Build', 'Build', 'Build', 'Core', 'Build',
#        'Core', 'Build', 'Build', 'Build', 'Build', 'Core', 'Build',
#        'Tests', 'Build', 'Build', 'Tests', 'Core', 'Build', 'Tests',
#        'Build', 'Docs', 'Build', 'Docs', 'Core', 'Build', 'Release',
#        'Release', 'Tests', 'Tests', 'Tests', 'Build', 'Build', 'Build',
#        'Tests', 'Core', 'Build', 'Build', 'Tests', 'Build', 'Tests',
#        'Core', 'Tests', 'Docs', 'Core', 'Tests', 'Build', 'Build', 'Build',
#        'Tests', 'Tests', 'Tests', 'Release', 'Build', 'Tests', 'Docs',
#        'Build', 'Build', 'Core', 'Docs', 'Tests', 'Build', 'Tests', 'Core',
#        'Build', 'Build'], dtype=object)

# %%
clf = LinearDiscriminantAnalysis()
clf.fit(X_train, y_train)
accuracy = clf.score(X_test, y_test)
"accuracy: %.1f percent"%(100*accuracy)
# Out:
# D:\Anaconda\lib\site-packages\sklearn\discriminant_analysis.py:387: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# 'accuracy: 81.1 percent'

# %%
df.describe()
# Out:
# D:\Anaconda\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#            n_files     insertions      deletions     pat_code      pat_doc  \
# count  4716.000000    4716.000000    3772.000000  4716.000000  4716.000000
# mean     14.384436     732.071459     478.211029    11.925148    15.384436
# std     131.389011   10566.586003    5478.142932   119.250411   131.389011
# min       1.000000       0.000000       0.000000     0.000000     2.000000
# 25%       1.000000       3.000000            NaN     1.000000     2.000000
# 50%       1.000000      11.000000            NaN     1.000000     2.000000
# 75%       2.000000      39.000000            NaN     2.000000     3.000000
# max    4293.000000  475138.000000  160046.000000  4090.000000  4294.000000
#
#           pat_test    pat_build    text_code     text_doc    text_test  \
# count  4716.000000  4716.000000  4716.000000  4716.000000  4716.000000
# mean      3.811069    15.384436     0.114080     0.391009     0.758058
# std      39.213797   131.389011     0.406893     0.846549     1.443231
# min       0.000000     2.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     0.000000     0.000000
# 50%       0.000000     2.000000     0.000000     0.000000     0.000000
# 75%       1.000000     3.000000     0.000000     1.000000     1.000000
# max     971.000000  4294.000000     6.000000    25.000000    19.000000
#
#         text_build  subjectivity  polarity
# count  4716.000000   4716.000000    4716.0
# mean      0.103265      0.015691       0.0
# std       0.494875      0.124291       0.0
# min       0.000000      0.000000       0.0
# 25%       0.000000      0.000000       0.0
# 50%       0.000000      0.000000       0.0
# 75%       0.000000      0.000000       0.0
# max      10.000000      1.000000       0.0

# %%
dfComplete = df.copy()
dfComplete['deletions'] = dfComplete['deletions'].fillna(0)
dfComplete['n_files'] = dfComplete['n_files'].fillna(0)
dfComplete['insertions'] = dfComplete['insertions'].fillna(0)
dfComplete.describe()
# Out:
#            n_files     insertions      deletions     pat_code      pat_doc  \
# count  4716.000000    4716.000000    4716.000000  4716.000000  4716.000000
# mean     14.384436     732.071459     382.487701    11.925148    15.384436
# std     131.389011   10566.586003    4902.886491   119.250411   131.389011
# min       1.000000       0.000000       0.000000     0.000000     2.000000
# 25%       1.000000       3.000000       1.000000     1.000000     2.000000
# 50%       1.000000      11.000000       3.000000     1.000000     2.000000
# 75%       2.000000      39.000000      13.000000     2.000000     3.000000
# max    4293.000000  475138.000000  160046.000000  4090.000000  4294.000000
#
#           pat_test    pat_build    text_code     text_doc    text_test  \
# count  4716.000000  4716.000000  4716.000000  4716.000000  4716.000000
# mean      3.811069    15.384436     0.114080     0.391009     0.758058
# std      39.213797   131.389011     0.406893     0.846549     1.443231
# min       0.000000     2.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     0.000000     0.000000
# 50%       0.000000     2.000000     0.000000     0.000000     0.000000
# 75%       1.000000     3.000000     0.000000     1.000000     1.000000
# max     971.000000  4294.000000     6.000000    25.000000    19.000000
#
#         text_build  subjectivity  polarity
# count  4716.000000   4716.000000    4716.0
# mean      0.103265      0.015691       0.0
# std       0.494875      0.124291       0.0
# min       0.000000      0.000000       0.0
# 25%       0.000000      0.000000       0.0
# 50%       0.000000      0.000000       0.0
# 75%       0.000000      0.000000       0.0
# max      10.000000      1.000000       0.0

# %%
dfCompleteX = dfComplete.drop("activity", 1).drop("files", 1).drop("text", 1).drop("date", 1).drop("author", 1)

# %%
dfCompleteX.head()
# Out:
#                                          n_files  insertions  deletions  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716        2           7        1.0
# b6123cfbe90141464bb86400a5f26c835c50f37        1           6        4.0
# 0c72c6d55452ffd0e7719b869bc54c3861595ab        2          20       17.0
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250        2           2        4.0
# cab88d529da07a73174ffb5e93cd3652a4fe0dd        1          29       29.0
#
#                                          pat_code  pat_doc  pat_test  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716         2        3         0
# b6123cfbe90141464bb86400a5f26c835c50f37         1        2         0
# 0c72c6d55452ffd0e7719b869bc54c3861595ab         2        3         2
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250         2        3         2
# cab88d529da07a73174ffb5e93cd3652a4fe0dd         1        2         0
#
#                                          pat_build  text_code  text_doc  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716          3          0         0
# b6123cfbe90141464bb86400a5f26c835c50f37          2          0         0
# 0c72c6d55452ffd0e7719b869bc54c3861595ab          3          0         0
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250          3          0         0
# cab88d529da07a73174ffb5e93cd3652a4fe0dd          2          0         0
#
#                                          text_test  text_build  subjectivity  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716          0           1             0
# b6123cfbe90141464bb86400a5f26c835c50f37          0           0             0
# 0c72c6d55452ffd0e7719b869bc54c3861595ab         10           0             0
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250          2           0             1
# cab88d529da07a73174ffb5e93cd3652a4fe0dd          0           0             0
#
#                                          polarity
# 57e2f2138c37e636e1f7684ab07cb36eea79716         0
# b6123cfbe90141464bb86400a5f26c835c50f37         0
# 0c72c6d55452ffd0e7719b869bc54c3861595ab         0
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250         0
# cab88d529da07a73174ffb5e93cd3652a4fe0dd         0

# %%
dfComplete["predicted"] = clf.predict(dfCompleteX)

# %%
dfComplete.describe()
# Out:
#            n_files     insertions      deletions     pat_code      pat_doc  \
# count  4716.000000    4716.000000    4716.000000  4716.000000  4716.000000
# mean     14.384436     732.071459     382.487701    11.925148    15.384436
# std     131.389011   10566.586003    4902.886491   119.250411   131.389011
# min       1.000000       0.000000       0.000000     0.000000     2.000000
# 25%       1.000000       3.000000       1.000000     1.000000     2.000000
# 50%       1.000000      11.000000       3.000000     1.000000     2.000000
# 75%       2.000000      39.000000      13.000000     2.000000     3.000000
# max    4293.000000  475138.000000  160046.000000  4090.000000  4294.000000
#
#           pat_test    pat_build    text_code     text_doc    text_test  \
# count  4716.000000  4716.000000  4716.000000  4716.000000  4716.000000
# mean      3.811069    15.384436     0.114080     0.391009     0.758058
# std      39.213797   131.389011     0.406893     0.846549     1.443231
# min       0.000000     2.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     0.000000     0.000000
# 50%       0.000000     2.000000     0.000000     0.000000     0.000000
# 75%       1.000000     3.000000     0.000000     1.000000     1.000000
# max     971.000000  4294.000000     6.000000    25.000000    19.000000
#
#         text_build  subjectivity  polarity
# count  4716.000000   4716.000000    4716.0
# mean      0.103265      0.015691       0.0
# std       0.494875      0.124291       0.0
# min       0.000000      0.000000       0.0
# 25%       0.000000      0.000000       0.0
# 50%       0.000000      0.000000       0.0
# 75%       0.000000      0.000000       0.0
# max      10.000000      1.000000       0.0

# %%
x = {'Count': pd.Series(dfComplete.predicted.value_counts())
     }
activity_count = pd.DataFrame(x)
activity_count.head()
# Out:
#          Count
# Core      1759
# Tests     1358
# Docs      1291
# Build      304
# Release      4

# %%
dfComplete[["activity", "predicted"]]
# Out:
#                                                                 activity  \
# 57e2f2138c37e636e1f7684ab07cb36eea79716                           crypto
# b6123cfbe90141464bb86400a5f26c835c50f37                              url
# 0c72c6d55452ffd0e7719b869bc54c3861595ab                             test
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250                             test
# cab88d529da07a73174ffb5e93cd3652a4fe0dd                              url
# 9ebdf14005cc948529b3f193ad550d5dfded26a                              doc
# 024104eecebda372022b671df97439e41f024ec                             test
# f75e21662fa5442e9069bfb6f23b625ea1a5b6f                             test
# 2ccffb081204c8f9b8b5a2a57354276f5676891                             test
# 26e967c6bddd1cfb901f7b12d06f9e3136243c1                              url
# f8582e5332f0cac61b5f441cdfcac0b5959d775                             test
# e7a414853fda90e6db28d1182ceb8ea61fbb83a                             test
# 3c482045859531e4983bb5481a151ac56b72161                      Revert "doc
# 92163c74cf8ed5bf581231a348d75e61809b9a2                             test
# c58193d1b1f9ac492a3fd44644e151996a94cb6                              doc
# 5474c8cee47cda7ca0e3711bd39ebcd8a6d8964                             test
# a776b3a56642d4cade5fa26c27c654bb6dde759                        inspector
# 74ecb05988da472d9f8cb58bf5e9d725539daeb                            build
# 8bb65f64117a3ab72a661e342a832ac2f10ec13                              url
# 4c6b6b22a6ea92b3307bfcfab933b75b9b70639                             test
# 95bd11468c99434ce8d8ca77af5b076bca7feb0                             test
# 9902124a9d697e441dbf724aa6b26bd98f75dd0                          process
# 1650aa8fc2bdd94bed7982ffb979004b5ef4fae                             test
# 4b4611e58f6f1509fe73bc48165acc1311254fc                              doc
# 62f260c4dacfcf3ac7b4609cb052b5d6ef2a345                              doc
# 22b43997f4f9f5204c337a8028d964eddf31d00                             test
# f1e77d186c021539731e8279eb68e2c7aae0a21                               vm
# 30dd14793da2aa1c252e38d33abb37570f8ee8a                        benchmark
# 0a2bb53b0eebf8f2fd6d3a3342b1c3d45a1bfb5                              doc
# 65bf2804cc9154d619e6898d4b4ac0b35a5a093                             test
# ...                                                                  ...
# dde95a8bdd1b5aaeb3bb68a1f0abf7cfc8b3c96                       async-wrap
# d42ba056afe1efe9a4f58f1274d9305c4998a1f                       async-wrap
# b2c78644972cdbeeb498f287640e3d6067a814f                       async-wrap
# 4bf609fd2dce0343157d2bf8afa323744fd3107                       async-wrap
# ed10f13492221da0e5d1795bb0c780308c08d48                              src
# 696c9efabd7efc962c6f01ac111c5809117ba95                              src
# dafdc57d1558c1de58f12a5d47e83c66d8d0bc2                Working on v2.0.1
# c89c4c7acdaa2035ec42195ade689419209c2fd  2015-05-04 io.js v2.0.0 Release
# 1b9913e1f537c96c4cb7d130a940590e3031042                              src
# c1fb39ce81373c161b4c7f873f96ae1830b0875                              doc
# 9581b2767766353e496bd98f91d4701a6014254                            build
# a219b00d163254f866e3287f690845d437b993a                             repl
# 51d482b151cc15b8273d705ec57209d0fa1db2a                             repl
# 67542ae17510e3657c2a946fde3dee4d775ac88                            build
# 79f6116aa7927532b8fab0b09a17709bc83c651                              src
# 7620fb96d339f704932f9bb9a0dceb9952df2d4                         tls_wrap
# acc1fa35ce546e88e18bdc10d9bc584d098f713                              doc
# 02997c1f08516fe84f52957cfd830a46d7eceac                      Revert "url
# daed248835d743dcfc320dc717c2b7de6834b17                      Revert "url
# f39ef4ca11bf0c6c6891dec3fa0d2d3d16513cb                      Revert "url
# 6877216bd833face753d9a5d573ad477895d880                              url
# bdd81a91bdce4cc59163e3be752dc3c53491987                              url
# 4f58983952fb56262795893b4f7b0482d1256f2                              net
# a3a1909ab5c1d6ac3104327e148acfbc6b5eb24                              doc
# e2fce0502399db5d0902a0d3eb9528e1d9420c4                             repl
# 2388dbf40fcce85e79c5aba8a6c411f523fd17d                              doc
# fd7fc429c394059113432312ed19decbafd8fc4                              url
# 7c4cc26e2ff3dd1210d79ae22a8fe5ce43fcef3                              doc
# 7782c0af8a4e4ee26da6e44e07c3987d9d3ddb6                             node
# a5195ccaf6d51262c9089c2ec5c6f5634bc12b5                             repl
#
#                                         predicted
# 57e2f2138c37e636e1f7684ab07cb36eea79716     Build
# b6123cfbe90141464bb86400a5f26c835c50f37      Core
# 0c72c6d55452ffd0e7719b869bc54c3861595ab     Tests
# 67be658f966dafe3d16bdd7b5bbb7c5e58c7250     Tests
# cab88d529da07a73174ffb5e93cd3652a4fe0dd      Core
# 9ebdf14005cc948529b3f193ad550d5dfded26a      Docs
# 024104eecebda372022b671df97439e41f024ec     Tests
# edc1aa690cceb8396a10fb7dfbb4efe5f5ce26b                                               Docs
# bb62bb3ae771fc57cc62ee14bd10d94680efb4f                                              Build
# 18ca7bfe0f5e3184bf1ed55daf1668702c5577a                                              Build
# 1c29dc1fecc675054762fb1f50a0cdd6b1f0df0                                            Release
# c16f1185493f94d20a9132621abc8106d614d58                                            Release
# cb8a1b3ebf53007637c12c376e3101681f57c02                                               Core
# 7f1da6b91a86ef3f54f4cf16dd87f5afd33c835                                              Build
# 23ed99f4a7e6259daf90af9bce849d1400b11d6                                              Tests
# 5d09b90ca39876d1d9cc29508cfd56e7e3c350e                                               Core
# bbcce68d7b8b8a7a2164a0f7a280ae9daf70b5c                                               Core
# d4f53416e5f74fa98e0c1d66b6f3c285a12f0ce                                              Build
# f5f5433d5ba8bcc1644c8bbb3c1038f97d454bf                                              Tests
# 2e24471c89b80e6208b4987bb76994e64c1e489                                               Core
# 60c0c6f995a4f7584dac5be8fe5eea114a95f69                                         Traversing
# ca2aa2254e805612d12bca457afefa920d0af5c                                              Build
# 160523d30e8f05c1a84592dfaa20eb2f0333708                                              Build
# ...                                                                                    ...
# 373a499d39e35172f9b93af993681e4b5f0908b                           Reduced script transport
# 59e3f57466e508ccfc3e30acfc2aee0c52df83c  Fix requirements and dependencies in README, c...
# 488f68adfe7d593f538aa1791ba35c6ace87a7e  Fix broken link in CONTRIBUTING.md, close gh-1...
# 632711d5cdc184b9d05850c5ca577799d8df399                                      Update Sizzle
# 871218cdf37fa0a3e0457882828648e6a40164a                                  Fix jQuery #13251
# 0290b8ffb05c504d3866a619f282bf795bc01f6                                       Ref cc324abf
# c324abf739669bd2a4669742c994b86c4ad467b                                          Fix #8335
# 96aa9e2709b4ba132b966a0f1a13d0e8eb49b9a                                         Fix #13233
# 06b698813c7d999b6f572d8d00b2691952fdea6                                          No ticket
# f0756b5341eb94ae540de20b9756762dc0a4144                                         Fix #13182
# 0cc33e27beb56e41bea1274bc3b51b1c59af9af                                         Fix #13183
# 6278d40ae86ecd45786eebcb20b72564f2bb53f            Updating the source version to 2.0.0pre
# cc06af007ad2f85b52ee757296d235fcf93337a                       Tagging the 2.0.0b1 release.
# 8cbbd3615d714bdb20fc5c817c0519bb226694c  Let version 1.9 claim jquery.js and jquery-lat...
# 7a2e3c72f0c9833214b17ca81f76e0a9da62495           Simplify release notes generator script.
# 48e1a75c87d13a0c87c6cc58b82bf9746e7eb9c                   de486684 with moar guard for IE6
# ff59f97ac63dd723b6932e7c6e2186735315401                                      Add a comment
# 8ad408f824492cd36a04d7c16df9df6c357ddb4  Fixes #13200 - innerHTML in buildFragment need...
# 1b95797155077e4e670c0bbb2c57815f89769a1                                         Fix #13203
# e486684e3df1988080fd41c97d5f6ab8e6171ed                      Fix f860e0bd Firefox failures
# 75b9ef8d030b0dbf247e826bfbf9585c7dbf98b                                         Fix #13180
# 76723436460c928b0eaf88fe36b575f36049a17                                          No ticket
# a71737fb424a43b9f705098c5be06b1c40f29b6  Leave out the web site, you know where to find...
# 0c1bdde6099a3fa1c16014be090aa6bf1fca8ca            Update copyrights used in file headers.
# ad229c53e50ae9e34ae3bd8ddf1737c538416f6                                      Update Sizzle
# aba2102b2f62d8a92f262fe6611f9df45088b3a  Revert grunt, grunt-contrib-jshint, and grunt-...
# 1a59f78c26eed95f4ad5d69d00578e63754713d                                      Update Sizzle
# ff2d1d3dcd99f7bd45fa312ba91bb1248cb6d55  Fix #12886. Fix map file reference in .min.js ...
# a49ef98d51e8a79ee70d5339a662dead5711165                                        Ref gh-1117
# e6c1ba92faf830d40cafe7a4deb4ad5ab9045fe                                        Ref gh-1117
#
#                                                                                       text  \
# 8816caf26c0acc7067cd5bad9c03cfb54e54979             Docs: Correct typo in issue template\n
# 10ac0e532a9376106c50f0c21a0d0fd0483b700      Build: Drop support for building on Node.j...
# d9145fa15d91ab6c804161ecd892d4d08b71aa2      Tests: Added tests for symbol-separated ta...
# f3a43eff8682b59cec785be6003753fa4b93706      Offset: Eliminate little-used internal fun...
# cb4cd71ef018854f75646270bacd4c4d3da9cde      Build: Use valid ecmaVersion\n    \n    Fi...
# 754e315f8a7760bcdc162712d2be7fee058fdc2      Build: Add most of the dist folder to .esl...
# 3e0a560723762036b7a2a9d5c99b7b3681cbbc6      Build: Drop jscs.json from .npmignore\n   ...
# bc8638c38bccd4ac7b787ac4d79de4bf2b6a0a0      Build: ESLint setup improvements\n    \n  ...
# d79c6466386862e70ce276a094c1897112b7491      Deferred: Stop inventing jQuery.when() res...
# 777899a747647f3fa839eea4b0bb695d3b60f06      Offset: report offset for 0 sized elements...
# e50967725e61a5d71c2792131de61dec0520f9c      Build: Make the @CODE-replacing regex more...
# fbab88110725c6e0b89f6513b9f7cff50320e1e      Build: jQuery Foundation -> JS Foundation\...
# b9575b9d14399e9426b9eacdd92b3717846c3f2      Core: Deprecate jQuery.isArray\n    \n    ...
# b4cb0d33731a58384e02ad51e703e7dcb00e424      Build: Stop testing on Node.js 0.10\n    \...
# edc1aa690cceb8396a10fb7dfbb4efe5f5ce26b      Docs: Remove supported jQuery versions fro...
# bb62bb3ae771fc57cc62ee14bd10d94680efb4f                    Build: Run tests on Node.js 7\n
# 18ca7bfe0f5e3184bf1ed55daf1668702c5577a      Build: Updating the master version to 3.1....
# 1c29dc1fecc675054762fb1f50a0cdd6b1f0df0      Release: fix quotes for releasing on Windo...
# c16f1185493f94d20a9132621abc8106d614d58      Release: add email to .mailmap, update AUT...
# cb8a1b3ebf53007637c12c376e3101681f57c02      Core: remove precautionary variable `ready...
# 7f1da6b91a86ef3f54f4cf16dd87f5afd33c835      Build: Make sourcemap updates in two .repl...
# 23ed99f4a7e6259daf90af9bce849d1400b11d6      Tests: Add test results for Safari 10/iOS ...
# 5d09b90ca39876d1d9cc29508cfd56e7e3c350e      Core: Compress stripAndCollapse\n    \n   ...
# bbcce68d7b8b8a7a2164a0f7a280ae9daf70b5c      Core: rnotwhite -> rhtmlnotwhite and jQuer...
# d4f53416e5f74fa98e0c1d66b6f3c285a12f0ce      Build: Update promises-aplus-tests for com...
# f5f5433d5ba8bcc1644c8bbb3c1038f97d454bf      Tests: Disable a whitespace-setting test i...
# 2e24471c89b80e6208b4987bb76994e64c1e489      Core: expose noConflict in AMD mode\n    \...
# 60c0c6f995a4f7584dac5be8fe5eea114a95f69      Traversing: Let .not(arraylike) pass non-e...
# ca2aa2254e805612d12bca457afefa920d0af5c      Build: Update Sizzle to 2.3.3\n    \n    F...
# 160523d30e8f05c1a84592dfaa20eb2f0333708                    Build: Update Sizzle to 2.3.2\n
# ...                                                                                    ...
# 373a499d39e35172f9b93af993681e4b5f0908b                         Reduced script transport\n
# 59e3f57466e508ccfc3e30acfc2aee0c52df83c      Fix requirements and dependencies in READM...
# 488f68adfe7d593f538aa1791ba35c6ace87a7e      Fix broken link in CONTRIBUTING.md, close ...
# 632711d5cdc184b9d05850c5ca577799d8df399          Update Sizzle: fixes native slice usage\n
# 871218cdf37fa0a3e0457882828648e6a40164a      Fix jQuery #13251: use slice instead of su...
# 0290b8ffb05c504d3866a619f282bf795bc01f6      Ref cc324abf: use acceptData to determine ...
# c324abf739669bd2a4669742c994b86c4ad467b      Fix #8335: Avoid memory leak by never sett...
# 96aa9e2709b4ba132b966a0f1a13d0e8eb49b9a      Fix #13233: re-allow .replaceWith of text ...
# 06b698813c7d999b6f572d8d00b2691952fdea6      No ticket: improve replaceWith testing\n  ...
# f0756b5341eb94ae540de20b9756762dc0a4144                        Fix #13182: update Sizzle\n
# 0cc33e27beb56e41bea1274bc3b51b1c59af9af      Fix #13183: Wrong animation initial value ...
# 6278d40ae86ecd45786eebcb20b72564f2bb53f          Updating the source version to 2.0.0pre\n
# cc06af007ad2f85b52ee757296d235fcf93337a                     Tagging the 2.0.0b1 release.\n
# 8cbbd3615d714bdb20fc5c817c0519bb226694c      Let version 1.9 claim jquery.js and jquery...
# 7a2e3c72f0c9833214b17ca81f76e0a9da62495         Simplify release notes generator script.\n
# 48e1a75c87d13a0c87c6cc58b82bf9746e7eb9c      de486684 with moar guard for IE6\n    (che...
# ff59f97ac63dd723b6932e7c6e2186735315401                                    Add a comment\n
# 8ad408f824492cd36a04d7c16df9df6c357ddb4      Fixes #13200 - innerHTML in buildFragment ...
# 1b95797155077e4e670c0bbb2c57815f89769a1      Fix #13203: delegated events with selector...
# e486684e3df1988080fd41c97d5f6ab8e6171ed      Fix f860e0bd Firefox failures\n    (cherry...
# 75b9ef8d030b0dbf247e826bfbf9585c7dbf98b      Fix #13180: don't delegate into SVG <use>\...
# 76723436460c928b0eaf88fe36b575f36049a17      No ticket: compress event.js\n    (cherry ...
# a71737fb424a43b9f705098c5be06b1c40f29b6      Leave out the web site, you know where to ...
# 0c1bdde6099a3fa1c16014be090aa6bf1fca8ca          Update copyrights used in file headers.\n
# ad229c53e50ae9e34ae3bd8ddf1737c538416f6                                    Update Sizzle\n
# aba2102b2f62d8a92f262fe6611f9df45088b3a      Revert grunt, grunt-contrib-jshint, and gr...
# 1a59f78c26eed95f4ad5d69d00578e63754713d                                    Update Sizzle\n
# ff2d1d3dcd99f7bd45fa312ba91bb1248cb6d55      Fix #12886. Fix map file reference in .min...
# a49ef98d51e8a79ee70d5339a662dead5711165      Ref gh-1117: Use native push for size and ...
# e6c1ba92faf830d40cafe7a4deb4ad5ab9045fe      Ref gh-1117: Don't stop on a falsy value i...
#
#                                                                                      files  \
# 8816caf26c0acc7067cd5bad9c03cfb54e54979  [ .github/ISSUE_TEMPLATE.md | 2 +-\n,  1 file ...
# 10ac0e532a9376106c50f0c21a0d0fd0483b700  [ .travis.yml  |  1 -\n,  Gruntfile.js | 39 ++...
# d9145fa15d91ab6c804161ecd892d4d08b71aa2  [ test/unit/core.js | 27 ++++++++++++++++++---...
# f3a43eff8682b59cec785be6003753fa4b93706  [ src/offset.js | 20 ++++++++++----------\n,  ...
# cb4cd71ef018854f75646270bacd4c4d3da9cde  [ test/node_smoke_tests/.eslintrc.json | 2 +-\...
# 754e315f8a7760bcdc162712d2be7fee058fdc2  [ .eslintignore | 2 ++\n,  1 file changed, 2 i...
# 3e0a560723762036b7a2a9d5c99b7b3681cbbc6  [ .npmignore | 1 -\n,  1 file changed, 1 delet...
# bc8638c38bccd4ac7b787ac4d79de4bf2b6a0a0  [ .eslintrc-browser.json                      ...
# d79c6466386862e70ce276a094c1897112b7491  [ src/deferred.js       | 14 ++++++++------\n,...
# 777899a747647f3fa839eea4b0bb695d3b60f06  [ src/offset.js       | 21 ++++++++-----------...
# e50967725e61a5d71c2792131de61dec0520f9c  [ build/tasks/build.js | 6 +++++-\n,  1 file c...
# fbab88110725c6e0b89f6513b9f7cff50320e1e  [ CONTRIBUTING.md | 4 ++--\n,  Gruntfile.js   ...
# b9575b9d14399e9426b9eacdd92b3717846c3f2  [ src/attributes/val.js   | 4 ++--\n,  src/cor...
# b4cb0d33731a58384e02ad51e703e7dcb00e424  [ .travis.yml  | 1 -\n,  Gruntfile.js | 4 ++--...
# edc1aa690cceb8396a10fb7dfbb4efe5f5ce26b  [ .github/ISSUE_TEMPLATE.md | 2 +-\n,  1 file ...
# bb62bb3ae771fc57cc62ee14bd10d94680efb4f  [ .travis.yml | 1 +\n,  1 file changed, 1 inse...
# 18ca7bfe0f5e3184bf1ed55daf1668702c5577a  [ package.json | 2 +-\n,  1 file changed, 1 in...
# 1c29dc1fecc675054762fb1f50a0cdd6b1f0df0  [ build/release/dist.js | 7 ++++---\n,  1 file...
# c16f1185493f94d20a9132621abc8106d614d58  [ .mailmap    | 1 +\n,  AUTHORS.txt | 2 +-\n, ...
# cb8a1b3ebf53007637c12c376e3101681f57c02  [ src/core/ready-no-deferred.js | 14 ++++-----...
# 7f1da6b91a86ef3f54f4cf16dd87f5afd33c835  [ build/release/cdn.js | 9 +++++----\n,  1 fil...
# 23ed99f4a7e6259daf90af9bce849d1400b11d6  [ test/unit/support.js | 21 ++----------------...
# 5d09b90ca39876d1d9cc29508cfd56e7e3c350e  [ src/core/stripAndCollapse.js | 12 +++++++---...
# bbcce68d7b8b8a7a2164a0f7a280ae9daf70b5c  [ src/ajax.js                  |  8 +++----\n,...
# d4f53416e5f74fa98e0c1d66b6f3c285a12f0ce  [ package.json | 2 +-\n,  1 file changed, 1 in...
# f5f5433d5ba8bcc1644c8bbb3c1038f97d454bf  [ test/unit/css.js | 11 ++++++++++-\n,  1 file...
# 2e24471c89b80e6208b4987bb76994e64c1e489  [ build/tasks/build.js  |  6 +-----\n,  src/ex...
# 60c0c6f995a4f7584dac5be8fe5eea114a95f69  [ src/traversing/findFilter.js | 19 ++++++++++...
# ca2aa2254e805612d12bca457afefa920d0af5c  [ external/sizzle/dist/sizzle.js      | 4 ++--...
# 160523d30e8f05c1a84592dfaa20eb2f0333708  [ external/sizzle/dist/sizzle.js     | 2 +-\n,...
# ...                                                                                    ...
# 373a499d39e35172f9b93af993681e4b5f0908b  [ src/ajax/script.js | 68 +++++++++++++++++---...
# 59e3f57466e508ccfc3e30acfc2aee0c52df83c  [ README.md | 14 ++++++--------\n,  1 file cha...
# 488f68adfe7d593f538aa1791ba35c6ace87a7e  [ CONTRIBUTING.md | 6 +++---\n,  1 file change...
# 632711d5cdc184b9d05850c5ca577799d8df399  [ src/sizzle | 2 +-\n,  1 file changed, 1 inse...
# 871218cdf37fa0a3e0457882828648e6a40164a  [ src/data.js | 2 +-\n,  src/sizzle  | 2 +-\n,...
# 0290b8ffb05c504d3866a619f282bf795bc01f6  [ src/event.js | 4 ++--\n,  1 file changed, 2 ...
# c324abf739669bd2a4669742c994b86c4ad467b  [ src/data.js       |  5 +++++\n,  test/unit/d...
# 96aa9e2709b4ba132b966a0f1a13d0e8eb49b9a  [ src/manipulation.js       | 10 ++--------\n,...
# 06b698813c7d999b6f572d8d00b2691952fdea6  [ test/unit/manipulation.js | 90 +++++++++++++...
# f0756b5341eb94ae540de20b9756762dc0a4144  [ src/sizzle | 2 +-\n,  1 file changed, 1 inse...
# 0cc33e27beb56e41bea1274bc3b51b1c59af9af  [ src/css.js           |  2 +-\n,  src/effects...
# 6278d40ae86ecd45786eebcb20b72564f2bb53f  [ package.json | 2 +-\n,  1 file changed, 1 in...
# cc06af007ad2f85b52ee757296d235fcf93337a  [ package.json | 4 ++--\n,  1 file changed, 2 ...
# 8cbbd3615d714bdb20fc5c817c0519bb226694c  [ build/release.js | 15 ++++++++-------\n,  1 ...
# 7a2e3c72f0c9833214b17ca81f76e0a9da62495  [ build/release-notes.js  | 39 +++++++++++++++...
# 48e1a75c87d13a0c87c6cc58b82bf9746e7eb9c  [ test/unit/event.js | 8 ++++----\n,  1 file c...
# ff59f97ac63dd723b6932e7c6e2186735315401  [ src/manipulation.js | 2 ++\n,  1 file change...
# 8ad408f824492cd36a04d7c16df9df6c357ddb4  [ src/manipulation.js | 10 +++++-----\n,  1 fi...
# 1b95797155077e4e670c0bbb2c57815f89769a1  [ src/event.js       |  4 +++-\n,  test/unit/e...
# e486684e3df1988080fd41c97d5f6ab8e6171ed  [ test/unit/event.js | 7 ++++---\n,  1 file ch...
# 75b9ef8d030b0dbf247e826bfbf9585c7dbf98b  [ src/event.js       | 84 ++++++++++++++++++++...
# 76723436460c928b0eaf88fe36b575f36049a17  [ src/effects.js |   4 +-\n,  src/event.js   |...
# a71737fb424a43b9f705098c5be06b1c40f29b6  [ Gruntfile.js | 2 +-\n,  1 file changed, 1 in...
# 0c1bdde6099a3fa1c16014be090aa6bf1fca8ca  [ Gruntfile.js | 2 +-\n,  src/intro.js | 2 +-\...
# ad229c53e50ae9e34ae3bd8ddf1737c538416f6  [ src/sizzle | 2 +-\n,  1 file changed, 1 inse...
# aba2102b2f62d8a92f262fe6611f9df45088b3a  [ package.json | 6 +++---\n,  1 file changed, ...
# 1a59f78c26eed95f4ad5d69d00578e63754713d  [ src/sizzle | 2 +-\n,  1 file changed, 1 inse...
# ff2d1d3dcd99f7bd45fa312ba91bb1248cb6d55  [ Gruntfile.js | 5 ++++-\n,  1 file changed, 4...
# a49ef98d51e8a79ee70d5339a662dead5711165  [ src/manipulation.js | 4 ++--\n,  1 file chan...
# e6c1ba92faf830d40cafe7a4deb4ad5ab9045fe  [ src/manipulation.js       | 11 ++++++++---\n...
#
#                                          n_files  insertions  deletions  \
# 8816caf26c0acc7067cd5bad9c03cfb54e54979      1.0         1.0        1.0
# 10ac0e532a9376106c50f0c21a0d0fd0483b700      2.0        11.0       29.0
# d9145fa15d91ab6c804161ecd892d4d08b71aa2      1.0        18.0        9.0
# f3a43eff8682b59cec785be6003753fa4b93706      1.0        10.0       10.0
# cb4cd71ef018854f75646270bacd4c4d3da9cde      1.0         1.0        1.0
# 754e315f8a7760bcdc162712d2be7fee058fdc2      1.0         2.0        NaN
# 3e0a560723762036b7a2a9d5c99b7b3681cbbc6      1.0         1.0        NaN
# bc8638c38bccd4ac7b787ac4d79de4bf2b6a0a
# 8816caf26c0acc7067cd5bad9c03cfb54e54979         0
# 10ac0e532a9376106c50f0c21a0d0fd0483b700         0
# d9145fa15d91ab6c804161ecd892d4d08b71aa2         0
# f3a43eff8682b59cec785be6003753fa4b93706         0
# cb4cd71ef018854f75646270bacd4c4d3da9cde         0
# 754e315f8a7760bcdc162712d2be7fee058fdc2         0
# 3e0a560723762036b7a2a9d5c99b7b3681cbbc6         0
# bc8638c38bccd4ac7b787ac4d79de4bf2b6a0a0         0
# d79c6466386862e70ce276a094c1897112b7491         0
# 777899a747647f3fa839eea4b0bb695d3b60f06         0
# e50967725e61a5d71c2792131de61dec0520f9c         0
# fbab88110725c6e0b89f6513b9f7cff50320e1e         0
# b9575b9d14399e9426b9eacdd92b3717846c3f2         0
# b4cb0d33731a58384e02ad51e703e7dcb00e424         0
# edc1aa690cceb8396a10fb7dfbb4efe5f5ce26b         0
# bb62bb3ae771fc57cc62ee14bd10d94680efb4f         0
# 18ca7bfe0f5e3184bf1ed55daf1668702c5577a         0
# 1c29dc1fecc675054762fb1f50a0cdd6b1f0df0         0
# c16f1185493f94d20a9132621abc8106d614d58         0
# cb8a1b3ebf53007637c12c376e3101681f57c02         0
# 7f1da6b91a86ef3f54f4cf16dd87f5afd33c835         0
# 23ed99f4a7e6259daf90af9bce849d1400b11d6         0
# 5d09b90ca39876d1d9cc29508cfd56e7e3c350e         0
# bbcce68d7b8b8a7a2164a0f7a280ae9daf70b5c         0
# d4f53416e5f74fa98e0c1d66b6f3c285a12f0ce         0
# f5f5433d5ba8bcc1644c8bbb3c1038f97d454bf         0
# 2e24471c89b80e6208b4987bb76994e64c1e489         0
# 60c0c6f995a4f7584dac5be8fe5eea114a95f69         0
# ca2aa2254e805612d12bca457afefa920d0af5c         0
# 160523d30e8f05c1a84592dfaa20eb2f0333708         0
# ...                                           ...
# 373a499d39e35172f9b93af993681e4b5f0908b         0
# 59e3f57466e508ccfc3e30acfc2aee0c52df83c         0
# 488f68adfe7d593f538aa1791ba35c6ace87a7e         0
# 632711d5cdc184b9d05850c5ca577799d8df399         0
# 871218cdf37fa0a3e0457882828648e6a40164a         0
# 0290b8ffb05c504d3866a619f282bf795bc01f6         0
# c324abf739669bd2a4669742c994b86c4ad467b         0
# 96aa9e2709b4ba132b966a0f1a13d0e8eb49b9a         0
# 06b698813c7d999b6f572d8d00b2691952fdea6         0
# f0756b5341eb94ae540de20b9756762dc0a4144         0
# 0cc33e27beb56e41bea1274bc3b51b1c59af9af         0
# 6278d40ae86ecd45786eebcb20b72564f2bb53f         0
# cc06af007ad2f85b52ee757296d235fcf93337a         0
# 8cbbd3615d714bdb20fc5c817c0519bb226694c         0
# 7a2e3c72f0c9833214b17ca81f76e0a9da62495         0
# 48e1a75c87d13a0c87c6cc58b82bf9746e7eb9c         0
# ff59f97ac63dd723b6932e7c6e2186735315401         0
# 8ad408f824492cd36a04d7c16df9df6c357ddb4         0
# 1b95797155077e4e670c0bbb2c57815f89769a1         0
# e486684e3df1988080fd41c97d5f6ab8e6171ed         0
# 75b9ef8d030b0dbf247e826bfbf9585c7dbf98b         0
# 76723436460c928b0eaf88fe36b575f36049a17         0
# a71737fb424a43b9f705098c5be06b1c40f29b6         0
# 0c1bdde6099a3fa1c16014be090aa6bf1fca8ca         0
# ad229c53e50ae9e34ae3bd8ddf1737c538416f6         0
# aba2102b2f62d8a92f262fe6611f9df45088b3a         0
# 1a59f78c26eed95f4ad5d69d00578e63754713d         0
# ff2d1d3dcd99f7bd45fa312ba91bb1248cb6d55         0
# a49ef98d51e8a79ee70d5339a662dead5711165         0
# e6c1ba92faf830d40cafe7a4deb4ad5ab9045fe         0
#
# [1191 rows x 18 columns]

# %%
from pandas.tools.plotting import scatter_matrix

scatter_matrix(dfComplete, alpha=0.2, figsize=(10, 10), diagonal='kde')
plt.show()

# %%
clf = GaussianNB()
clf.fit(X_train, y_train)
accuracy = clf.score(X_test, y_test)
"accuracy: %.1f percent"%(100*accuracy)
# Out:
# 'accuracy: 61.1 percent'

# %%
clf = KNeighborsClassifier()
clf.fit(X_train, y_train)
accuracy = clf.score(X_test, y_test)
"accuracy: %.1f percent"%(100*accuracy)
# Out:
# 'accuracy: 54.7 percent'

# %%
scaler = StandardScaler().fit(X_train)
X_train_sc = scaler.transform(X_train)
X_test_sc = scaler.transform(X_test)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
clf = KNeighborsClassifier()
clf.fit(X_train_sc, y_train)
accuracy = clf.score(X_test_sc, y_test)
"accuracy: %.1f percent"%(100*accuracy)
# Out:
# 'accuracy: 87.4 percent'

# %%
clf = LogisticRegression()
clf.fit(X_train, y_train)
accuracy = clf.score(X_test, y_test)
"accuracy: %.1f percent"%(100*accuracy)
# Out:
# 'accuracy: 85.3 percent'

# %%
def accuracy_dist(clfs, X, y, n=10):
    accuracy = np.zeros((n,len(clfs)))
    columns = [clf.__class__.__name__ for clf in clfs]
    for i in range(n):
        X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, random_state=31*i)
        for j in range(len(clfs)):
            clf = clfs[j]
            clf.fit(X_train,y_train)
            accuracy[i][j] = clf.score(X_test,y_test)
    return pd.DataFrame(accuracy, columns=columns, index=range(n))

# %%
accuracy_df = accuracy_dist([GaussianNB(),LinearDiscriminantAnalysis(),LogisticRegression()], X, y)
accuracy_df = pd.concat(
    (accuracy_df, accuracy_dist([KNeighborsClassifier()], StandardScaler().fit_transform(X), y)), axis=1)
accuracy_df.plot(kind='kde', ylim=[0,25])
plt.show()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:387: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
y = {'Count': pd.Series(df.author.value_counts())
     }
author_count = pd.DataFrame(y)
author_count.head()
# Out:
#                           Count
# timmywillisn@gmail.com      245
# m.goleb@gmail.com           221
# markelog@gmail.com          179
# richard.gibson@gmail.com    145
# dave.methvin@gmail.com      135

# %%
plt.figure(figsize=(18,10))
author_count.query('Count > 5').plot(kind='bar', color="blue", alpha=.75)
plt.title("User vs. Number of Activities")
plt.show()

# %%
for index, row in df.iterrows(): 
    textblob = TextBlob(row['text'])
    df.set_value(index, 'polarity', textblob.sentiment.polarity) 
    df.set_value(index, 'subjectivity', textblob.sentiment.subjectivity) 
df.head()
