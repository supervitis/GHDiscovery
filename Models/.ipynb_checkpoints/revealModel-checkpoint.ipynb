# %%
import sys
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import urllib
from threading import Thread
from queue import Queue
import math
import requests
import time 
from datetime import timedelta
import pickle
from datetime import datetime

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
df = pd.DataFrame(columns=['author','date','activity', 'text', 'files'])
filne = "log_reveal.txt"
##with urllib2.urlopen("https://file.io/rSWakX") as f:
with open(filne, 'r+', encoding="utf-8") as f:
    lines = f.readlines()
    ##for i in range(0, 100):
  
    for i in range(0, len(lines)):
        line = lines[i]
        if line[:6] == "commit":
            sha = line[8:].strip()
            ##Author
            line = lines[i+1]
            if line[:6] == "Merge:":
                i = i + 1
                line = lines[i+1]
            divided = line.split("<")
            divided[1][:-2]          
            author = divided[1][:-2]
            ##Author
            line = lines[i+2]
            divided = line.split(":   ")
            date = divided[1].strip()
            line = lines[i+3]  
            text = ""
            if line in ['\n', '\r\n']:
                line = lines[i + 4]
                divided = line.split(":")
                activity = divided[0].strip()
            j = 5
            text += line
            while 1:
                line = lines[i+j]            
                if line in ['\n', '\r\n']:
                    break
                text += line    
                j = j + 1
            j = j + 1
            files = []
            while 1:
                line = lines[i+j]            
                if line in ['\n', '\r\n']:
                    break
                files.append(line)   
                j = j + 1
            print("...........")
            ##print sha
            ##print author
            ##print date
            ##print activity
            ##print files
            print(text)
            df.loc[sha] = pd.Series({'author': author, 'date': date, 'activity': activity, 'text': text, 'files': files})
# Out:
# ...........
#     fix unclosed code block
#
# ...........
#     3.4.0
#
# ...........
#     Merge branch 'dev' of github.com:hakimel/reveal.js
#
# ...........
#     fragments inherit visibility to avoid conflicts with parent slide visibility
#
# ...........
#     don't show error message while iframe fades in #1577
#
# ...........
#     Merge branch 'add-refused-to-display-tips-to-link-preview' of https://github.com/Huxpro/reveal.js into dev
#
# ...........
#     always use lowercase reveal.js
#
# ...........
#     Merge pull request #1767 from demoneaux/readme
#
#     Add note about head.js to readme.
#
# ...........
#     Add note about head.js to readme.
#
#     Closes #1569.
#
# ...........
#     Enable passing options for parsing Markdown.
#
#     Closes #1163, #1495.
#
# ...........
#     Reduce required Node.js version to 4.0.0.
#
#     The development workflow can be used with Node 4+, not just Node 6. We
#     should avoid showing warnings and errors when users are installing this
#     package via npm/yarn.
#
#     Ref. #1729, #1743.
#     Closes #1725.
#
# ...........
#     Merge pull request #1760 from demoneaux/package-json
#
#     Reduce required Node.js version to 4.0.0.
#
# ...........
#     Reduce required Node.js version to 4.0.0.
#
#     The development workflow can be used with Node 4+, not just Node 6. We
#     should avoid showing warnings and errors when users are installing this
#     package via npm/yarn.
#
#     Ref. #1729, #1743.
#     Closes #1725.
#
# ...........
#     Merge pull request #1740 from christinakayastha/feature/printing-remove-slide-number
#
#     Hide slide number when in paper or pdf print view
#
# ...........
#     merge package version conflicts
#
# ...........
#     update dependencies to work with latest node #1743
#
# ...........
#     Merge pull request #1743 from haf/patch-1
#
#     Bump node engine in packages.json
#
# ...........
#     Merge pull request #1747 from spencermathews/feature/readme-defaults-fix
#
#     Defaults in README are not current
#
# ...........
#     Merge pull request #1757 from daanmichiels/correct-copyright
#
#     include contributors in (c)
#
# ...........
#     Merge pull request #1756 from jmpp/better-data-trim
#
#     Implementing a better data-trim
#
# ...........
#     correct copyright message to include contributors
#
# ...........
#     Better version of data-trim on code snippets
#
# ...........
#     Update README.md to reflect current defaults in js/reveal.js
#
# ...........
#     add pdf-ready event; dispatched when the presentation is laid out and ready to print
#
# ...........
#     Bump node engine in packages.json
#
# ...........
#     Don't remove slide-number in pdf view
#
# ...........
#     Hide slide number when in paper or pdf print view
#
# ...........
#     remove debug code
#
# ...........
#     fixes ff overview rendering bug #1649
#
# ...........
#     remove unused dom lookup
#
# ...........
#     attempt at fixing ff transition bug #1627
#
# ...........
#     fix merge conflict for #1634
#
# ...........
#     code format tweaks
#
# ...........
#     only use nodeType 1 and 3 (only relevant types)
#
# ...........
#     limit text written to the status div
#
# ...........
#     renamed grunt 'base' option to 'root' (#1660)
#
#     * Allow slides to be served away from revealjs server location
#
#     The previous 'base' option conflicts with Grunt's 'base' option.
#     Changing it to 'root' avoids this. Further, updating to a newer Grunt
#     allows multiple parameters to be used. therefore `grunt serve --root="."
#     --root="pathtomyslides"` allows you to keep your slide content separate
#     from JS/CSS and such
#
#     * Live reload for relocated base
#
#     * Updated packages to match origin/dev
#
#     * Updated packages to match origin/dev
#
#     * Ensure root is an array
#
# ...........
#     remove issue comment
#
# ...........
#     ignore delta=0 mousewheel event
#
#     fix #1607
#
# ...........
#     prevent exception when initializing with no slides #1678 #1679
#
# ...........
#     Add note to README about how to disable scaling
#
# ...........
#     autoSlide duration with playbackRate
#
#     The autoSlide duration of media elements with data-autoplay now takes the playbackRate of said media element into account when setting the duration so that autoSlide and the media element stay in sync.
#
# ...........
#     Merge branch 'r400-linux' of https://github.com/jroper/reveal.js into dev
#
# ...........
#     Logitech R400 on Ubuntu blackout button support
#
#     On Ubuntu 16.04, the Logitech R400's blackout button gets mapped to 'v'
#     (keyCode 86). I don't know why this is, but since nothing else is
#     currently using 'v', this allows it to be supported out of the box.
#
# ...........
#     speaker layouts in server side notes plugin
#
# ...........
#     layout selector for speaker view; includes four options
#
# ...........
#     autoplay support for content inside of fragments
#
# ...........
#     none/fade/slide transitions use flat transform style, prevents blurred content #1002
#
# ...........
#     null computed style to avoid npe
#
# ...........
#     null check to avoid occasional npe
#
# ...........
#     ready flag on .reveal container
#
# ...........
#     Update JSDocs and fix typos
#
# ...........
#     update dependencies based on retire.js info #1473
#
# ...........
#     merge retire.js #1473
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     Merge pull request #1628 from davidjb/markdown-doc-fix
#
#     Detail markdown plugin attributes & defaults
#
# ...........
#     use first fragment's data-autoslide value when there is no current fragment
#
# ...........
#     remove unused dom reference
#
# ...........
#     revise simple.md so that slide 1.1 and 1.2 correctly break into separate slides
#
# ...........
#     Merge branch 'bug/markdownSetOptions' of https://github.com/snowyu/reveal.js into dev
#
# ...........
#     Detail markdown plugin attributes & defaults
#
#     Expands the details already given by highlighting the defaults for all attributes and clarifying what's required.
#
# ...........
#     move speaker notes into page container when printing pdf
#
# ...........
#     request fullscreen on documentElement instead of body (#1621 #1624)
#
# ...........
#     request fullscreen on documentElement instead of body (#1621 #1624)
#
# ...........
#     Revert "fix theme backgrounds in firefox fullscreen mode #1386"
#
#     This reverts commit b7e0d9b1c79a475249777d734a9675b1ba03a47a.
#
# ...........
#     fix theme backgrounds in firefox fullscreen mode #1386
#
# ...........
#     increase default font sizes, adjust config defaults for less margings and larger max scale #1605
#
# ...........
#     prevent repeated initialization #1616
#
# ...........
#     Merge branch 'Timothep-master' into dev
#
# ...........
#     Horizontal 2-1 View for the speaker notes instead of a vertical 1-2
#
# ...........
#     Added a description of the undocumented timer-reset feature
#
# ...........
#     Merge branch 'master' of https://github.com/dhyegofernando/reveal.js into dev
#
# ...........
#     add showHelp to api #1611
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     text alignment
#
# ...........
#     hdpi slides banner
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     slides banner
#
# ...........
#     include layout for notes outside of pdf exports
#
# ...........
#     support for 'separate-page' layout for notes in PDF exports #1518
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     Update README.md
#
#     more in-depth documentation of slide backgrounds #1542
#
# ...........
#     Merge pull request #1537 from vincentbernat/fix/dark-background-simple-theme
#
#     make theme "simple" use white titles on dark backgrounds
#
# ...........
#     code format
#
# ...........
#     Merge pull request #1585 from jasonkiss/feature/disabled-buttons
#
#     set/remove @disabled on navigation buttons
#
# ...........
#     ocd
#
# ...........
#     Merge pull request #1586 from jasonkiss/feature/accessible-speaker-notes
#
#     make speaker notes keyboard accessible
#
# ...........
#     moz selection color in theme template #1575
#
# ...........
#     Merge pull request #1575 from aniqah/firefox-selection-colour
#
#     Add selection colour for Mozilla Firefox
#
# ...........
#     merge readme conflict #1595
#
# ...........
#     Merge branch 'patch-1' of https://github.com/tiagorg/reveal.js into dev
#
# ...........
#     Removing duplicated "position" property at pdf.css
#
#     Found that by running css-lint on the code
#
# ...........
#     Add minor imporovements to the PDF export instructions
#
# ...........
#     make speaker notes keyboard accessible
#
#     Places div.speaker-notes in default kbd Tab order, and when focused,
#     prevent slide navigation with up/down arrows, allowing up/down arrow
#     keys to scroll div.speaker-notes.
#
# ...........
#     set/remove @disabled on navigation buttons
#
#     Keeps disabled buttons out of kbd tab order and indicates to assistive
#     tech like screen readers that button is disabled. Otherwise buttons
#     that aren’t enabled remain in kbd Tab order and screen readers announce
#     them as buttons, but they don’t work.
#
# ...........
#     add refused-to-display tips in link-preview-overlay
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     Merge pull request #1571 from adius/patch-1
#
#     Simplify full setup
#
# ...........
#     tweak formatting to match rest of slide
#
# ...........
#     Merge pull request #1572 from jesstelford/zoom-content-size
#
#     More natural zooming on block level elements
#
# ...........
#     fix pdf bg layering, simplify code
#
# ...........
#     make max pages per slide limit configurable
#
# ...........
#     prevent pages from overflowing when printing to pdf
#
# ...........
#     Add selection colour for Mozilla Firefox
#
#     Defines the highlight colour when selecting slide content using Mozilla
#     Firefox to match other browsers, instead of being the default colour.
#
# ...........
#     use scrollHeight instead of custom measurement
#
# ...........
#     More natural zooming on block level elements
#
#     Switching a `display: block` element to `display: inline-block` allows calculating the bounds based on the contents of the div rather than the entire container (which is often `width: 100%`).
#
#     This provides a much more natural zoom, especially for paragraphs and code examples.
#
# ...........
#     Simplify full setup
#
# ...........
#     3.3.0
#
# ...........
#     change introduction
#
# ...........
#     readme tweak for #1535
#
# ...........
#     Merge branch '1549' of https://github.com/RopoMen/reveal.js into dev
#
# ...........
#     overview now works with percentage based width/height #1247
#
# ...........
#     Merge branch 'dev' of github.com:hakimel/reveal.js into dev
#
# ...........
#     widen watch for html files, required for updates to demo.html
#
# ...........
#     merge conflict
#
# ...........
#     lazy load iframe in demo
#
# ...........
#     Merge branch 'update-headjs' of https://github.com/booi/reveal.js into dev
#
# ...........
#     Fix watching for markdown files
#
#     `./*.md` didn't work `*.md` does work
#
# ...........
#     Fixes #1549, now UA match is limiting out MS Edge and Chrome detection is improved. Also improved UserAgent access by storing it in to a local variable, it was accessed so many times in different places.
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     new multiplex server courtesy of now.sh (closes #1377)
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     remove test content
#
# ...........
#     support for standalone multiplexing
#
# ...........
#     Update README.md
#
# ...........
#     Update README.md
#
#     readme tweaks
#
# ...........
#     Merge pull request #1545 from ducin/master
#
#     Table of contents added in README.md
#
# ...........
#     generalize scroll offset prevention
#
# ...........
#     Table of contents added in README.md
#
# ...........
#     make theme "simple" use white titles on dark backgrounds
#
#     This is similar to what is done in the "white" theme.
#
# ...........
#     minor tweaks
#
# ...........
#     remove unintentionally added file
#
# ...........
#     new empty template at index.html, move old index to demo.html #1526
#
# ...........
#     add 'shuffle' config value and API method #1506 #1089
#
# ...........
#     update headjs to v1.0.3
#
# ...........
#     fix(PDF Export): Mark as important `width`, `height` and add `zoom` properties to fix CSS rules which were overrided by inline styles
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     slides link
#
# ...........
#     Merge pull request #1523 from demoneaux/readme-fix
#
#     Make PDF export section less OS X specific.
#
# ...........
#     server notes plugin no longer syncs overview mode #1446
#
# ...........
#     notes plugin no longer syncs overview mode #1446
#
# ...........
#     fix notes regex #1522 #1392
#
# ...........
#     Make PDF export section less OS X specific.
#
#     Closes #1073.
#
# ...........
#     Merge branch 'patch-1' of https://github.com/LaurentTreguier/reveal.js into dev
#
# ...........
#     Merge pull request #1522 from demoneaux/notes-fix
#
#     Fix query parameter issue in notes plugin.
#
# ...........
#     Merge pull request #1521 from demoneaux/unused-dependencies
#
#     Remove unused dependencies.
#
# ...........
#     Fix query parameter issue in notes plugin.
#
#     Closes #1392.
#
# ...........
#     Remove unused dependencies.
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     Merge pull request #1484 from omer727/patch-1
#
#     Fixing spelling typo and GitHub proper camelcase for brand name
#
# ...........
#     use css  to scale slides up in safari
#
# ...........
#     Change ".video" to ".reveal .video"
#
#     I don't know if this is supposed to be this way ?
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     readme tweak
#
# ...........
#     add barebones example to readme
#
# ...........
#     Fixing spelling typo and GitHub proper camelcase for brand name
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     note about showNotes in PDF exports
#
# ...........
#     merge #1220
#
# ...........
#     Merge branch 'jetzhliu-patch-1' of https://github.com/jetzhliu/reveal.js into dev
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     Merge pull request #1476 from prtksxna/patch-1
#
#     Remove rebase conflict in README.md
#
# ...........
#     Remove rebase conflict in README.md
#
# ...........
#     code format
#
# ...........
#     Merge branch 'patch-1' of https://github.com/danieltdt/reveal.js into dev
#
# ...........
#     fix broken iframe in backgrounds example
#
# ...........
#     tweak implementation of #1376
#
# ...........
#     same code format
#
# ...........
#     Merge branch 'patch-2' of https://github.com/teawithfruit/reveal.js into dev
#
# ...........
#     rebuild css
#
# ...........
#     merge conflict
#
# ...........
#     include speaker view keyboard shortcut when applicable #1466
#
# ...........
#     tweaked fragment examples
#
# ...........
#     center help overlay with flexbox
#
# ...........
#     added retire.js to build process
#     -allows security vulnerability check in used npm-dependencies and own scripts
#     -execute with ```grunt retire```
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     resolve conflict
#
# ...........
#     add new fragment styles to readme #1445
#
# ...........
#     Merge branch 'fragments' of https://github.com/kewitz/reveal.js into dev
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     tweak to pdf print isntructions
#
# ...........
#     Merge pull request #1450 from Quintasan/fix-printing-readme
#
#     Chromium users need to check Background graphics option when printing.
#
# ...........
#     expose version number through  #1451
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     merge conflict
#
# ...........
#     Merge pull request #1472 from vicapow/master
#
#     Add the grunt-cli as a dependency instead of assuming global grunt.
#
# ...........
#     Add the grunt-cli as a dependency instead of assuming global grunt.
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     Merge pull request #1459 from appleboy/patch-1
#
#     remove redundant spaces.
#
# ...........
#     Merge pull request #1467 from ismith/spelling_fix
#
#     Fix spelling error in print-pdf plugin
#
# ...........
#     :copyright: :copyright: :copyright: :copyright: :copyright: closes #1469
#
# ...........
#     Fix spelling error in print-pdf plugin
#
# ...........
#     updated to mustache 2.2.1
#
#     prevents XSS vulnerability (see https://github.com/janl/mustache.js/pull/388)
#
# ...........
#     ignoring IntelliJ IDEA files
#
# ...........
#     update to highlight.js 9.0.0
#
# ...........
#     remove redundant spaces.
#
# ...........
#     Merge branch 'muted-video' of github.com:oslego/reveal.js into muted-video
#
# ...........
#     add option to mute background videos (updated)
#
# ...........
#     Chromium users need to check Background graphics option when printing.
#
# ...........
#     Clean version of the new transitions.
#
# ...........
#     Added 4 fragment transitions effect.
#
# ...........
#     tweak
#
# ...........
#     2x playback controls for retina displays
#
# ...........
#     add autoSlideMethod to default config
#
# ...........
#     Merge branch 'dev' of github.com:hakimel/reveal.js into dev
#
# ...........
#     Merge pull request #1437 from der-michik/autoslide-direction
#
#     Add an option to auto-slide right only
#
# ...........
#     Fix build error
#
# ...........
#     Add a more flexible autoSlideMethod option
#
#     Auto-sliding will now use the method specified in the config if it is
#     a function or default to navigateNext.
#
# ...........
#     simplify condition #1434
#
# ...........
#     Merge pull request #1434 from mikemellor11/master
#
#     stops parallax failing if only the single horizontal slide and multiple vertical
#
# ...........
#     Add autoSlideRight option
#
#     When the autoSlideRight config option is active, the auto-sliding
#     will always navigate to the right and never down even if slides are
#     present there. This allows hidden "bonus slides" in presentations
#     which can be displayed as needed but won't show up automatically.
#
# ...........
#     update parallax background docs #1436
#
# ...........
#     check for 0 division, stops parallax failing if only the single horizontal slide and multiple vertical
#
# ...........
#     * [bug] the markdown plugin can not render highlight codes for marked.setOptions(highlight)
#
# ...........
#     * update marked.js version to 0.3.5
#
# ...........
#     3.2.0
#
# ...........
#     Merge pull request #1362 from GuGuss/patch-1
#
#     Update the theme README.md
#
# ...........
#     Merge pull request #1381 from lordsutch/master
#
#     Fix text being cut off in Chrome when printing.
#
# ...........
#     Merge pull request #1391 from rohithpr/notes-key-binding
#
#     Fixed #1379 - config keyboard now disables 's' key
#
# ...........
#     update highlight.js 8.6 -> 8.9.1 #1385
#
# ...........
#     server notes sync slide changes both ways, fixes #1425
#
# ...........
#     update highlight.js url
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     Merge pull request #1422 from gre/patch-1
#
#     Fixes #1225
#
# ...........
#     Fixes #1225
#
#     always enable highlight.js to fix markdown-only usage
#
# ...........
#     fixed loading
#
# ...........
#     more slide number tweaking
#
# ...........
#     tweak how speaker notes look in pdf exports
#
# ...........
#     style tweak
#
# ...........
#     hide slide number element when disabled
#
# ...........
#     remove out of sync comments from pdf css
#
# ...........
#     one more slide number format
#
# ...........
#     slide numbers work in pdf exports, update slide number style
#
# ...........
#     change slide number formats
#
# ...........
#     remove mention of deprecated transitions #1390
#
# ...........
#     fix mixed indentation
#
# ...........
#     Merge pull request #1399 from sloan-848/markdown-packaging
#
#     Add more support for external markdown.
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     Merge pull request #1400 from adunning/patch-1
#
#     Use en dash in title; <meta> is a void element.
#
# ...........
#     Merge pull request #1401 from adunning/patch-2
#
#     move up presentation size section
#
# ...........
#     remove remotes.io plugin, service no longer exists #1411
#
# ...........
#     syntax error in postmessage example
#
# ...........
#     format note content when creating slide
#
#     In html content, marked allow `Inline-Level Grammar` but not `Block-Level Grammar`, so when I write following:
#     ```
#     note:
#     * a
#     * b
#     * c
#     ```
#     it become:
#     ```html
#     <p><em> a
#     </em> b</p>
#     <ul>
#     <li>c</li>
#     </ul>
#     ```
#     unbelievable!
#
# ...........
#     Move up Presentation Size section.
#
#     This brings together all configuration options.
#
# ...........
#     Use en dash in title; <meta> is a void element.
#
# ...........
#     Add more support for external markdown.
#
#     The 'grunt watch' command now also watches for changes to external
#     markdown.
#     The 'grunt package' command now packages all external markdown files for
#     rapid deployment in static enviroments.
#
# ...........
#     Fixed #1379 - config keyboard now disables 's' key
#
# ...........
#     run autoprefixer
#
# ...........
#     fix black background in fullscreen mode #668 #1386
#
# ...........
#     rebuild css
#
# ...........
#     Fix slides being cut off in Chrome.
#
# ...........
#     Merge remote-tracking branch 'upstream/master'
#
# ...........
#     fix bower dependency #1375
#
# ...........
#     UPDATED - Improvement on spaces and indentation
#
# ...........
#     UPDATED - Improvement on spaces and indentation
#
# ...........
#     UPDATED - Improvement of code. Now none flag is used, but the readyState property  from video element
#
# ...........
#     Merge branch 'master' of https://github.com/alexbatista/reveal.js
#
#     Conflicts:
#             js/reveal.js
#
# ...........
#     Improvement of code. Now none flag is used, but the readyState property  from video element
#
# ...........
#     improvement on spaces and indentation
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     Merge pull request #1357 from davidbanham/master
#
#     Update location of multiplex demo server
#
# ...........
#     update travis node.js version
#
# ...........
#     Merge branch 'master' of https://github.com/davidbanham/reveal.js into dev
#
# ...........
#     Merge pull request #1281 from fghaas/dev
#
#     Update README to include socket.io 1.3.5 examples
#
# ...........
#     multiplexing work with socket.io 1.0+ #1281 #1276
#
# ...........
#     speaker notes work with socket.io 1.0 #1375
#
# ...........
#     Merge branch 'deps-update' of https://github.com/verdurin/reveal.js into dev
#
# ...........
#     bug fix - when the first section has a background-video, the vido do not execute. Now, it's work
#
# ...........
#     Update dependencies to fix installation
#
# ...........
#     Merge branch 'dev' of github.com:hakimel/reveal.js into dev
#
# ...........
#     notes defined in data-notes attributes retain preformatted whitespace
#
# ...........
#     Update the theme README.md
#
#     The `grunt css-themes` command now loops through all Sass files. There is no need to add the newly created file to the task list.
#
# ...........
#     add option to mute background videos
#
# ...........
#     Update location of multiplex demo server
#
# ...........
#     Add the data-noescape attribute and example
#
# ...........
#     document `data-prevent-swipe` #951
#
# ...........
#     prevent swipes on speaker notes
#
# ...........
#     modifications to #951
#
# ...........
#     Merge branch 'feature_prevent_swipe' of https://github.com/Calyhre/reveal.js into dev
#
# ...........
#     notes style changes
#
# ...........
#     bump up z-index of notes in pdf
#
# ...........
#     fix pdf print when showNotes is disabled
#
# ...........
#     reorder css
#
# ...........
#     print notes to pdf when  is enabled #304
#
# ...........
#     add getSlideNotes API method and tests
#
# ...........
#     dont show notes container when printing pdf
#
# ...........
#     document showNotes config value #304
#
# ...........
#     ability to share presentation with speaker notes #304
#
# ...........
#     Merge pull request #1309 from cben/patch-1
#
#     README example: load MathJax over https
#
# ...........
#     formatting
#
# ...........
#     Merge pull request #1310 from teawithfruit/patch-1
#
#     solves early access error with video element
#
# ...........
#     Merge branch 'master' of https://github.com/gruber76/reveal.js into dev
#
# ...........
#     fix initial visibility of strike fragments #737
#
# ...........
#     fix issue where 'none' transition did not apply to vertical stacks
#
# ...........
#     avoid duplicate var
#
# ...........
#     simplify
#
# ...........
#     fix object.keys call on non-object
#
# ...........
#     Update reveal.js
#
#     Removed toLowerCase call
#
# ...........
#     only use zoom to scale presentations up, fixes shifts in text layout
#
# ...........
#     solves early access error with video element
#
#     This will maybe solve the "InvalidStateError: An attempt was made to use an object that is not, or is no longer, usable" error in firefox.
#
# ...........
#     README example: load MathJax over https
#
#     tiny followup to #1103
#
# ...........
#     Merge pull request #1132 from kendaleiv/plain-images
#
#     Add plain class for plain images
#
# ...........
#     tweaks for #1200
#
# ...........
#     Merge branch 'master' of https://github.com/bfritscher/reveal.js into dev
#
# ...........
#     Merge pull request #1205 from gothma/mathjax-md
#
#     Allow tex parsing in <code> tags
#
# ...........
#     fix theme control arrow selectors #1257
#
# ...........
#     Merge branch 'controls-buttons-a11y' of https://github.com/marcysutton/reveal.js into dev
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     add bower json #1067
#
# ...........
#     Merge pull request #1287 from obilodeau/patch-1
#
#     README: suggest decktape as an alternative for PDF rendering
#
# ...........
#     remove harcoded syntax highlight colors #1290
#
# ...........
#     Gruntfile.js: watch tasks restructured
#
# ...........
#     update highlight.js theme
#
# ...........
#     README: suggest decktape as an alternative for PDF rendering
#
#     It works around the current PDF rendering bugs like #1261
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     Merge pull request #1250 from kfuglsang/highlightjs-86
#
#     Updated to Highlightjs 8.6 with all languages supported.
#
# ...........
#     Merge pull request #1260 from pierreozoux/master
#
#     Allows to specify PORT from env on multiplex plugin
#
# ...........
#     Merge pull request #1270 from jasonkarns/patch-1
#
#     enabling launching presentation with npm-start
#
# ...........
#     Merge pull request #1274 from jasonkarns/patch-3
#
#     broken <table> html in demo deck
#
# ...........
#     Merge pull request #1271 from jasonkarns/patch-2
#
#     `licenses` field is deprecated
#
# ...........
#     Update README to include socket.io 1.3.5 examples
#
#     The socket.io server at reveal.jit.su has been updated with socket.io
#     1.x, which means the examples referring to 0.9.x client libraries
#     no longer work. Update them with URLs for 1.3.5.
#
#     Fixes #1276.
#
# ...........
#     broken <table> html in demo deck
#
# ...........
#     `licenses` field is deprecated
#
#     the `licenses` field in package.json is deprecated. https://docs.npmjs.com/files/package.json#license
#
#     The `license` field is the recommended field and expects an SPDX expression.
#
# ...........
#     enabling launching presentation with npm-start
#
# ...........
#     Merge pull request #1268 from gneatgeek/migrate-leap-plugin
#
#     Removed leap motion plugin from main project
#
# ...........
#     Removed leap motion plugin from main project
#
# ...........
#     Allows to specify PORT from env on multiplex plugin
#
# ...........
#     accessibility: controls as buttons, not divs
#
# ...........
#     Merge branch 'davidbanham-master' into dev
#
# ...........
#     merge #959 with minor tweaks
#
# ...........
#     add base option for grunt serve task #1102
#
# ...........
#     Merge pull request #1202 from alexandreleroux/patch-1
#
#     PDF exporting also works with Chromium
#
# ...........
#     Merge pull request #1234 from lememora/master
#
#     Added missing comma on the configuration example
#
# ...........
#     Merge pull request #1201 from MA3STR0/master
#
#     Correct Readme.md -> Theming -> sky
#
# ...........
#     Merge pull request #1207 from danielePala/patch-1
#
#     Update index.html
#
# ...........
#     Updated to Highlightjs 8.6 with all languages supported.
#
# ...........
#     added missing comma on the configuration example
#
# ...........
#     3.1.0
#
# ...........
#     consider lazy loaded iframes when formatting src
#
# ...........
#     fix iframe unload in firefox
#
# ...........
#     iframe postmesssage api works with lazy loaded iframes
#
# ...........
#     sync starts playing new embedded content
#
# ...........
#     type check to ensure we don't call media api before media has loaded
#
# ...........
#     fix lazy load selector error
#
# ...........
#     tweak to iframe lazy load test
#
# ...........
#     typo
#
# ...........
#     lazy-load iframes only for current slide, unload when hidden
#
# ...........
#     lazy loading fallback also considers iframes
#
# ...........
#     add test presentation for per-slide transitions, compile css #1106
#
# ...........
#     Merge branch 'master' of https://github.com/jammon/reveal.js into dev
#
# ...........
#     Fixed last header having a border-bottom
#
#     `<tbody/>` is automatically inserted, so we can guarantee that this affects all ths and tds in the last row of the table *body* and the head is left untouched
#
# ...........
#     Update index.html
#
#     Added https prefix to slideshare iframe link, without this I got a 'not found' error when opening the demo locally.
#
# ...........
#     Allow tex parsing in <code> tags
#
#     Just using $ as delimiter in markdown document fails since the markdown
#     parser unknown to the dollar syntax will try to interpret underscores.
#     Putting the $ delimented formula in backticks will cause the markdown
#     parser to put the tex-code with the $ delimiters into a code block.
#     The texcode will then be unchanged. This patch allows for mathJax to
#     interpret and automagically display the tex-formulas.
#
# ...........
#     PDF exporting also works with Chromium
#
#     For those who can't install Google Chrome (e.g. work network policies) but can use Chromium, Chromium does work for creating the pdf. I updated the readme accordingly. Thanks!
#
# ...........
#     change iframe example
#
# ...........
#     Correct Readme.md#theming
#
#     Theming/sky.css has dark gray text on light blue background; not white text
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     Merge pull request #1162 from bobylito/master
#
#     Make npm dependency usable by Browserify through npm
#
# ...........
#     fix markdown test
#
# ...........
#     remove 'roll-in' fragment style due to Chrome crash #1150
#
# ...........
#     update cssmin to 0.12.2 #1179
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     Merge pull request #1180 from kayakr/patch-1
#
#     typo
#
# ...........
#     Merge branch 'query-params' of https://github.com/FND/reveal.js into dev
#
# ...........
#     Merge pull request #1193 from danielquinn/Firefox-friendly
#
#     Added support for standard transforms
#
# ...........
#     handle the </script> end bug inside code markdown
#
#     by changing the tag before html is parsed and restoring it before markdown parsing
#
# ...........
#     Added support for standard transforms
#
#     -webkit- stuff only works on webkit browsers.  I'm pretty sure that using the standard `transform:` here works in most modern browsers.
#
# ...........
#     support query parameters within notes plugin
#
# ...........
#     Fix typo /s/configure/configured
#
# ...........
#     fix for #1150?
#
# ...........
#     reset fragment transforms using 'none'
#
# ...........
#     fix #1170
#
# ...........
#     remove variable definitions #1158
#
# ...........
#     Merge branch 'dev' of https://github.com/bchretien/reveal.js into dev
#
# ...........
#     Merge branch 'patch-1' of https://github.com/drzax/reveal.js into dev
#
# ...........
#     Merge pull request #1166 from callahad/update-marked
#
#     update marked to 0.3.3
#
# ...........
#     Merge branch 'patch-1' of https://github.com/borrown/reveal.js into dev
#
# ...........
#     alt+zoom only works on slide content #1151
#
# ...........
#     Update reveal.js
#
# ...........
#     Attribute values should be quoted
#
# ...........
#     Bumped Marked to v0.3.3
#
#     Compressed with `uglifyjs lib/marked.js --comments="/Copyright/" --mangle --compress`
#
#     Used Marked v0.3.3 as of chjj/marked@2b5802f258c5e23e48366f2377fbb4c807f47658
#
# ...........
#     updated md slide separator regex #929
#
#     see https://github.com/hakimel/reveal.js/issues/929#issuecomment-80738837
#
# ...........
#     Make npm dependency usable by Browserify through NPM
#
#     Right now the package is not recognized as usable library by Browserify.
#     Adding the main attribute in the package.json solves that, and now gives
#     others the possibility to use reveal as a library in more complex
#     systems.
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     note about plugins
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into dev
#
# ...........
#     link to plugins
#
# ...........
#     Fix slide numbering for custom slide number formatting.
#
#     Numbering was off when dealing with fragments.
#
# ...........
#     Add support for custom notes.html file
#
#     It would be nice if we could define a custom notes.html file.
#
#     Actually, I'm used to compile my js files before releasing my app and, using selectors like `script[src$="notes.js"]`, doesn't work :(
#
#     So, what do you think about it?
#
# ...........
#     remove selection color from core css
#
# ...........
#     add blood theme to demo slides #928
#
# ...........
#     tweaks to blood theme
#
# ...........
#     code format
#
# ...........
#     Merge branch 'patch-1' of https://github.com/jhofker/reveal.js into dev
#
# ...........
#     fix mixed spaces/tabs
#
# ...........
#     Markdown table column alignment #1050
#
#     The alignment information were already in the generated html.
#     The css was the only thing missing, so I added it.
#
# ...........
#     Merge pull request #1113 from brndnb/patch-1
#
#     grammar
#
# ...........
#     code format
#
# ...........
#     Merge pull request #1138 from denehyg/background-video-loop
#
#     background video loop
#
# ...........
#     merge conflict
#
# ...........
#     fix mixed indentation
#
# ...........
#     fix progress bar clicks in rtl mode #1131
#
# ...........
#     ensure postmessage data is a string #1143
#
# ...........
#     merge options for parallax step size #733
#
# ...........
#     Check before calling blur on activeElement.
#
#     It's possible for slides to be in a situation where the last clicked thing was an SVG before the tab/window loses focus. When returning, `.blur()` is called on the previously-active element, but can result in an exception.
#
#     This protects against that and will only call `.blur()` when `document.activeElement` supports it.
#
# ...........
#     Added option to loop background videos
#
# ...........
#     Add plain class for plain images
#
# ...........
#     fix looped view distance calculation
#
# ...........
#     prevent iframes from offsetting presentation
#
# ...........
#     only preload last slides if presentation is looped
#
# ...........
#     gifs now restart when their slide container is shown
#
# ...........
#     only transition slides container in overview mode
#
# ...........
#     Merge pull request #1119 from hakimel/feature/new-overview
#
#     Refactored overview mode
#
# ...........
#     fix error when exiting overview
#
# ...........
#     comments
#
# ...........
#     cleaner approach to applying transforms to slides container
#
# ...........
#     dynamic file mapping to avoid themes hardcoded in gruntfile
#
# ...........
#     theme readme update
#
# ...........
#     ensure overview indices are up to date if a slide moves
#
# ...........
#     cross browser adjustments for overview mode
#
# ...........
#     further overview refactoring
#
# ...........
#     refactoring and optimization of overview mode
#
# ...........
#     Merge pull request #1115 from raboof/patch-1
#
#     themes grunt task was renamed
#
# ...........
#     Grunt target was renamed
#
# ...........
#     Fix small typo
#
# ...........
#     add global flag back in for whitespace removal, without it most of the content in example.html does not work #682
#
# ...........
#     default to https mathjax #1103
#
# ...........
#     fix for #1088 when presentation is not scaled
#
# ...........
#     Adding one-sided transitions
#
#     Now the transition isn’t any more „per slide“ but „per movement of a
#     slide“. So the slide can disappear in another way than it appeared.
#
# ...........
#     Mixins for readability of transitions added
#
#     To honor the DRY principle repeating patterns have been factored out.
#     In addition there was an anchor missing in README.md.
#
# ...........
#     apply z position to slide container, rather than individual slides
#
# ...........
#     firefox support for #1088
#
# ...........
#     no longer set o-transforms
#
# ...........
#     background images now work in overview mode #1088
#
# ...........
#     support for custom slide number formatting #965
#
# ...........
#     use getElementByID when looking up linked slides #1086
#
# ...........
#     only read textContent for aria callout #1100
#
# ...........
#     documentation for getState/setState
#
# ...........
#     documentation for postMessage API
#
# ...........
#     Merge pull request #1093 from hakimel/dev
#
#     3.0.0
#
# ...........
#     content tweak
#
# ...........
#     content tweaks
#
# ...........
#     reorganize fonts, include source sans pro for offline use
#
# ...........
#     always play background video from the start #1049
#
# ...........
#     merge master into dev
#
# ...........
#     revise contribution guidelines, graduate 3.0 from dev
#
# ...........
#     dont subset league glyphs #989
#
# ...........
#     new slideshare pdf example
#
# ...........
#     new font & type settings for default theme
#
# ...........
#     reveal container size determines progress bar width
#
# ...........
#     avoid repetition
#
# ...........
#     (c) 2015
#
# ...........
#     remove deprecated data-state background colors
#
# ...........
#     kill unintended transition into overview mode
#
# ...........
#     change transition defaults
#
# ...........
#     tweak comments
#
# ...........
#     readme tweaks
#
# ...........
#     new pdf export example
#
# ...........
#     white theme inverts text color against dark bg
#
# ...........
#     bad theme name
#
# ...........
#     remove theme config option #1061
#
# ...........
#     add white theme, reverse of default theme #1018
#
# ...........
#     default content update; remove image slide, add two new slides
#
# ...........
#     include background video example in default presentation
#
# ...........
#     zoom plugin now works for scaled presentations
#
# ...........
#     rename previous default theme to league
#
# ...........
#     first revision of new default theme #1018
#
# ...........
#     dont force links to be underlined in pdf
#
# ...........
#     Merge remote-tracking branch 'upstream/master'
#
# ...........
#     reorder scale condition; if calculated scale is exactly 1 don't apply any scale styles
#
# ...........
#     Merge pull request #1033 from PeterDaveHello/patch-1
#
#     ci status indicator is svg instead of png
#
# ...........
#     add missing condition for recalculating scale
#
# ...........
#     ignore calculating scale if only possible outcome is 1
#
# ...........
#     update order of default slides
#
# ...........
#     default to slide transitions
#
# ...........
#     update background color/image example slides
#
# ...........
#     typo
#
# ...........
#     theme updates, normalized spacing between block-level elements
#
# ...........
#     simplify default initialization options
#
# ...........
#     Merge pull request #1037 from Suva/dev
#
#     Do not add video backgrounds to speaker notes.
#
# ...........
#     Do not add video backgrounds to speaker notes.
#
# ...........
#     Use svg instead of png to get better image quality
#
# ...........
#     add video and iframe backgrounds to readme
#
# ...........
#     update slide bg example presentation to include iframes and videos #1029
#
# ...........
#     Merge branch 'feature/background-iframe' of https://github.com/lutangar/reveal.js into dev
#
# ...........
#     fix navigatePrev in rtl mode #1030
#
# ...........
#     remove styles from #1030, simplify navigatePrev
#
# ...........
#     update grunt connect for more hostname flexibility #981
#
# ...........
#     correct defaults for min-height, thanks @sebastianz #985
#
# ...........
#     continue auto-sliding through fragments on last slide #974
#
# ...........
#     better handling of overflowing speaker notes #1017
#
# ...........
#     update grunt-qunit
#
# ...........
#     use nesting for fragment styles
#
# ...........
#     Fix RTL Navigation with space bar
#
# ...........
#     add support for iframe backgrounds
#
# ...........
#     use node.js 0.10
#
# ...........
#     reduce grunt task overhead
#
# ...........
#     reveal.css is now scss, merge autoprexier #1007
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js
#
# ...........
#     add contribution guidelines from dev
#
# ...........
#     compile themes
#
# ...........
#     merge #975 into dev
#
# ...........
#     prevent auto-sliding in notes frames #1004
#
# ...........
#     minor copy tweak
#
# ...........
#     remove classList condition from unrelated dependencies
#
# ...........
#     multiple updates to default presentation content
#
# ...........
#     remove css 3d warning
#
# ...........
#     style tweaks for all themes; larger line heights, no default adjustmetn to letter-spacing
#
# ...........
#     add new black theme
#
# ...........
#     dont open notes when S is pressed inside of notes window #991
#
# ...........
#     merged dev branch
#
# ...........
#     re-created unprefixed version of reveal.css automatically using autoprefixer, to facilitate merging of changes to it
#
# ...........
#     update highlight.js to 8.2
#
# ...........
#     cleanup classes when backgrounds are synced
#
# ...........
#     rgba color parsing support, ignore brightness of transparent colors
#
# ...........
#     has-dark-background
#
# ...........
#     bubble has-light-background to .reveal container
#
# ...........
#     is-light-background -> has-light-background, doesn't apply to background itself
#
# ...........
#     update slide backgrounds example
#
# ...........
#     use computed style when calculating bg birghtness
#
# ...........
#     add is-background-light class to slides/backgrounds that are > 128 brightness
#
# ...........
#     util methods for calculating color brightness
#
# ...........
#     better test for fragment indices
#
# ...........
#     fix current fragment index check when multiple fragments have same index
#
# ...........
#     -
#
# ...........
#     added newly generated reveal.min.css
#
# ...........
#     removed all vendor-prefixes from reveal.css
#
# ...........
#     fix previewLinks target
#
# ...........
#     the paused mode can now be disabled via the 'pause' config option
#
# ...........
#     only load highlight.js if there's a 'pre code' block on page
#
# ...........
#     update highlight.js to 8.1
#
# ...........
#     Update package.json
#
# ...........
#     removed ruby dependency.
#
# ...........
#     listen for touch + click on all devices except android
#
# ...........
#     fix double-navigation on touch for some android systems
#
# ...........
#     Listen to custom mapped togglePause keys
#
#     This resolves issue #941
#
# ...........
#     fix npe
#
# ...........
#     prevent additional inaccurate showSlide calls
#
# ...........
#     prevent incorrect showSlide calls at startup
#
# ...........
#     overview slide size matches defaults
#
# ...........
#     Merge remote-tracking branch 'upstream/master'
#
# ...........
#     more specific targeting for pdf printing hack
#
# ...........
#     Fix tests
#
# ...........
#     Add ability to prevent swipe for specific elements
#
# ...........
#     only allow text in aria status div
#
# ...........
#     documentation for help flag
#
# ...........
#     config option for disabling the help overlay
#
# ...........
#     fix append to existing embed query
#
# ...........
#     vimeo support for autoplay/pause
#
# ...........
#     rewrite youtube iframe embeds to force ?enablejsapi=1 (fixes #856)
#
# ...........
#     shift a few additional styles from core to theme
#
# ...........
#     move large chunk of content styles from core css to theme css
#
# ...........
#     toggle instead of always showing the help overlay when ? is pressed
#
# ...........
#     more flexible keyboard shortcut table styles
#
# ...........
#     update link to Slides
#
# ...........
#     adjust list of displayed key shortcuts #943
#
# ...........
#     merge and tweak key shortcuts overlay #943
#
# ...........
#     Merge branch 'keyboard_shortcuts_overlay' of https://github.com/navateja/reveal.js into dev
#
# ...........
#     update to node 0.10
#
# ...........
#     ci fix attempt 2
#
# ...........
#     attempt to fix travis ci
#
# ...........
#     don't trim aria status
#
# ...........
#     merge and tweak screen reader support #854
#
# ...........
#     Merge remote-tracking branch 'upstream/dev' into keyboard_shortcuts_overlay
#
# ...........
#     creates a new branch for the feature
#
# ...........
#     Shows keyboard shorcuts overlay on pressing question mark
#
# ...........
#     typo #938
#
# ...........
#     write current hash when history is toggled on #934
#
# ...........
#     fix search & replace error
#
# ...........
#     adjust check for focused text inputs
#
# ...........
#     move paragraph styles to theme
#
# ...........
#     limit scope of all slide selectors, avoids multiple .reveal classes on one page causing errors
#
# ...........
#     additional monospace options for phantomjs
#
# ...........
#     only use zoom to scale in chrome
#
# ...........
#     dont specify hyphens auto, behavior/rendering varies between browsers
#
# ...........
#     hide slide numbers while printing to pdf #885
#
# ...........
#     fix data-autoplay on first slide
#
# ...........
#     validate named links according to html id spec #914
#
# ...........
#     zoom viewport is centered on target element #900
#
# ...........
#     relax keyboard blocking condition #899
#
# ...........
#     add minimal-ui to viewport for ios fullscreen
#
# ...........
#     Merge branch 'fix-isFirstSlide' of https://github.com/fabianorosas/reveal.js into dev
#
# ...........
#     fix bug in retrieval or background images while in pdf mode
#
# ...........
#     no need to override font sizes after updates to pdf printing
#
# ...........
#     == --> ===
#
# ...........
#     fixed a problem in the function isFirstSlide
#
#     when visiting a vertical slide and then going back to the first slide, the function would return false.
#     made it more fail proof by checking the indices directly.
#
# ...........
#     kill-yank mistake
#
# ...........
#     Broaden the coverage of isFirstSlide test
#
#     If we:
#     - visit a vertical slide
#
#     and then:
#     - go to the first slide
#
#     the function will return **false**.
#
#     Added a test to isLastSlide too just to be sure.
#
# ...........
#     Small typo
#
# ...........
#     fix edge case in singleton node creation
#
# ...........
#     createSingletonNode now ensures found nodes are in the correct container
#
# ...........
#     sync server-side speaker notes after notes window opens
#
# ...........
#     ensure default can be prevented
#
# ...........
#     update server side notes to match client side plugin
#
# ...........
#     limit size of media elements when printing to pdf
#
# ...........
#     reduce max-height of images in pdfs
#
# ...........
#     clicking on notes timer now resets it #779
#
# ...........
#     wait for document to load before triggering pdf layout
#
# ...........
#     ensure pdf pages are never zero-height
#
# ...........
# ...
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js
#
# ...........
#     Merge pull request #97 from davidbanham/master
#
#     Include speaker notes plugin after reveal.js
#
# ...........
#     Include speaker notes plugin after reveal.js
#
#     Must be called after reveal.js otherwise the Reveal object is undefined
#     and the plugin can't add it's event listener.
#
# ...........
#     correct copy year
#
# ...........
#     disable 3d links in ie, reorder script loading in index for readability (closes #95)
#
# ...........
#     fix disappearing 3d hover in chrome
#
# ...........
#     ie8 support (closes #96)
#
# ...........
#     add eot font for ie
#
# ...........
#     Oops, made the page a little too responsive
#
#     if you resized the window or visited the page on a small screen everything would be amiss
#
#     now, I've fixed that with a one-liner
#
# ...........
#     Made the slideshow responsive
#
#     Woohoo! The slideshow now responds to resizing of the browser nicely!
#
# ...........
#     added example
#
# ...........
#     update markdown code example to correctly reflect line breaks
#
# ...........
#     modified data-markdown to support markdown indented with tabs
#
# ...........
#     self-execute data-markdown
#
# ...........
#     markdown instructions
#
# ...........
#     added slide announcing markdown support (#15)
#
# ...........
#     support for data-markdown (#15)
#
# ...........
#     move theme styles at bottom of main.css, change background of page transition to be transparent
#
# ...........
#     fixes bug where the .present class remained on previous slide (closes #88)
#
# ...........
#     adds new api methods (getCurrentSlide, getPreviousSlide, getIndices) closes #73
#
# ...........
#     added example from @pamelafox
#
# ...........
#     readme code marking
#
# ...........
#     1.4 is now stable, increment master to 1.5
#
# ...........
#     clean up initialization, conditionally load classList polyfill prior to reveal.js
#
# ...........
#     'keyboard' config option for disabling keyboard navigation (closes #84)
#
# ...........
#     null check progress DOM element even if it's configured to be on
#
# ...........
#     sub/superscript styles (closes #82)
#
# ...........
#     readme update
#
# ...........
#     Merge pull request #83 from basecode/patch-slidechange
#
#     slidechange doesn't get fired on "hashchange" events
#
# ...........
#     Remove assignment to `indexv` and `indexh` to trigger 'onslidechange' at startup and onhashchange.
#
# ...........
#     Merge pull request #80 from ob1/patch-2
#
#     Another instance of: id="reveal" => class="reveal"
#
# ...........
#     Another instance of: id="reveal" => class="reveal"
#
# ...........
#     remove background from default anchor hover style
#
# ...........
#     added autoSlide option (#59), clear out list of options in index.html's initialize call
#
# ...........
#     Merge pull request #79 from ob1/patch-1
#
#     Update README to reflect "reveal" container selector change
#
# ...........
#     Update README to reflect "Main #reveal container is now selected via a class instead of ID"
#
# ...........
#     add beige theme, move theme class from .reveal to document element, use log instead of alert to demonstrate custom events
#
# ...........
#     changenote re code sample font size
#
# ...........
#     added new example to readme
#
# ...........
#     larger font for code samples (closes #60)
#
# ...........
#     slidenotes becomes speakernotes to match wording in readme
#
# ...........
#     folder structure description in readme
#
# ...........
#     fix incorrect directory reference
#
# ...........
#     adjustments to initial node messages #57
#
# ...........
#     separate loading of classList.js as its not tied to execution of highlight.js
#
# ...........
#     refactored folder structure, added /plugins which is initially only used by #57
#
# ...........
#     use head.js to script load everything, fixes bug with inclusion of notes server js #57
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js into notes
#
# ...........
#     Merge pull request #75 from tansengming/css_charset
#
#     adds charset declaration in main.css
#
# ...........
#     adds charset declaration in main.css
#
# ...........
#     small tweaks to notes page style
#
# ...........
#     small tweaks to notes page style
#
# ...........
#     simplify query match
#
# ...........
#     remove unused copy of notes client
#
# ...........
#     readme updates
#
# ...........
#     conditional loading of socket.io and the notes client js based on window host
#
# ...........
#     update instructions printed on server start
#
# ...........
#     convert spaces to tabs to match project style
#
# ...........
#     move notes client code into lib
#
# ...........
#     tweaks to slidenotes
#
# ...........
#     adjust whitespace of notes code to match rest of project
#
# ...........
#     include underscore as a dependency for npm
#
# ...........
#     /lib restructuring
#
# ...........
#     restructured /lib, moved /assets/fonts to /lib/fonts
#
# ...........
#     Merge branch 'presenter_notes_server' of https://github.com/rmurphey/reveal.js into notes
#
# ...........
#     Merge pull request #72 from rhudea/fix-fragmenthidden
#
#     Send the correct element for fragmenthidden events
#
# ...........
#     Send the correct element for fragmenthidden events
#
# ...........
#     Merge pull request #65 from bleathem/patch-2
#
#     Specify position for .reveal.linear sections. fixes #64
#
# ...........
#     enable controls by default
#
# ...........
#     connect to whatever server we're on
#
# ...........
#     fix socket id
#
# ...........
#     fix path to socket.io
#
# ...........
#     have notes page only listen to one socket
#
# ...........
#     add mustache dependency
#
# ...........
#     broadcast socket id as part of slidedata
#
# ...........
#     use current host/port
#
# ...........
#     Specify position for .reveal.linear sections. fixes #64
#
# ...........
#     Merge pull request #63 from bleathem/patch-1
#
#     Changed #reveal to .reveal in print.css
#
# ...........
#     Changed #reveal to .reveal in print.css
#
# ...........
#     Merge pull request #58 from danielmitd/controls
#
#     fix JS error when controls are removed from HTML
#
# ...........
#     add default table styles (closes #62)
#
# ...........
#     Merge pull request #61 from rmurphey/navigatePrev_navigateNext
#
#     Expose navigatePrev, navigateNext
#
# ...........
#     update readme
#
# ...........
#     expose navigatePrev, navigateNext
#
# ...........
#     adapt coding style
#
# ...........
#     use config
#
# ...........
#     controls are not necessary
#
#     no need to include the controls in html
#
# ...........
#     removing errant author info
#
# ...........
#     taking a stab at a presenter notes server
#
# ...........
#     syntax highlighting in readme examples
#
# ...........
#     include references to previous/current sldie DOM elements in slidechange event
#
# ...........
#     prevent duplicate slidechange from firing after hash change (closes #54)
#
# ...........
#     added example
#
# ...........
#     Merge pull request #53 from isellsoap/master
#
#     simplified handling of nested lists
#
# ...........
#     simplified handling of nested lists
#
# ...........
#     change add .reveal class in index (closes #51)
#
# ...........
#     added new example (closes #50)
#
# ...........
#     readme update
#
# ...........
#     api methods for adding/removing all event listeners (#48)
#
# ...........
#     changed selection of main container from #reveal to .reveal (closes #46)
#
# ...........
#     credit in readme
#
# ...........
#     version 1.3 is stable, upgrade to 1.4
#
# ...........
#     comments, tweaks and a new slide highlighting mobile support
#
# ...........
#     support for swipe and pinch gestures #48
#
# ...........
#     minified!
#
# ...........
#     added some public access methods
#
#     Added overview toggle to allow for button-based overview toggling
#
#     Added add/removeEvents methods to allow for adding& removing event
#     listeners that may interfere with other libs.
#
# ...........
#     dispatch events when visible fragment changes ('fragmentshown', 'fragmenthidden') closes #44
#
# ...........
#     support more variations of nested lists (closes #47)
#
# ...........
#     added new examples, linked all contributor names to github pages
#
# ...........
#     updated min.js to match
#
# ...........
#     fixed bug in swipe gesture interacting with links.
#
# ...........
#     added left, right, up, down gestures to change slides. moved window edge slide triggers to a touchend event to prevent interference of gestures
#
# ...........
#     space and return keys can be used to exit the overview mode
#
# ...........
#     adjust where page background is applied
#
# ...........
#     added example
#
# ...........
#     adjust end key nav to last slide
#
# ...........
#     Merge pull request #41 from frockenstein/master
#
#     home and end key use
#
# ...........
#     use home and end key
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js
#
# ...........
#     more explicit list styles (closes #38)
#
# ...........
#     added example
#
# ...........
#     fix controls z-index in ff
#
# ...........
#     hide address bar in mobile browsers, add apple web app meta
#
# ...........
#     show all fragments during print
#
# ...........
#     print styles (closes #19)
#
# ...........
#     'slidechanged' event, added Reveal.addEventListener/Reveal.removeEventListener api methods
#
# ...........
#     ie9 fixes, including new classList polyfill
#
# ...........
#     minor style or wording tweaks
#
# ...........
#     Merge pull request #36 from commadelimited/master
#
#     Adding example for custom event bindings.
#
# ...........
#     Adding example for custom event binding.
#
# ...........
#     new example
#
# ...........
#     added support for looped presentations
#
# ...........
#     merge keyboard shortcut changes
#
# ...........
#     ignore metaKey modifier too
#
# ...........
#     p for previous, n for next
#
# ...........
#     Add new key mappings for navigation.
#
#     hjkl for directions.
#     space to move to next slide.
#     esc for 3D overview (instead of space)
#
# ...........
#     (c) year
#
# ...........
#     significantly smaller js file header, added minified js
#
# ...........
#     Merge pull request #32 from philipbjorge/master
#
#     Overview mode shows hidden fragments. (closes #30)
#
# ...........
#     added new example
#
# ...........
#     Overview now shows hidden fragments.
#
# ...........
#     new example
#
# ...........
#     added new example
#
# ...........
#     more detailed usage instructions including docs on new state feature
#
# ...........
#     upgrade to v 1.3
#
# ...........
#     better example of state usage
#
# ...........
#     new example
#
# ...........
#     change back state event scope, document level makes more sense as that's where the state class is applied
#
# ...........
#     adjustments to custom state events
#
# ...........
#     Firing custom event based on data-state name. This allows developers to trigger custom javascript code on a per slide basis.
#
# ...........
#     now capturing data-state on slides and lifting it to document element classList when slide is open
#
# ...........
#     merge prev/next navigation pull request with modifications
#
# ...........
#     Implemented correct Previous and Next navigation for both mouse scroll and wireless presenter.
#
# ...........
#     classList polyfill included for ie9
#
# ...........
#     delay hash changes to avoid transition lag in chrome and enable history by default (closes #22)
#
# ...........
#     don't overwrite existing classes on slides (closes #23)
#
# ...........
#     Merge pull request #21 from archive/master
#
#     Added support for wireless presenter
#
# ...........
#     added support for wireless presenter
#
# ...........
#     Merge pull request #20 from Fil/master
#
#     reveal.js was failing when the hash was of an unexpected format
#
# ...........
#     Do not fail on other kinds of hashes
#
# ...........
#     new example
#
# ...........
#     new examples
#
# ...........
#     default hash updates to false, see http://code.google.com/p/chromium/issues/detail?id=62820
#
# ...........
#     fix reference to old 'hasClass' method
#
# ...........
#     new example
#
# ...........
#     tweaked mouse wheel navigation
#
# ...........
#     Merge pull request #13 from naugtur/master
#
#     Mouse scroll handling
#
# ...........
#     removed history comment in js
#
# ...........
#     added usage instructions to readme
#
# ...........
#     rolled back to classList, promoting poyfill in readme
#
# ...........
#     broaden selector for img:hover (fixes #11)
#
# ...........
#     don't apply linkify effect to anchors containing images
#
# ...........
#     add new example
#
# ...........
#     Added support for smart scrolling through slides. Scrolling events are throttled to prevent going too far
#
# ...........
#     removed dependency on classList (#9)
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js
#
# ...........
#     moved inline base64 images to aws
#
# ...........
#     scrolling fallback mode for IE < 9
#
# ...........
#     slightly reduced size of progress bar
#
# ...........
#     prevent default on space press
#
# ...........
#     Added example
#
# ...........
#     history on by default
#
# ...........
#     browser history updates can now be disabled via config
#
# ...........
#     Merge branch 'master' of github.com:hakimel/reveal.js
#
# ...........
#     updated copy in slides, added one that explains transitions
#
# ...........
#     updated readme
#
# ...........
#     adjusted background color of page/box themes
#
# ...........
#     major, non backwards compatible, restructuring of DOM tree
#
# ...........
#     changed id of 'main' container to 'reveal'
#
# ...........
#     packed v1.1, upgraded to 1.2
#
# ...........
#     readme history update
#
# ...........
#     added new transitions (box/page) and a ui theme (neon)
#
# ...........
#     fix padding and duplicate background on vertical slides in overview
#
# ...........
#     fix clicks on vertical slides in overview
#
# ...........
#     skip fragments when in overview
#
# ...........
#     added experimental overview mode (press SPACE)
#
# ...........
#     fallback on 2d transform transitions via feature detect
#
# ...........
#     slides three or more steps away from current are now hidden
#
# ...........
#     only apply background gradient to <html>
#
# ...........
#     added '-ms' prefixed properties
#
# ...........
#     progress bar is now a div and uses the same transition + easing as slides (fixes #6)
#
# ...........
#     Added examples
#
# ...........
#     updated readme
#
# ...........
#     hide progress by default
#
# ...........
#     added optional presentation progress bar
#
# ...........
#     replaced google logo with a unicorn
#
# ...........
#     comments & typo correction
#
# ...........
#     slide with code is now editable, escaped unicode arrows
#
# ...........
#     Merge pull request #5 from matthewlein/master
#
#     contenteditable and arrow keys
#
# ...........
#     for contenteditable elements, don't let arrow keys work
#
# ...........
#     fragments now work in vertical slides (fixes #4)
#
# ...........
#     disabled overflow on body (fixes #2)
#
# ...........
#     fix broken link
#
# ...........
#     fix vertical slide transition and hit areas of rolling links
#
# ...........
#     cleanup & comments
#
# ...........
#     readme update
#
# ...........
#     Updated readme
#
# ...........
#     renamed to reveal.js, many new features, and upgraded to v1.0
#
# ...........
#     added version comment
#
# ...........
#     Merge branch 'master' of github.com:hakimel/CSS-3D-Slideshow
#
# ...........
#     fixed issue with links on touch devices (tap wasn't working)
#
# ...........
#     adjusted shadow on headers
#
# ...........
#     readme update
#
# ...........
#     Merge pull request #1 from altryne/master
#
#     Added fix for firefox ( and other browsers without 3d support ) to be able to click links
#
# ...........
#     firefox links now clikable
#
# ...........
#     updated readme
#
# ...........
#     removed tracking code
#
# ...........
#     added font license
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-f21be76c5f87> in <module>()
#      39             files = []
#      40             while 1:
# ---> 41                 line = lines[i+j]
#      42                 if line in ['\n', '\r\n']:
#      43                     break
#
# IndexError: list index out of range

# %%
df.head()

# %%
len(df)
# Out:
# 15740

# %%
df['changes'] = pd.Series(df['files'].str[-1], index=df.index)

# %%
df['n_files'] = pd.Series(df['changes'].str.split().str[0] , index=df.index)
df['insertions'] = pd.Series(df['changes'].str.split(",").str[1].str.split().str[0] , index=df.index)
df['deletions'] = pd.Series(df['changes'].str.split(",").str[2].str.split().str[0] , index=df.index)

# %%
del df['changes']
df.head()
# Out:
#                                                            author  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf   bardi@bardiharborow.com
# 63926717cbc1420218796396fac06c1005447bf            quy@fluxbb.org
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5            quy@fluxbb.org
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0       markdotto@gmail.com
# cb252570a0fb2507c7169427569f50a0a1cb031  marcusmolchany@gmail.com
#
#                                                              date  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf  Mon Jan 23 10:38:34 2017
# 63926717cbc1420218796396fac06c1005447bf  Mon Jan 23 05:37:14 2017
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5  Sun Jan 22 20:17:17 2017
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0  Sun Jan 22 03:02:23 2017
# cb252570a0fb2507c7169427569f50a0a1cb031  Sun Jan 22 03:01:13 2017
#
#                                                                        activity  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf            Move htmllint to npm script.
# 63926717cbc1420218796396fac06c1005447bf             Change to markdown (#21815)
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5  Change header to use markdown (#21809)
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0          Merge branch 'v4-dev' of https
# cb252570a0fb2507c7169427569f50a0a1cb031        Update grid layout docs (#21806)
#
#                                                                                       text  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf                     Move htmllint to npm script.\n
# 63926717cbc1420218796396fac06c1005447bf                      Change to markdown (#21815)\n
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5      Change header to use markdown (#21809)\n  ...
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0      Merge branch 'v4-dev' of https://github.co...
# cb252570a0fb2507c7169427569f50a0a1cb031      Update grid layout docs (#21806)\n    \n  ...
#
#                                                                                      files  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf  [ Gruntfile.js     | 25 ++++------------------...
# 63926717cbc1420218796396fac06c1005447bf  [ docs/layout/responsive-utilities.md | 3 ++-\...
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5  [ docs/layout/responsive-utilities.md | 3 ++-\...
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0  [commit 3cb252570a0fb2507c7169427569f50a0a1cb0...
# cb252570a0fb2507c7169427569f50a0a1cb031  [ docs/layout/grid.md | 2 +-\n,  1 file change...
#
#                                         n_files insertions deletions
# 5a9ebf57635cdf5096e76be961a05367edd3ddf       3         24        22
# 63926717cbc1420218796396fac06c1005447bf       1          2         1
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5       1          2         1
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0   Date:        NaN       NaN
# cb252570a0fb2507c7169427569f50a0a1cb031       1          1         1

# %%
df['n_files'] = df.n_files.apply(pd.to_numeric, args=('coerce',))
df['insertions'] = df.insertions.apply(pd.to_numeric, args=('coerce',))
df['deletions'] = df.deletions.apply(pd.to_numeric, args=('coerce',))

# %%
df.head()
# Out:
#                                                            author  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf   bardi@bardiharborow.com
# 63926717cbc1420218796396fac06c1005447bf            quy@fluxbb.org
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5            quy@fluxbb.org
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0       markdotto@gmail.com
# cb252570a0fb2507c7169427569f50a0a1cb031  marcusmolchany@gmail.com
#
#                                                              date  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf  Mon Jan 23 10:38:34 2017
# 63926717cbc1420218796396fac06c1005447bf  Mon Jan 23 05:37:14 2017
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5  Sun Jan 22 20:17:17 2017
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0  Sun Jan 22 03:02:23 2017
# cb252570a0fb2507c7169427569f50a0a1cb031  Sun Jan 22 03:01:13 2017
#
#                                                                        activity  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf            Move htmllint to npm script.
# 63926717cbc1420218796396fac06c1005447bf             Change to markdown (#21815)
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5  Change header to use markdown (#21809)
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0          Merge branch 'v4-dev' of https
# cb252570a0fb2507c7169427569f50a0a1cb031        Update grid layout docs (#21806)
#
#                                                                                       text  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf                     Move htmllint to npm script.\n
# 63926717cbc1420218796396fac06c1005447bf                      Change to markdown (#21815)\n
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5      Change header to use markdown (#21809)\n  ...
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0      Merge branch 'v4-dev' of https://github.co...
# cb252570a0fb2507c7169427569f50a0a1cb031      Update grid layout docs (#21806)\n    \n  ...
#
#                                                                                      files  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf  [ Gruntfile.js     | 25 ++++------------------...
# 63926717cbc1420218796396fac06c1005447bf  [ docs/layout/responsive-utilities.md | 3 ++-\...
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5  [ docs/layout/responsive-utilities.md | 3 ++-\...
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0  [commit 3cb252570a0fb2507c7169427569f50a0a1cb0...
# cb252570a0fb2507c7169427569f50a0a1cb031  [ docs/layout/grid.md | 2 +-\n,  1 file change...
#
#                                          n_files  insertions  deletions
# 5a9ebf57635cdf5096e76be961a05367edd3ddf      3.0        24.0       22.0
# 63926717cbc1420218796396fac06c1005447bf      1.0         2.0        1.0
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5      1.0         2.0        1.0
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0      NaN         NaN        NaN
# cb252570a0fb2507c7169427569f50a0a1cb031      1.0         1.0        1.0

# %%
pattern_code = ".*\.awk(~?)|.*\.scm(~?)|.*\.glsl(~?)|.*\.patch(~?)|.*\.c((\.swp)?)(~?)|.*/script(s?)/.*|.*\.jar(~?)|.*/src/.*|.*\.m((\.swp)?)(~?)|.*\.cs(~?)|.*\.idl(~?)|.*\.s(~?)|.*\.r((\.swp)?)(~?)|.*\.cxx(~?)|.*\.pyc(~?)|.*\.asm(x?)(~?)|.*\.py((\.swp)?)(~?)|.*\.y((\.swp)?)(~?)|.*\.gi((\.swp)?)(∼?)|.*\.t((\.swp)?)(~?)|.*\.dll(~?)|.*\.h˙template((\.swp)?)(∼?)|.*\.js((\.swp)?)(~?)|.*\.rb((\.swp)?)(~?)|.*\.c˙template((\.swp)?)(∼ ?)|.*\.hg((\.swp)?)(~?)|.*\.pm((\.swp)?)(~?)|.*\.php((\.swp)?)(\d?)(∼ ?)|.*\.cc((\.swp)?)(~?)|.*\.sh((\.swp)?)(~?)|.*\.php((\.swp)?)(\d?)(∼ ?)|.*\.el((\.swp)?)(~?)|.*\.hh((\.swp)?)(~?)|.*\.h((pp)?)((\.swp)?)(∼ ?)|.*\.xs((\.swp)?)(~?)|.*\.pl((\.swp)?)(~?)|.*\.h\.tmpl((\.swp)?)(∼?)|.*\.mm((\.swp)?)(~?)|.*\.idl((\.swp)?)(~?)|.*\.h.win32((\.swp)?)(∼ ?)|.*\.xpt((\.swp)?)(~?)|.*\.ccg((\.swp)?)(~?)|.*\.c˙tmpl((\.swp)?)(∼?)|.*\.snk((\.swp)?)(~?)|.*\.inc((\.swp)?)(~?)|.*\.asp(x?)((\.swp)?)(∼ ?)|.*\.cpp((\.swp)?)(~?)|.*\.gob((\.swp)?)(~?)|.*\.vapi((\.swp)?)(∼?)|.*\.giv((\.swp)?)(~?)|.*\.dtd((\.swp)?)(~?)|.*\.gidl((\.swp)?)(∼?)|.*\.giv((\.swp)?)(~?)|.*\.ada((\.swp)?)(~?)|.*\.defs((\.swp)?)(∼?)|.*\.tcl((\.swp)?)(~?)|.*\.vbs((\.swp)?)(~?)|.*\.java((\.swp)?)(∼?)|.*\.nib((\.swp)?)(~?)|.*\.sed((\.swp)?)(~?)|.*\.vala((˙swp)?)(∼?)"
pattern_doc = "|.*\.zabw|.*/potfiles|.*/install|.*\.wml|.*\.chm|.*\.ods|.*/copyright|.*/version|.*\.css|.*\.vcard(~?)|.*/plan|.*/feature(s?)|.*\.txt((\.bak)?)|.*/credits|.*/notes|.*/licence|.*\.txt((\.old)?)|.*\.man|.*/howto|.*/license|.*\.rtf|.*\.ics|.*/faq|.*/maintainers|.*\.tex|.*/documenters|.*copying|.*/copying|.*\.sgml|.*\.gnumeric|.*/copying.*|.*/committers|.*\.eps|.*\.vcf|.*/doc(s?)/.*|.*/thanks|.*\.xsd|.*\.schemas|.*/help(s?)/.*|.*/authors|.*\.texi|.*\.doc|.*/bugs|.*\.docx"
pattern_test = ".*\.test(s?)/.*|.*/.*test\..*|.*/test.*\..*"
pattern_build = "|.*\.m4(~?)|.*makefile.*|.*\.prj|.*\.plo|.*\.mk|.*\.make|.*\.deps|.*\.wxiproj|.*\.am(~?)|.*\.mp4|.*\.builder|.*\.lo|.*\.target|.*\.iss|.*\.nsi|.*\.wxi|.*/configure((\..+)?)|.*\.wxs|.*/mkbundle\..+|.*\.in|.*/autogen\.((.+\.)?)sh|.*\.wpj|.*\.vc(x?)proj(i?)n((\.filters((in)?))?)|.*\.vcproj((\.filters((in)?))?)"

# %%
df['pat_code'] = 0
df['pat_doc'] = 0
df['pat_test'] = 0
df['pat_build'] = 0
df.head()
# Out:
#                                                            author  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf   bardi@bardiharborow.com
# 63926717cbc1420218796396fac06c1005447bf            quy@fluxbb.org
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5            quy@fluxbb.org
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0       markdotto@gmail.com
# cb252570a0fb2507c7169427569f50a0a1cb031  marcusmolchany@gmail.com
#
#                                                              date  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf  Mon Jan 23 10:38:34 2017
# 63926717cbc1420218796396fac06c1005447bf  Mon Jan 23 05:37:14 2017
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5  Sun Jan 22 20:17:17 2017
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0  Sun Jan 22 03:02:23 2017
# cb252570a0fb2507c7169427569f50a0a1cb031  Sun Jan 22 03:01:13 2017
#
#                                                                        activity  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf            Move htmllint to npm script.
# 63926717cbc1420218796396fac06c1005447bf             Change to markdown (#21815)
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5  Change header to use markdown (#21809)
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0          Merge branch 'v4-dev' of https
# cb252570a0fb2507c7169427569f50a0a1cb031        Update grid layout docs (#21806)
#
#                                                                                       text  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf                     Move htmllint to npm script.\n
# 63926717cbc1420218796396fac06c1005447bf                      Change to markdown (#21815)\n
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5      Change header to use markdown (#21809)\n  ...
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0      Merge branch 'v4-dev' of https://github.co...
# cb252570a0fb2507c7169427569f50a0a1cb031      Update grid layout docs (#21806)\n    \n  ...
#
#                                                                                      files  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf  [ Gruntfile.js     | 25 ++++------------------...
# 63926717cbc1420218796396fac06c1005447bf  [ docs/layout/responsive-utilities.md | 3 ++-\...
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5  [ docs/layout/responsive-utilities.md | 3 ++-\...
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0  [commit 3cb252570a0fb2507c7169427569f50a0a1cb0...
# cb252570a0fb2507c7169427569f50a0a1cb031  [ docs/layout/grid.md | 2 +-\n,  1 file change...
#
#                                          n_files  insertions  deletions  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf      3.0        24.0       22.0
# 63926717cbc1420218796396fac06c1005447bf      1.0         2.0        1.0
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5      1.0         2.0        1.0
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0      NaN         NaN        NaN
# cb252570a0fb2507c7169427569f50a0a1cb031      1.0         1.0        1.0
#
#                                          pat_code  pat_doc  pat_test  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf         0        0         0
# 63926717cbc1420218796396fac06c1005447bf         0        0         0
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5         0        0         0
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0         0        0         0
# cb252570a0fb2507c7169427569f50a0a1cb031         0        0         0
#
#                                          pat_build
# 5a9ebf57635cdf5096e76be961a05367edd3ddf          0
# 63926717cbc1420218796396fac06c1005447bf          0
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5          0
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0          0
# cb252570a0fb2507c7169427569f50a0a1cb031          0

# %%
import re
for index, row in df.iterrows():
    code = 0
    doc = 0
    test = 0
    build = 0
    for j in range(0, len(row['files'])):
        match_code = re.match(pattern_code, row['files'][j], flags=0)
        if match_code:
            code += 1
        match_doc = re.match(pattern_doc, row['files'][j], flags=0)
        if match_doc:
            doc += 1
        match_test = re.match(pattern_test, row['files'][j], flags=0)
        if match_test:
            test += 1
        match_build = re.match(pattern_build, row['files'][j], flags=0)
        if match_build:
            build += 1
    
    df.set_value(index, 'pat_code', code) 
    df.set_value(index, 'pat_doc', doc) 
    df.set_value(index, 'pat_test', test) 
    df.set_value(index, 'pat_build', build) 
df.head()
# Out:
#                                                            author  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf   bardi@bardiharborow.com
# 63926717cbc1420218796396fac06c1005447bf            quy@fluxbb.org
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5            quy@fluxbb.org
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0       markdotto@gmail.com
# cb252570a0fb2507c7169427569f50a0a1cb031  marcusmolchany@gmail.com
#
#                                                              date  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf  Mon Jan 23 10:38:34 2017
# 63926717cbc1420218796396fac06c1005447bf  Mon Jan 23 05:37:14 2017
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5  Sun Jan 22 20:17:17 2017
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0  Sun Jan 22 03:02:23 2017
# cb252570a0fb2507c7169427569f50a0a1cb031  Sun Jan 22 03:01:13 2017
#
#                                                                        activity  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf            Move htmllint to npm script.
# 63926717cbc1420218796396fac06c1005447bf             Change to markdown (#21815)
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5  Change header to use markdown (#21809)
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0          Merge branch 'v4-dev' of https
# cb252570a0fb2507c7169427569f50a0a1cb031        Update grid layout docs (#21806)
#
#                                                                                       text  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf                     Move htmllint to npm script.\n
# 63926717cbc1420218796396fac06c1005447bf                      Change to markdown (#21815)\n
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5      Change header to use markdown (#21809)\n  ...
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0      Merge branch 'v4-dev' of https://github.co...
# cb252570a0fb2507c7169427569f50a0a1cb031      Update grid layout docs (#21806)\n    \n  ...
#
#                                                                                      files  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf  [ Gruntfile.js     | 25 ++++------------------...
# 63926717cbc1420218796396fac06c1005447bf  [ docs/layout/responsive-utilities.md | 3 ++-\...
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5  [ docs/layout/responsive-utilities.md | 3 ++-\...
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0  [commit 3cb252570a0fb2507c7169427569f50a0a1cb0...
# cb252570a0fb2507c7169427569f50a0a1cb031  [ docs/layout/grid.md | 2 +-\n,  1 file change...
#
#                                          n_files  insertions  deletions  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf      3.0        24.0       22.0
# 63926717cbc1420218796396fac06c1005447bf      1.0         2.0        1.0
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5      1.0         2.0        1.0
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0      NaN         NaN        NaN
# cb252570a0fb2507c7169427569f50a0a1cb031      1.0         1.0        1.0
#
#                                          pat_code  pat_doc  pat_test  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf         2        4         0
# 63926717cbc1420218796396fac06c1005447bf         1        2         0
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5         1        2         0
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0         1        3         0
# cb252570a0fb2507c7169427569f50a0a1cb031         1        2         0
#
#                                          pat_build
# 5a9ebf57635cdf5096e76be961a05367edd3ddf          4
# 63926717cbc1420218796396fac06c1005447bf          2
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5          2
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0          3
# cb252570a0fb2507c7169427569f50a0a1cb031          2

# %%
df.insertions.describe()
# Out:
# D:\Anaconda\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# count    11751.000000
# mean        85.486427
# std        837.376180
# min          0.000000
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max      46646.000000
# Name: insertions, dtype: float64

# %%
comment_code = "(?:^|\W)cod(?:$|)"
comment_doc = "(?:^|\W)doc(?:$|)"
comment_test = "(?:^|\W)test(?:$|)"
comment_build = "(?:^|\W)build(?:$|)"

# %%
df['text_code'] = 0
df['text_doc'] = 0
df['text_test'] = 0
df['text_build'] = 0

# %%
match_code = re.findall(comment_code, df['text'][1], re.IGNORECASE)
match_doc = re.findall(comment_doc, df['text'][1], re.IGNORECASE)
match_test = re.findall(comment_test, df['text'][1], re.IGNORECASE)
match_build = re.findall(comment_build, df['text'][1], re.IGNORECASE)

# %%
for index, row in df.iterrows():   
    match_code = re.findall(comment_code, row['text'], re.IGNORECASE)
    match_doc = re.findall(comment_doc, row['text'], re.IGNORECASE)
    match_test = re.findall(comment_test, row['text'], re.IGNORECASE)
    match_build = re.findall(comment_build, row['text'], re.IGNORECASE)

    df.set_value(index, 'text_code', len(match_code)) 
    df.set_value(index, 'text_doc', len(match_doc)) 
    df.set_value(index, 'text_test', len(match_test))
    df.set_value(index, 'text_build', len(match_build)) 
df.head()
# Out:
#                                                            author  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf   bardi@bardiharborow.com
# 63926717cbc1420218796396fac06c1005447bf            quy@fluxbb.org
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5            quy@fluxbb.org
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0       markdotto@gmail.com
# cb252570a0fb2507c7169427569f50a0a1cb031  marcusmolchany@gmail.com
#
#                                                              date  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf  Mon Jan 23 10:38:34 2017
# 63926717cbc1420218796396fac06c1005447bf  Mon Jan 23 05:37:14 2017
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5  Sun Jan 22 20:17:17 2017
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0  Sun Jan 22 03:02:23 2017
# cb252570a0fb2507c7169427569f50a0a1cb031  Sun Jan 22 03:01:13 2017
#
#                                                                        activity  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf            Move htmllint to npm script.
# 63926717cbc1420218796396fac06c1005447bf             Change to markdown (#21815)
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5  Change header to use markdown (#21809)
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0          Merge branch 'v4-dev' of https
# cb252570a0fb2507c7169427569f50a0a1cb031        Update grid layout docs (#21806)
#
#                                                                                       text  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf                     Move htmllint to npm script.\n
# 63926717cbc1420218796396fac06c1005447bf                      Change to markdown (#21815)\n
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5      Change header to use markdown (#21809)\n  ...
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0      Merge branch 'v4-dev' of https://github.co...
# cb252570a0fb2507c7169427569f50a0a1cb031      Update grid layout docs (#21806)\n    \n  ...
#
#                                                                                      files  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf  [ Gruntfile.js     | 25 ++++------------------...
# 63926717cbc1420218796396fac06c1005447bf  [ docs/layout/responsive-utilities.md | 3 ++-\...
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5  [ docs/layout/responsive-utilities.md | 3 ++-\...
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0  [commit 3cb252570a0fb2507c7169427569f50a0a1cb0...
# cb252570a0fb2507c7169427569f50a0a1cb031  [ docs/layout/grid.md | 2 +-\n,  1 file change...
#
#                                          n_files  insertions  deletions  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf      3.0        24.0       22.0
# 63926717cbc1420218796396fac06c1005447bf      1.0         2.0        1.0
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5      1.0         2.0        1.0
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0      NaN         NaN        NaN
# cb252570a0fb2507c7169427569f50a0a1cb031      1.0         1.0        1.0
#
#                                          pat_code  pat_doc  pat_test  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf         2        4         0
# 63926717cbc1420218796396fac06c1005447bf         1        2         0
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5         1        2         0
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0         1        3         0
# cb252570a0fb2507c7169427569f50a0a1cb031         1        2         0
#
#                                          pat_build  text_code  text_doc  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf          4          0         0
# 63926717cbc1420218796396fac06c1005447bf          2          0         0
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5          2          0         0
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0          3          0         0
# cb252570a0fb2507c7169427569f50a0a1cb031          2          0         1
#
#                                          text_test  text_build
# 5a9ebf57635cdf5096e76be961a05367edd3ddf          0           0
# 63926717cbc1420218796396fac06c1005447bf          0           0
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5          0           0
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0          0           0
# cb252570a0fb2507c7169427569f50a0a1cb031          0           0

# %%
from textblob import TextBlob

# %%
df['subjectivity'] = 0
df['polarity'] = 0

# %%
for index, row in df.iterrows(): 
    textblob = TextBlob(row['text'])
    df.set_value(index, 'polarity', textblob.sentiment.polarity) 
    df.set_value(index, 'subjectivity', textblob.sentiment.subjectivity) 
df.head()
# Out:
#                                                            author  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf   bardi@bardiharborow.com
# 63926717cbc1420218796396fac06c1005447bf            quy@fluxbb.org
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5            quy@fluxbb.org
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0       markdotto@gmail.com
# cb252570a0fb2507c7169427569f50a0a1cb031  marcusmolchany@gmail.com
#
#                                                              date  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf  Mon Jan 23 10:38:34 2017
# 63926717cbc1420218796396fac06c1005447bf  Mon Jan 23 05:37:14 2017
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5  Sun Jan 22 20:17:17 2017
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0  Sun Jan 22 03:02:23 2017
# cb252570a0fb2507c7169427569f50a0a1cb031  Sun Jan 22 03:01:13 2017
#
#                                                                        activity  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf            Move htmllint to npm script.
# 63926717cbc1420218796396fac06c1005447bf             Change to markdown (#21815)
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5  Change header to use markdown (#21809)
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0          Merge branch 'v4-dev' of https
# cb252570a0fb2507c7169427569f50a0a1cb031        Update grid layout docs (#21806)
#
#                                                                                       text  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf                     Move htmllint to npm script.\n
# 63926717cbc1420218796396fac06c1005447bf                      Change to markdown (#21815)\n
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5      Change header to use markdown (#21809)\n  ...
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0      Merge branch 'v4-dev' of https://github.co...
# cb252570a0fb2507c7169427569f50a0a1cb031      Update grid layout docs (#21806)\n    \n  ...
#
#                                                                                      files  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf  [ Gruntfile.js     | 25 ++++------------------...
# 63926717cbc1420218796396fac06c1005447bf  [ docs/layout/responsive-utilities.md | 3 ++-\...
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5  [ docs/layout/responsive-utilities.md | 3 ++-\...
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0  [commit 3cb252570a0fb2507c7169427569f50a0a1cb0...
# cb252570a0fb2507c7169427569f50a0a1cb031  [ docs/layout/grid.md | 2 +-\n,  1 file change...
#
#                                          n_files  insertions  deletions  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf      3.0        24.0       22.0
# 63926717cbc1420218796396fac06c1005447bf      1.0         2.0        1.0
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5      1.0         2.0        1.0
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0      NaN         NaN        NaN
# cb252570a0fb2507c7169427569f50a0a1cb031      1.0         1.0        1.0
#
#                                          pat_code  pat_doc  pat_test  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf         2        4         0
# 63926717cbc1420218796396fac06c1005447bf         1        2         0
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5         1        2         0
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0         1        3         0
# cb252570a0fb2507c7169427569f50a0a1cb031         1        2         0
#
#                                          pat_build  text_code  text_doc  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf          4          0         0
# 63926717cbc1420218796396fac06c1005447bf          2          0         0
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5          2          0         0
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0          3          0         0
# cb252570a0fb2507c7169427569f50a0a1cb031          2          0         1
#
#                                          text_test  text_build  subjectivity  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf          0           0             0
# 63926717cbc1420218796396fac06c1005447bf          0           0             0
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5          0           0             0
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0          0           0             0
# cb252570a0fb2507c7169427569f50a0a1cb031          0           0             0
#
#                                          polarity
# 5a9ebf57635cdf5096e76be961a05367edd3ddf         0
# 63926717cbc1420218796396fac06c1005447bf         0
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5         0
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0         0
# cb252570a0fb2507c7169427569f50a0a1cb031         0

# %%
df.polarity.describe()
# Out:
# count    15740.000000
# mean         0.000635
# std          0.027605
# min         -1.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: polarity, dtype: float64

# %%
print('Class                                                                                        Amount')
for i in range(1,10):
    classCount = df.activity.value_counts()
print(classCount)
# Out:
# Class                                                                                        Amount
# grunt                                                                        379
# Merge branch '3.0.0-wip' of github.com                                       181
# Merge branch 'master' of github.com                                          171
# Merge branch '2.0-wip' of github.com                                          63
# Run `grunt`.                                                                  57
# automatic grunt dist                                                          55
# grunt dist                                                                    46
# Merge branch 'v4-dev' of https                                                44
# automatic `grunt dist`                                                        42
# Merge branch '2.0-wip' of https                                               41
# Docs                                                                          39
# update shrinkwrap                                                             38
# Merge branch 'master' of https                                                27
# Merge branch '3.0.0-wip' of https                                             27
# Merge branch '1.3-wip' of github.com                                          26
# Merge branch 'master' into docs_derp                                          25
# Merge branch 'v4' of https                                                    22
# Update dependencies.                                                          21
# Merge branch 'master' of http                                                 19
# https                                                                         18
# Merge branch '2.1.0-wip' of github.com                                        17
# rebuild                                                                       17
# typo                                                                          16
# Merge branch '2.1.0-wip' of https                                             16
# Update devDependencies.                                                       16
# linting                                                                       15
# Merge branch 'master' into derp                                               15
# http                                                                          14
# Merge branch '2.0.2-wip' of github.com                                        13
# Merge branch '2.3.0-wip' into 3.0.0-wip                                       13
#                                                                             ...
# remove remaining fluid grid css                                                1
# Merge pull request #18816 from twbs/fix-17308                                  1
# tweak #13453 Firefox bug summary                                               1
# Round results from gutter division to prevent decimal margins and padding      1
# Merge pull request #9788 from brunoamaral/3.0.0-wip                            1
# clean up new input append examples                                             1
# Fixes #11623                                                                   1
# Add Most Wanted Features entries for <dialog>                                  1
# More forms overhaul                                                            1
# Options of sizes added in modal                                                1
# text size                                                                      1
# Merge pull request #14242 from hnrch02/remove-aria-describedby-later           1
# add ability to cycle carousel to a particular frame                            1
# rewrite helpers in markdown                                                    1
# Merge pull request #17152 from zacechola/popover_container_example             1
# Merge pull request #8852 from briannelsondesign/label_baselines                1
# Move grid offsets to desktop only (fixes #8229)                                1
# possibly avoid some extra S3 charges                                           1
# Fix pixel values in Responsive Utilities docs to match the actual code         1
# Merge pull request #12688 from twbs/document_popover_focus                     1
# Turn off clean-css' advanced optimizations.                                    1
# Update time-grunt to v0.3.1.                                                   1
# add nav class to tabs in javascript demo                                       1
# Merge pull request #17495 from vsn4ik/mv_text_hide                             1
# fixes #9436 more                                                               1
# Merge pull request #6380 from Yohn/patch-10                                    1
# Merge pull request #15678 from coliff/patch-1                                  1
# tweaks                                                                         1
# Switch to Rogue over Pygments for speeeeeed                                    1
# update boto & s3_cache.py                                                      1
# Name: activity, dtype: int64

# %%
print('User                                 Count')
for i in range(1,10):
    classCount = df.author.value_counts()
print(classCount)
# Out:
# User                                 Count
# markdotto@gmail.com                    3139
# otto@github.com                        3019
# jacobthornton@gmail.com                1162
# github@rebertia.com                    1005
# markotto@twitter.com                   1000
# code@rebertia.com                       962
# markd.otto@gmail.com                    582
# github@chrisrebert.com                  459
# xhmikosr@gmail.com                      320
# code@chrisrebert.com                    317
# mark.otto@twitter.com                   307
# hnrch02@gmail.com                       223
# redux@splintered.co.uk                  218
# xhmikosr@users.sourceforge.net          204
# legospace9876@gmail.com                 161
# bigj95t@gmail.com                       129
# twbs-grunt@users.noreply.github.com      95
# Kev.Kirsche+GitHub@gmail.com             62
# quy@fluxbb.org                           59
# vsn4ik@gmail.com                         48
# XhmikosR@users.noreply.github.com        48
# bardi@bardiharborow.com                  42
# steveb@stevenblack.com                   36
# burnsra@gmail.com                        34
# glex.spb@gmail.com                       32
# bass@w3masters.nl                        29
# phopkins@twitter.com                     29
# developer@smerik.nl                      26
# ggam@brainleakage.com                    25
# github@nazgul.nu                         24
#                                        ...
# nate@nateeag.com                          1
# tombyrer@gmail.com                        1
# ryaburne@fabric.com                       1
# s.chikhalia@gmail.com                     1
# mail@jonasw.de                            1
# stepan.zastupov@gmail.com                 1
# martin.stein01@sap.com                    1
# ndmuir@gmail.com                          1
# noahblon@gmail.com                        1
# rafbmasson@gmail.com                      1
# jason.harbert@gmail.com                   1
# shot@perceptualmediaworks.com             1
# dasch@daschmedia.de                       1
# aaron.ricketson@gmail.com                 1
# dev@ckundo.com                            1
# viky.nandha@gmail.com                     1
# mc@mathisonian.com                        1
# henning@hoefer.tk                         1
# thoogh@gmail.com                          1
# brent@bmemedia.net                        1
# westonplatter@gmail.com                   1
# pine3ree@gmail.com                        1
# rwollin96@gmail.com                       1
# mark@arcticflare.com                      1
# stephan@minddust.com                      1
# dscherer@targetfmi.com                    1
# juniorcnt@gmail.com                       1
# jamesdmosier@gmail.com                    1
# greg@corax.org                            1
# leggieroeduardo@gmail.com                 1
# Name: author, dtype: int64

# %%
x = {'Count': pd.Series(df.activity.value_counts())
     }
activity_count = pd.DataFrame(x)
activity_count.head()
# Out:
#                                         Count
# grunt                                     379
# Merge branch '3.0.0-wip' of github.com    181
# Merge branch 'master' of github.com       171
# Merge branch '2.0-wip' of github.com       63
# Run `grunt`.                               57

# %%
plt.figure(figsize=(18,10))
activity_count.query('Count > 5').plot(kind='bar', color="blue", alpha=.75)
plt.title("Distribution of Activities")
plt.show()

# %%
#####################

# %%
#####################

# %%
############################

# %%
dfTest = df[df.activity.isin(["Build","Tests", "Docs", "Release", "Core"])]

# %%
dfTest.describe()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#           n_files   insertions     deletions    pat_code     pat_doc  \
# count  378.000000   378.000000    312.000000  378.000000  378.000000
# mean     3.574074   117.076720    132.262821    3.280423    4.574074
# std      9.555426   785.713143    931.973549    9.215411    9.555426
# min      1.000000     1.000000      1.000000    0.000000    2.000000
# 25%      1.000000     2.000000           NaN    1.000000    2.000000
# 50%      1.000000     6.000000           NaN    1.000000    2.000000
# 75%      3.000000    20.750000           NaN    3.000000    4.000000
# max    129.000000  8708.000000  11415.000000  129.000000  130.000000
#
#          pat_test   pat_build   text_code    text_doc   text_test  text_build  \
# count  378.000000  378.000000  378.000000  378.000000  378.000000  378.000000
# mean     0.185185    4.574074    0.042328    0.097884    0.671958    0.476190
# std      0.615962    9.555426    0.354294    0.314876    1.029180    0.555383
# min      0.000000    2.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    2.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    4.000000    0.000000    0.000000    1.000000    1.000000
# max      8.000000  130.000000    6.000000    2.000000    7.000000    2.000000
#
#        subjectivity    polarity
# count    378.000000  378.000000
# mean       0.026455    0.002646
# std        0.160697    0.051434
# min        0.000000    0.000000
# 25%        0.000000    0.000000
# 50%        0.000000    0.000000
# 75%        0.000000    0.000000
# max        1.000000    1.000000

# %%
dfTest['deletions'] = dfTest['deletions'].fillna('0')
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
##LEAVE THINGS ABOVE, BUT NOT RUN THEM

# %%
#######

# %%
#######

# %%
#######

# %%
#######

# %%
#######

# %%
from sklearn import cross_validation
from sklearn.preprocessing import *
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import *
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import *
from sklearn.cross_validation import KFold
import random

# %%
dfTest = pd.read_csv('jQuery_Training.csv', index_col=0, encoding="utf-8")
dfFinal = dfTest.drop("activity", 1).drop("files", 1).drop("text", 1).drop("date", 1).drop("author", 1)
X = dfFinal.values
y = dfTest.activity.values

# %%
dfTest.head()
# Out:
#                                                            author  \
# 8816caf26c0acc7067cd5bad9c03cfb54e54979           alex@louden.com
# 10ac0e532a9376106c50f0c21a0d0fd0483b700         m.goleb@gmail.com
# d9145fa15d91ab6c804161ecd892d4d08b71aa2        broder93@gmail.com
# cb4cd71ef018854f75646270bacd4c4d3da9cde  richard.gibson@gmail.com
# 754e315f8a7760bcdc162712d2be7fee058fdc2         m.goleb@gmail.com
#
#                                                                    date  \
# 8816caf26c0acc7067cd5bad9c03cfb54e54979   Thu Jan 5 16:49:02 2017 +0800
# 10ac0e532a9376106c50f0c21a0d0fd0483b700  Fri Dec 30 12:17:00 2016 +0100
# d9145fa15d91ab6c804161ecd892d4d08b71aa2  Sat Dec 24 10:33:27 2016 +0000
# cb4cd71ef018854f75646270bacd4c4d3da9cde  Mon Dec 19 11:58:48 2016 -0500
# 754e315f8a7760bcdc162712d2be7fee058fdc2  Wed Nov 30 15:32:29 2016 +0100
#
#                                         activity  \
# 8816caf26c0acc7067cd5bad9c03cfb54e54979     Docs
# 10ac0e532a9376106c50f0c21a0d0fd0483b700    Build
# d9145fa15d91ab6c804161ecd892d4d08b71aa2    Tests
# cb4cd71ef018854f75646270bacd4c4d3da9cde    Build
# 754e315f8a7760bcdc162712d2be7fee058fdc2    Build
#
#                                                                                       text  \
# 8816caf26c0acc7067cd5bad9c03cfb54e54979           Docs: Correct typo in issue template\r\n
# 10ac0e532a9376106c50f0c21a0d0fd0483b700      Build: Drop support for building on Node.j...
# d9145fa15d91ab6c804161ecd892d4d08b71aa2      Tests: Added tests for symbol-separated ta...
# cb4cd71ef018854f75646270bacd4c4d3da9cde      Build: Use valid ecmaVersion\r\n    \r\n  ...
# 754e315f8a7760bcdc162712d2be7fee058fdc2      Build: Add most of the dist folder to .esl...
#
#                                                                                      files  \
# 8816caf26c0acc7067cd5bad9c03cfb54e54979  [' .github/ISSUE_TEMPLATE.md | 2 +-\n', ' 1 fi...
# 10ac0e532a9376106c50f0c21a0d0fd0483b700  [' .travis.yml  |  1 -\n', ' Gruntfile.js | 39...
# d9145fa15d91ab6c804161ecd892d4d08b71aa2  [' test/unit/core.js | 27 ++++++++++++++++++--...
# cb4cd71ef018854f75646270bacd4c4d3da9cde  [' test/node_smoke_tests/.eslintrc.json | 2 +-...
# 754e315f8a7760bcdc162712d2be7fee058fdc2  [' .eslintignore | 2 ++\n', ' 1 file changed, ...
#
#                                          n_files  insertions  deletions  \
# 8816caf26c0acc7067cd5bad9c03cfb54e54979      1.0         1.0        1.0
# 10ac0e532a9376106c50f0c21a0d0fd0483b700      2.0        11.0       29.0
# d9145fa15d91ab6c804161ecd892d4d08b71aa2      1.0        18.0        9.0
# cb4cd71ef018854f75646270bacd4c4d3da9cde      1.0         1.0        1.0
# 754e315f8a7760bcdc162712d2be7fee058fdc2      1.0         2.0        0.0
#
#                                          pat_code  pat_doc  pat_test  \
# 8816caf26c0acc7067cd5bad9c03cfb54e54979         1        2         0
# 10ac0e532a9376106c50f0c21a0d0fd0483b700         2        3         0
# d9145fa15d91ab6c804161ecd892d4d08b71aa2         1        2         0
# cb4cd71ef018854f75646270bacd4c4d3da9cde         1        2         0
# 754e315f8a7760bcdc162712d2be7fee058fdc2         0        2         0
#
#                                          pat_build  text_code  text_doc  \
# 8816caf26c0acc7067cd5bad9c03cfb54e54979          2          0         1
# 10ac0e532a9376106c50f0c21a0d0fd0483b700          3          0         0
# d9145fa15d91ab6c804161ecd892d4d08b71aa2          2          0         0
# cb4cd71ef018854f75646270bacd4c4d3da9cde          2          0         0
# 754e315f8a7760bcdc162712d2be7fee058fdc2          2          0         0
#
#                                          text_test  text_build  subjectivity  \
# 8816caf26c0acc7067cd5bad9c03cfb54e54979          0           0             0
# 10ac0e532a9376106c50f0c21a0d0fd0483b700          1           2             0
# d9145fa15d91ab6c804161ecd892d4d08b71aa2          2           0             0
# cb4cd71ef018854f75646270bacd4c4d3da9cde          1           1             0
# 754e315f8a7760bcdc162712d2be7fee058fdc2          0           1             0
#
#                                          polarity
# 8816caf26c0acc7067cd5bad9c03cfb54e54979         0
# 10ac0e532a9376106c50f0c21a0d0fd0483b700         0
# d9145fa15d91ab6c804161ecd892d4d08b71aa2         0
# cb4cd71ef018854f75646270bacd4c4d3da9cde         0
# 754e315f8a7760bcdc162712d2be7fee058fdc2         0

# %%
X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, test_size=0.25)
y_train
# Out:
# array(['Build', 'Docs', 'Core', 'Build', 'Core', 'Tests', 'Tests', 'Core',
#        'Build', 'Core', 'Build', 'Build', 'Build', 'Build', 'Tests',
#        'Tests', 'Tests', 'Tests', 'Tests', 'Build', 'Release', 'Build',
#        'Build', 'Tests', 'Docs', 'Release', 'Core', 'Build', 'Tests',
#        'Core', 'Core', 'Build', 'Build', 'Tests', 'Build', 'Docs', 'Build',
#        'Build', 'Tests', 'Release', 'Core', 'Build', 'Tests', 'Build',
#        'Release', 'Build', 'Core', 'Build', 'Tests', 'Core', 'Tests',
#        'Build', 'Build', 'Tests', 'Build', 'Release', 'Build', 'Build',
#        'Core', 'Core', 'Tests', 'Build', 'Build', 'Build', 'Docs', 'Tests',
#        'Core', 'Tests', 'Tests', 'Tests', 'Build', 'Tests', 'Build',
#        'Build', 'Docs', 'Core', 'Tests', 'Build', 'Core', 'Build', 'Build',
#        'Tests', 'Core', 'Build', 'Docs', 'Tests', 'Core', 'Build', 'Build',
#        'Build', 'Build', 'Tests', 'Tests', 'Tests', 'Core', 'Release',
#        'Build', 'Build', 'Build', 'Core', 'Tests', 'Release', 'Build',
#        'Tests', 'Docs', 'Build', 'Build', 'Tests', 'Build', 'Build',
#        'Release', 'Tests', 'Build', 'Docs', 'Docs', 'Build', 'Build',
#        'Build', 'Build', 'Docs', 'Core', 'Core', 'Build', 'Core', 'Build',
#        'Core', 'Core', 'Core', 'Build', 'Core', 'Tests', 'Tests', 'Core',
#        'Build', 'Build', 'Tests', 'Build', 'Tests', 'Core', 'Build',
#        'Tests', 'Build', 'Tests', 'Release', 'Core', 'Build', 'Tests',
#        'Core', 'Tests', 'Release', 'Release', 'Build', 'Tests', 'Build',
#        'Core', 'Release', 'Core', 'Build', 'Tests', 'Build', 'Build',
#        'Core', 'Build', 'Tests', 'Tests', 'Tests', 'Build', 'Tests',
#        'Build', 'Build', 'Tests', 'Build', 'Docs', 'Tests', 'Core', 'Core',
#        'Build', 'Tests', 'Tests', 'Build', 'Tests', 'Release', 'Build',
#        'Tests', 'Build', 'Docs', 'Docs', 'Build', 'Build', 'Build',
#        'Release', 'Build', 'Build', 'Tests', 'Core', 'Build', 'Core',
#        'Build', 'Core', 'Build', 'Build', 'Core', 'Core', 'Tests', 'Build',
#        'Build', 'Release', 'Build', 'Docs', 'Tests', 'Build', 'Build',
#        'Build', 'Build', 'Build', 'Build', 'Tests', 'Build', 'Docs',
#        'Build', 'Build', 'Build', 'Build', 'Core', 'Core', 'Tests',
#        'Release', 'Build', 'Tests', 'Tests', 'Build', 'Build', 'Build',
#        'Core', 'Tests', 'Build', 'Build', 'Docs', 'Tests', 'Build',
#        'Tests', 'Release', 'Build', 'Build', 'Build', 'Docs', 'Docs',
#        'Build', 'Build', 'Tests', 'Build', 'Docs', 'Tests', 'Tests',
#        'Build', 'Tests', 'Build', 'Build', 'Core', 'Core', 'Tests',
#        'Release', 'Build', 'Core', 'Core', 'Core', 'Build', 'Tests',
#        'Build', 'Core', 'Docs', 'Build', 'Build', 'Build', 'Build', 'Docs',
#        'Core', 'Core', 'Core', 'Tests', 'Tests', 'Docs', 'Build'], dtype=object)

# %%
clf = LinearDiscriminantAnalysis()
clf.fit(X_train, y_train)
accuracy = clf.score(X_test, y_test)
"accuracy: %.1f percent"%(100*accuracy)
# Out:
# D:\Anaconda\lib\site-packages\sklearn\discriminant_analysis.py:387: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# 'accuracy: 82.1 percent'

# %%
df.describe()
# Out:
# D:\Anaconda\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#             n_files    insertions     deletions      pat_code       pat_doc  \
# count  11751.000000  11751.000000   9821.000000  15740.000000  15740.000000
# mean       3.253766     85.486427     78.098768      1.766010      4.003494
# std        6.188165    837.376180    663.211140      3.780018      5.368620
# min        1.000000      0.000000      0.000000      0.000000      2.000000
# 25%             NaN           NaN           NaN      1.000000      2.000000
# 50%             NaN           NaN           NaN      1.000000      3.000000
# 75%             NaN           NaN           NaN      1.000000      4.000000
# max      236.000000  46646.000000  21852.000000    102.000000    237.000000
#
#            pat_test     pat_build     text_code      text_doc     text_test  \
# count  15740.000000  15740.000000  15740.000000  15740.000000  15740.000000
# mean       0.069695      4.003494      0.024333      0.241804      0.029924
# std        0.697383      5.368620      0.169030      1.408354      0.205847
# min        0.000000      2.000000      0.000000      0.000000      0.000000
# 25%        0.000000      2.000000      0.000000      0.000000      0.000000
# 50%        0.000000      3.000000      0.000000      0.000000      0.000000
# 75%        0.000000      4.000000      0.000000      0.000000      0.000000
# max       22.000000    237.000000      4.000000     69.000000      6.000000
#
#          text_build  subjectivity      polarity
# count  15740.000000  15740.000000  15740.000000
# mean       0.008958      0.016836      0.000635
# std        0.103235      0.128661      0.027605
# min        0.000000      0.000000     -1.000000
# 25%        0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000
# max        4.000000      1.000000      1.000000

# %%
dfComplete = df.copy()
dfComplete['deletions'] = dfComplete['deletions'].fillna(0)
dfComplete['n_files'] = dfComplete['n_files'].fillna(0)
dfComplete['insertions'] = dfComplete['insertions'].fillna(0)
dfComplete.describe()
# Out:
#             n_files    insertions     deletions      pat_code       pat_doc  \
# count  15740.000000  15740.000000  15740.000000  15740.000000  15740.000000
# mean       2.429161     63.821537     48.729860      1.766010      4.003494
# std        5.530938    724.475670    525.228781      3.780018      5.368620
# min        0.000000      0.000000      0.000000      0.000000      2.000000
# 25%        0.000000      0.000000      0.000000      1.000000      2.000000
# 50%        1.000000      2.000000      1.000000      1.000000      3.000000
# 75%        3.000000     13.000000      7.000000      1.000000      4.000000
# max      236.000000  46646.000000  21852.000000    102.000000    237.000000
#
#            pat_test     pat_build     text_code      text_doc     text_test  \
# count  15740.000000  15740.000000  15740.000000  15740.000000  15740.000000
# mean       0.069695      4.003494      0.024333      0.241804      0.029924
# std        0.697383      5.368620      0.169030      1.408354      0.205847
# min        0.000000      2.000000      0.000000      0.000000      0.000000
# 25%        0.000000      2.000000      0.000000      0.000000      0.000000
# 50%        0.000000      3.000000      0.000000      0.000000      0.000000
# 75%        0.000000      4.000000      0.000000      0.000000      0.000000
# max       22.000000    237.000000      4.000000     69.000000      6.000000
#
#          text_build  subjectivity      polarity
# count  15740.000000  15740.000000  15740.000000
# mean       0.008958      0.016836      0.000635
# std        0.103235      0.128661      0.027605
# min        0.000000      0.000000     -1.000000
# 25%        0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000
# max        4.000000      1.000000      1.000000

# %%
dfCompleteX = dfComplete.drop("activity", 1).drop("files", 1).drop("text", 1).drop("date", 1).drop("author", 1)

# %%
dfCompleteX.head()
# Out:
#                                          n_files  insertions  deletions  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf      3.0        24.0       22.0
# 63926717cbc1420218796396fac06c1005447bf      1.0         2.0        1.0
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5      1.0         2.0        1.0
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0      0.0         0.0        0.0
# cb252570a0fb2507c7169427569f50a0a1cb031      1.0         1.0        1.0
#
#                                          pat_code  pat_doc  pat_test  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf         2        4         0
# 63926717cbc1420218796396fac06c1005447bf         1        2         0
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5         1        2         0
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0         1        3         0
# cb252570a0fb2507c7169427569f50a0a1cb031         1        2         0
#
#                                          pat_build  text_code  text_doc  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf          4          0         0
# 63926717cbc1420218796396fac06c1005447bf          2          0         0
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5          2          0         0
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0          3          0         0
# cb252570a0fb2507c7169427569f50a0a1cb031          2          0         1
#
#                                          text_test  text_build  subjectivity  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf          0           0             0
# 63926717cbc1420218796396fac06c1005447bf          0           0             0
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5          0           0             0
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0          0           0             0
# cb252570a0fb2507c7169427569f50a0a1cb031          0           0             0
#
#                                          polarity
# 5a9ebf57635cdf5096e76be961a05367edd3ddf         0
# 63926717cbc1420218796396fac06c1005447bf         0
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5         0
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0         0
# cb252570a0fb2507c7169427569f50a0a1cb031         0

# %%
dfComplete["predicted"] = clf.predict(dfCompleteX)

# %%
dfComplete.describe()
# Out:
#             n_files    insertions     deletions      pat_code       pat_doc  \
# count  15740.000000  15740.000000  15740.000000  15740.000000  15740.000000
# mean       2.429161     63.821537     48.729860      1.766010      4.003494
# std        5.530938    724.475670    525.228781      3.780018      5.368620
# min        0.000000      0.000000      0.000000      0.000000      2.000000
# 25%        0.000000      0.000000      0.000000      1.000000      2.000000
# 50%        1.000000      2.000000      1.000000      1.000000      3.000000
# 75%        3.000000     13.000000      7.000000      1.000000      4.000000
# max      236.000000  46646.000000  21852.000000    102.000000    237.000000
#
#            pat_test     pat_build     text_code      text_doc     text_test  \
# count  15740.000000  15740.000000  15740.000000  15740.000000  15740.000000
# mean       0.069695      4.003494      0.024333      0.241804      0.029924
# std        0.697383      5.368620      0.169030      1.408354      0.205847
# min        0.000000      2.000000      0.000000      0.000000      0.000000
# 25%        0.000000      2.000000      0.000000      0.000000      0.000000
# 50%        0.000000      3.000000      0.000000      0.000000      0.000000
# 75%        0.000000      4.000000      0.000000      0.000000      0.000000
# max       22.000000    237.000000      4.000000     69.000000      6.000000
#
#          text_build  subjectivity      polarity
# count  15740.000000  15740.000000  15740.000000
# mean       0.008958      0.016836      0.000635
# std        0.103235      0.128661      0.027605
# min        0.000000      0.000000     -1.000000
# 25%        0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000
# max        4.000000      1.000000      1.000000

# %%
x = {'Count': pd.Series(dfComplete.predicted.value_counts())
     }
activity_count = pd.DataFrame(x)
activity_count.head()
# Out:
#          Count
# Core     12405
# Docs      2660
# Tests      539
# Build      126
# Release     10

# %%
dfComplete[["activity", "predicted"]]
# Out:
#                                                                                   activity  \
# 5a9ebf57635cdf5096e76be961a05367edd3ddf                       Move htmllint to npm script.
# 63926717cbc1420218796396fac06c1005447bf                        Change to markdown (#21815)
# 91f3b8c246a8e4923f3f156ffbf3e359058d1d5             Change header to use markdown (#21809)
# 920049b5b36cfcb225c92d9aaf743fa6320a2e0                     Merge branch 'v4-dev' of https
# cb252570a0fb2507c7169427569f50a0a1cb031                   Update grid layout docs (#21806)
# eb1c59c53f3a840bb1fe2794fdf9fc7d081f47f                                              grunt
# fa7749442ea7ab609d1c8c25dc4ba750194e542  Drop Normalize, port relevant parts to Reboot ...
# 220d8b7d4232e0f40456fd3583d1aed02214b3b                                              grunt
# 5fed9b0cd14ee76aa2397fb6a218e3aa4b4aa46                     Merge branch 'v4-dev' of https
# cf235508d8ae881304877e0c4da3258c69de867  Fix container within navbar on smallest breakp...
# b361fa6c120f5f817a70d3f6acbc197aee3844b                      Progress line height (#21805)
# 2b22ebad65c10fb22b5dc55b785a70158005199                     fix segmented buttons (#21716)
# de657afee0172b51979593c0cb0828db094f7f7  Fix gaps between vertical grouped buttons when...
# f7ce09fb8c074d6d9c76eb4d03f8a3c504a94a6                        remove pretty obvi comments
# 0058b233ee69ec27be1ebb8b07957ec8e38cec2  Merge pull request #21774 from vanduynslagerp/...
# 7713c9fc543e7cf067c43ad16076c64cf61e3fe                            Fix missing closing tag
# 167682deb6146e1949cb49baf6e87d350befe3d  Specify card component is necessary for accord...
# a45ca51061288ac9dbb7a62b74c02c699d0a88f  Fix horizontal scrollbar appearing in docs (#2...
# 7751da48232ac4ca1964c819aaf89e78a3f9e64        Update .tag to .badge in migration (#21565)
# b4fe7c69dbe7c878a6b9664585bde70503fbe82        Remove IE9 from SVG images callout (#21566)
# 528516dd6fc886322ee2f7822a8bdb7b74e966e          Add doc example with badge links (#21674)
# eb67091b5f97868e825fcc72dae7a4ad4545463      Update Search input to type="search" (#21617)
# 4684a60e55406a1e918ebcadfe49368fe425ad3  Correct xs and sm breakpoint values in respons...
# 6a5439a8cc7cb3f916efb36bf785bdbd836858d  Remove list-group-item-heading and list-group-...
# 3bc607c1080df2d0bbca03c613aa9e992acb722              Remove unused scss variables (#21579)
# d0f527249ffcad217c47701dab1c7872e85fb34  Add alert divider (<hr>) example in docs (#21673)
# 7af46359b14340265e02243e2f0a9d8aa1fce50                                    Remove   filter
# c82352594ba94ed415003acf79b727b86917d6a                        fixes #21625, closes #21539
# 5848192da592fa6df9503f95e7ef192d43e0861  Merge pull request #21736 from marios-zindilis...
# 7fe8ac84cda0f6e361b0d6a29e86c3adf87f83d                                   Fixed minor typo
# ...                                                                                    ...
# 660f6f18d610ee4b03c0e3bf2823393fc66640b  new buttons, new modal updates around spacing ...
# 0abe21189992f165ff8c7091743bda727adfedd           resolve conflict in patterns from modals
# 8f421eac7d71d3815b394efbefe2abafc30c6a5                          more modal tweaks i think
# 33808447e13f340755861f389d7b4db4557f10c                          started workign on modals
# 71563eb819092894d9c89683c1159612cecaffb  + add a make file which auto builds the bootst...
# b665f157eccc6262c4e2c8c4f7d1b7d76d07eef                                        remove line
# 54c07b5a8f0b1d2295034b73c271da38960cf48                      Merge branch 'master' of http
# c4d17755a6ae16598dc14597a23cb74c223d6a4                                   delete that shit
# 852a71fc9930aa6a27239673359ff6ffacb3813                      Merge branch 'master' of http
# 864bf3b7a855bf1432136d49eb85e14d3040c4b                                              chmod
# 392c9529855f295b93c815a9ea691290e505779                      Merge branch 'master' of http
# 43fc873d9a5a07dd85b9809fc845557d482369a  mucho updato around buttons to fix some stuff ...
# b5c2662e4a07aae82b32bef35eb5b5201dc1917                              fix table-sorter link
# d769f9a6e4419f0588a4c947961ae148fdb3671  update to use latest version of bootstrap, doc...
# 9e28e48a8ef480eff3420896d92b130ae6496a5             updated to remove mention of blueprint
# a627019a53e20851c34b69f6c131afcca371d82                        add to readme + add license
# 5a679e2d1459e7c71b27c28d6823d40257db327     fancy scroll stuff and tiny js roundup/cleanup
# 37bf9fec59dd2ecdd449f8bc680ece12c54fb94                                  clean up org more
# 6c3e709963516a06ad6e723a7bba3fbf5fc1ba2                                  cleanup old stuff
# 447898bf251cfa4cc6b1c8f9cb4c238ad12ef52                             rearranging everything
# 6d5f6743f41c0e62fa7e97dc7faa5d1a47f2456  Changing up boostrap for better grid variable ...
# b8ebe2312e4424a4e40974f0f21dd008064f736  More subtle grid pattern, adding dropdown arro...
# 61317d7b5bb7a8aa11f7ac3fc60efcd359f1606                        Added main topbar and shit.
# 89ba29385d43ffed43b479be566e98ad2eaf1ff    Added compiled CSS file and fixed link to do it
# b3389303d169b4ad8e85292e23fbc1a1be87f1b  Added in mini layout docs; cleaned up layout m...
# c2e1286984152c0a354296d8a9f6fcfc9a14dfd                                More readme changes
# 824ed4e3364bc0b49df89945dd69deff3ee7acd    Updated docs styles for footer; updated readme;
# 95e99a173f50dbbca2478338f42165532289db7  Updated documentation; added stacked forms; cl...
# 9d6acf766728b0bf28fe4d7644a80651f9b0e1c             More documentation and content changes
# 3e0a560723762036b7a2a9d5c99b7b3681cbbc6                                              Build
# bc8638c38bccd4ac7b787ac4d79de4bf2b6a0a0                                              Build
# d79c6466386862e70ce276a094c1897112b7491                                           Deferred
# 777899a747647f3fa839eea4b0bb695d3b60f06                                             Offset
# e50967725e61a5d71c2792131de61dec0520f9c                                              Build
# fbab88110725c6e0b89f6513b9f7cff50320e1e                                              Build
# b9575b9d14399e9426b9eacdd92b3717846c3f2                                               Core
# b4cb0d33731a58384e02ad51e703e7dcb00e424                                              Build
# edc1aa690cceb8396a10fb7dfbb4efe5f5ce26b                                               Docs
# bb62bb3ae771fc57cc62ee14bd10d94680efb4f                                              Build
# 18ca7bfe0f5e3184bf1ed55daf1668702c5577a                                              Build
# 1c29dc1fecc675054762fb1f50a0cdd6b1f0df0                                            Release
# c16f1185493f94d20a9132621abc8106d614d58                                            Release
# cb8a1b3ebf53007637c12c376e3101681f57c02                                               Core
# 7f1da6b91a86ef3f54f4cf16dd87f5afd33c835                                              Build
# 23ed99f4a7e6259daf90af9bce849d1400b11d6                                              Tests
# 5d09b90ca39876d1d9cc29508cfd56e7e3c350e                                               Core
# bbcce68d7b8b8a7a2164a0f7a280ae9daf70b5c                                               Core
# d4f53416e5f74fa98e0c1d66b6f3c285a12f0ce                                              Build
# f5f5433d5ba8bcc1644c8bbb3c1038f97d454bf                                              Tests
# 2e24471c89b80e6208b4987bb76994e64c1e489                                               Core
# 60c0c6f995a4f7584dac5be8fe5eea114a95f69                                         Traversing
# ca2aa2254e805612d12bca457afefa920d0af5c                                              Build
# 160523d30e8f05c1a84592dfaa20eb2f0333708                                              Build
# ...                                                                                    ...
# 373a499d39e35172f9b93af993681e4b5f0908b                           Reduced script transport
# 59e3f57466e508ccfc3e30acfc2aee0c52df83c  Fix requirements and dependencies in README, c...
# 488f68adfe7d593f538aa1791ba35c6ace87a7e  Fix broken link in CONTRIBUTING.md, close gh-1...
# 632711d5cdc184b9d05850c5ca577799d8df399                                      Update Sizzle
# 871218cdf37fa0a3e0457882828648e6a40164a                                  Fix jQuery #13251
# 0290b8ffb05c504d3866a619f282bf795bc01f6                                       Ref cc324abf
# c324abf739669bd2a4669742c994b86c4ad467b                                          Fix #8335
# 96aa9e2709b4ba132b966a0f1a13d0e8eb49b9a                                         Fix #13233
# 06b698813c7d999b6f572d8d00b2691952fdea6                                          No ticket
# f0756b5341eb94ae540de20b9756762dc0a4144                                         Fix #13182
# 0cc33e27beb56e41bea1274bc3b51b1c59af9af                                         Fix #13183
# 6278d40ae86ecd45786eebcb20b72564f2bb53f            Updating the source version to 2.0.0pre
# cc06af007ad2f85b52ee757296d235fcf93337a                       Tagging the 2.0.0b1 release.
# 8cbbd3615d714bdb20fc5c817c0519bb226694c  Let version 1.9 claim jquery.js and jquery-lat...
# 7a2e3c72f0c9833214b17ca81f76e0a9da62495           Simplify release notes generator script.
# 48e1a75c87d13a0c87c6cc58b82bf9746e7eb9c                   de486684 with moar guard for IE6
# ff59f97ac63dd723b6932e7c6e2186735315401                                      Add a comment
# 8ad408f824492cd36a04d7c16df9df6c357ddb4  Fixes #13200 - innerHTML in buildFragment need...
# 1b95797155077e4e670c0bbb2c57815f89769a1                                         Fix #13203
# e486684e3df1988080fd41c97d5f6ab8e6171ed                      Fix f860e0bd Firefox failures
# 75b9ef8d030b0dbf247e826bfbf9585c7dbf98b                                         Fix #13180
# 76723436460c928b0eaf88fe36b575f36049a17                                          No ticket
# a71737fb424a43b9f705098c5be06b1c40f29b6  Leave out the web site, you know where to find...
# 0c1bdde6099a3fa1c16014be090aa6bf1fca8ca            Update copyrights used in file headers.
# ad229c53e50ae9e34ae3bd8ddf1737c538416f6                                      Update Sizzle
# aba2102b2f62d8a92f262fe6611f9df45088b3a  Revert grunt, grunt-contrib-jshint, and grunt-...
# 1a59f78c26eed95f4ad5d69d00578e63754713d                                      Update Sizzle
# ff2d1d3dcd99f7bd45fa312ba91bb1248cb6d55  Fix #12886. Fix map file reference in .min.js ...
# a49ef98d51e8a79ee70d5339a662dead5711165                                        Ref gh-1117
# e6c1ba92faf830d40cafe7a4deb4ad5ab9045fe                                        Ref gh-1117
#
#                                                                                       text  \
# 8816caf26c0acc7067cd5bad9c03cfb54e54979             Docs: Correct typo in issue template\n
# 10ac0e532a9376106c50f0c21a0d0fd0483b700      Build: Drop support for building on Node.j...
# d9145fa15d91ab6c804161ecd892d4d08b71aa2      Tests: Added tests for symbol-separated ta...
# f3a43eff8682b59cec785be6003753fa4b93706      Offset: Eliminate little-used internal fun...
# cb4cd71ef018854f75646270bacd4c4d3da9cde      Build: Use valid ecmaVersion\n    \n    Fi...
# 754e315f8a7760bcdc162712d2be7fee058fdc2      Build: Add most of the dist folder to .esl...
# 3e0a560723762036b7a2a9d5c99b7b3681cbbc6      Build: Drop jscs.json from .npmignore\n   ...
# bc8638c38bccd4ac7b787ac4d79de4bf2b6a0a0      Build: ESLint setup improvements\n    \n  ...
# d79c6466386862e70ce276a094c1897112b7491      Deferred: Stop inventing jQuery.when() res...
# 777899a747647f3fa839eea4b0bb695d3b60f06      Offset: report offset for 0 sized elements...
# e50967725e61a5d71c2792131de61dec0520f9c      Build: Make the @CODE-replacing regex more...
# fbab88110725c6e0b89f6513b9f7cff50320e1e      Build: jQuery Foundation -> JS Foundation\...
# b9575b9d14399e9426b9eacdd92b3717846c3f2      Core: Deprecate jQuery.isArray\n    \n    ...
# b4cb0d33731a58384e02ad51e703e7dcb00e424      Build: Stop testing on Node.js 0.10\n    \...
# edc1aa690cceb8396a10fb7dfbb4efe5f5ce26b      Docs: Remove supported jQuery versions fro...
# bb62bb3ae771fc57cc62ee14bd10d94680efb4f                    Build: Run tests on Node.js 7\n
# 18ca7bfe0f5e3184bf1ed55daf1668702c5577a      Build: Updating the master version to 3.1....
# 1c29dc1fecc675054762fb1f50a0cdd6b1f0df0      Release: fix quotes for releasing on Windo...
# c16f1185493f94d20a9132621abc8106d614d58      Release: add email to .mailmap, update AUT...
# cb8a1b3ebf53007637c12c376e3101681f57c02      Core: remove precautionary variable `ready...
# 7f1da6b91a86ef3f54f4cf16dd87f5afd33c835      Build: Make sourcemap updates in two .repl...
# 23ed99f4a7e6259daf90af9bce849d1400b11d6      Tests: Add test results for Safari 10/iOS ...
# 5d09b90ca39876d1d9cc29508cfd56e7e3c350e      Core: Compress stripAndCollapse\n    \n   ...
# bbcce68d7b8b8a7a2164a0f7a280ae9daf70b5c      Core: rnotwhite -> rhtmlnotwhite and jQuer...
# d4f53416e5f74fa98e0c1d66b6f3c285a12f0ce      Build: Update promises-aplus-tests for com...
# f5f5433d5ba8bcc1644c8bbb3c1038f97d454bf      Tests: Disable a whitespace-setting test i...
# 2e24471c89b80e6208b4987bb76994e64c1e489      Core: expose noConflict in AMD mode\n    \...
# 60c0c6f995a4f7584dac5be8fe5eea114a95f69      Traversing: Let .not(arraylike) pass non-e...
# ca2aa2254e805612d12bca457afefa920d0af5c      Build: Update Sizzle to 2.3.3\n    \n    F...
# 160523d30e8f05c1a84592dfaa20eb2f0333708                    Build: Update Sizzle to 2.3.2\n
# ...                                                                                    ...
# 373a499d39e35172f9b93af993681e4b5f0908b                         Reduced script transport\n
# 59e3f57466e508ccfc3e30acfc2aee0c52df83c      Fix requirements and dependencies in READM...
# 488f68adfe7d593f538aa1791ba35c6ace87a7e      Fix broken link in CONTRIBUTING.md, close ...
# 632711d5cdc184b9d05850c5ca577799d8df399          Update Sizzle: fixes native slice usage\n
# 871218cdf37fa0a3e0457882828648e6a40164a      Fix jQuery #13251: use slice instead of su...
# 0290b8ffb05c504d3866a619f282bf795bc01f6      Ref cc324abf: use acceptData to determine ...
# c324abf739669bd2a4669742c994b86c4ad467b      Fix #8335: Avoid memory leak by never sett...
# 96aa9e2709b4ba132b966a0f1a13d0e8eb49b9a      Fix #13233: re-allow .replaceWith of text ...
# 06b698813c7d999b6f572d8d00b2691952fdea6      No ticket: improve replaceWith testing\n  ...
# f0756b5341eb94ae540de20b9756762dc0a4144                        Fix #13182: update Sizzle\n
# 0cc33e27beb56e41bea1274bc3b51b1c59af9af      Fix #13183: Wrong animation initial value ...
# 6278d40ae86ecd45786eebcb20b72564f2bb53f          Updating the source version to 2.0.0pre\n
# cc06af007ad2f85b52ee757296d235fcf93337a                     Tagging the 2.0.0b1 release.\n
# 8cbbd3615d714bdb20fc5c817c0519bb226694c      Let version 1.9 claim jquery.js and jquery...
# 7a2e3c72f0c9833214b17ca81f76e0a9da62495         Simplify release notes generator script.\n
# 48e1a75c87d13a0c87c6cc58b82bf9746e7eb9c      de486684 with moar guard for IE6\n    (che...
# ff59f97ac63dd723b6932e7c6e2186735315401                                    Add a comment\n
# 8ad408f824492cd36a04d7c16df9df6c357ddb4      Fixes #13200 - innerHTML in buildFragment ...
# 1b95797155077e4e670c0bbb2c57815f89769a1      Fix #13203: delegated events with selector...
# e486684e3df1988080fd41c97d5f6ab8e6171ed      Fix f860e0bd Firefox failures\n    (cherry...
# 75b9ef8d030b0dbf247e826bfbf9585c7dbf98b      Fix #13180: don't delegate into SVG <use>\...
# 76723436460c928b0eaf88fe36b575f36049a17      No ticket: compress event.js\n    (cherry ...
# a71737fb424a43b9f705098c5be06b1c40f29b6      Leave out the web site, you know where to ...
# 0c1bdde6099a3fa1c16014be090aa6bf1fca8ca          Update copyrights used in file headers.\n
# ad229c53e50ae9e34ae3bd8ddf1737c538416f6                                    Update Sizzle\n
# aba2102b2f62d8a92f262fe6611f9df45088b3a      Revert grunt, grunt-contrib-jshint, and gr...
# 1a59f78c26eed95f4ad5d69d00578e63754713d                                    Update Sizzle\n
# ff2d1d3dcd99f7bd45fa312ba91bb1248cb6d55      Fix #12886. Fix map file reference in .min...
# a49ef98d51e8a79ee70d5339a662dead5711165      Ref gh-1117: Use native push for size and ...
# e6c1ba92faf830d40cafe7a4deb4ad5ab9045fe      Ref gh-1117: Don't stop on a falsy value i...
#
#                                                                                      files  \
# 8816caf26c0acc7067cd5bad9c03cfb54e54979  [ .github/ISSUE_TEMPLATE.md | 2 +-\n,  1 file ...
# 10ac0e532a9376106c50f0c21a0d0fd0483b700  [ .travis.yml  |  1 -\n,  Gruntfile.js | 39 ++...
# d9145fa15d91ab6c804161ecd892d4d08b71aa2  [ test/unit/core.js | 27 ++++++++++++++++++---...
# f3a43eff8682b59cec785be6003753fa4b93706  [ src/offset.js | 20 ++++++++++----------\n,  ...
# cb4cd71ef018854f75646270bacd4c4d3da9cde  [ test/node_smoke_tests/.eslintrc.json | 2 +-\...
# 754e315f8a7760bcdc162712d2be7fee058fdc2  [ .eslintignore | 2 ++\n,  1 file changed, 2 i...
# 3e0a560723762036b7a2a9d5c99b7b3681cbbc6  [ .npmignore | 1 -\n,  1 file changed, 1 delet...
# bc8638c38bccd4ac7b787ac4d79de4bf2b6a0a0  [ .eslintrc-browser.json                      ...
# d79c6466386862e70ce276a094c1897112b7491  [ src/deferred.js       | 14 ++++++++------\n,...
# 777899a747647f3fa839eea4b0bb695d3b60f06  [ src/offset.js       | 21 ++++++++-----------...
# e50967725e61a5d71c2792131de61dec0520f9c  [ build/tasks/build.js | 6 +++++-\n,  1 file c...
# fbab88110725c6e0b89f6513b9f7cff50320e1e  [ CONTRIBUTING.md | 4 ++--\n,  Gruntfile.js   ...
# b9575b9d14399e9426b9eacdd92b3717846c3f2  [ src/attributes/val.js   | 4 ++--\n,  src/cor...
# b4cb0d33731a58384e02ad51e703e7dcb00e424  [ .travis.yml  | 1 -\n,  Gruntfile.js | 4 ++--...
# edc1aa690cceb8396a10fb7dfbb4efe5f5ce26b  [ .github/ISSUE_TEMPLATE.md | 2 +-\n,  1 file ...
# bb62bb3ae771fc57cc62ee14bd10d94680efb4f  [ .travis.yml | 1 +\n,  1 file changed, 1 inse...
# 18ca7bfe0f5e3184bf1ed55daf1668702c5577a  [ package.json | 2 +-\n,  1 file changed, 1 in...
# 1c29dc1fecc675054762fb1f50a0cdd6b1f0df0  [ build/release/dist.js | 7 ++++---\n,  1 file...
# c16f1185493f94d20a9132621abc8106d614d58  [ .mailmap    | 1 +\n,  AUTHORS.txt | 2 +-\n, ...
# cb8a1b3ebf53007637c12c376e3101681f57c02  [ src/core/ready-no-deferred.js | 14 ++++-----...
# 7f1da6b91a86ef3f54f4cf16dd87f5afd33c835  [ build/release/cdn.js | 9 +++++----\n,  1 fil...
# 23ed99f4a7e6259daf90af9bce849d1400b11d6  [ test/unit/support.js | 21 ++----------------...
# 5d09b90ca39876d1d9cc29508cfd56e7e3c350e  [ src/core/stripAndCollapse.js | 12 +++++++---...
# bbcce68d7b8b8a7a2164a0f7a280ae9daf70b5c  [ src/ajax.js                  |  8 +++----\n,...
# d4f53416e5f74fa98e0c1d66b6f3c285a12f0ce  [ package.json | 2 +-\n,  1 file changed, 1 in...
# f5f5433d5ba8bcc1644c8bbb3c1038f97d454bf  [ test/unit/css.js | 11 ++++++++++-\n,  1 file...
# 2e24471c89b80e6208b4987bb76994e64c1e489  [ build/tasks/build.js  |  6 +-----\n,  src/ex...
# 60c0c6f995a4f7584dac5be8fe5eea114a95f69  [ src/traversing/findFilter.js | 19 ++++++++++...
# ca2aa2254e805612d12bca457afefa920d0af5c  [ external/sizzle/dist/sizzle.js      | 4 ++--...
# 160523d30e8f05c1a84592dfaa20eb2f0333708  [ external/sizzle/dist/sizzle.js     | 2 +-\n,...
# ...                                                                                    ...
# 373a499d39e35172f9b93af993681e4b5f0908b  [ src/ajax/script.js | 68 +++++++++++++++++---...
# 59e3f57466e508ccfc3e30acfc2aee0c52df83c  [ README.md | 14 ++++++--------\n,  1 file cha...
# 488f68adfe7d593f538aa1791ba35c6ace87a7e  [ CONTRIBUTING.md | 6 +++---\n,  1 file change...
# 632711d5cdc184b9d05850c5ca577799d8df399  [ src/sizzle | 2 +-\n,  1 file changed, 1 inse...
# 871218cdf37fa0a3e0457882828648e6a40164a  [ src/data.js | 2 +-\n,  src/sizzle  | 2 +-\n,...
# 0290b8ffb05c504d3866a619f282bf795bc01f6  [ src/event.js | 4 ++--\n,  1 file changed, 2 ...
# c324abf739669bd2a4669742c994b86c4ad467b  [ src/data.js       |  5 +++++\n,  test/unit/d...
# 96aa9e2709b4ba132b966a0f1a13d0e8eb49b9a  [ src/manipulation.js       | 10 ++--------\n,...
# 06b698813c7d999b6f572d8d00b2691952fdea6  [ test/unit/manipulation.js | 90 +++++++++++++...
# f0756b5341eb94ae540de20b9756762dc0a4144  [ src/sizzle | 2 +-\n,  1 file changed, 1 inse...
# 0cc33e27beb56e41bea1274bc3b51b1c59af9af  [ src/css.js           |  2 +-\n,  src/effects...
# 6278d40ae86ecd45786eebcb20b72564f2bb53f  [ package.json | 2 +-\n,  1 file changed, 1 in...
# cc06af007ad2f85b52ee757296d235fcf93337a  [ package.json | 4 ++--\n,  1 file changed, 2 ...
# 8cbbd3615d714bdb20fc5c817c0519bb226694c  [ build/release.js | 15 ++++++++-------\n,  1 ...
# 7a2e3c72f0c9833214b17ca81f76e0a9da62495  [ build/release-notes.js  | 39 +++++++++++++++...
# 48e1a75c87d13a0c87c6cc58b82bf9746e7eb9c  [ test/unit/event.js | 8 ++++----\n,  1 file c...
# ff59f97ac63dd723b6932e7c6e2186735315401  [ src/manipulation.js | 2 ++\n,  1 file change...
# 8ad408f824492cd36a04d7c16df9df6c357ddb4  [ src/manipulation.js | 10 +++++-----\n,  1 fi...
# 1b95797155077e4e670c0bbb2c57815f89769a1  [ src/event.js       |  4 +++-\n,  test/unit/e...
# e486684e3df1988080fd41c97d5f6ab8e6171ed  [ test/unit/event.js | 7 ++++---\n,  1 file ch...
# 75b9ef8d030b0dbf247e826bfbf9585c7dbf98b  [ src/event.js       | 84 ++++++++++++++++++++...
# 76723436460c928b0eaf88fe36b575f36049a17  [ src/effects.js |   4 +-\n,  src/event.js   |...
# a71737fb424a43b9f705098c5be06b1c40f29b6  [ Gruntfile.js | 2 +-\n,  1 file changed, 1 in...
# 0c1bdde6099a3fa1c16014be090aa6bf1fca8ca  [ Gruntfile.js | 2 +-\n,  src/intro.js | 2 +-\...
# ad229c53e50ae9e34ae3bd8ddf1737c538416f6  [ src/sizzle | 2 +-\n,  1 file changed, 1 inse...
# aba2102b2f62d8a92f262fe6611f9df45088b3a  [ package.json | 6 +++---\n,  1 file changed, ...
# 1a59f78c26eed95f4ad5d69d00578e63754713d  [ src/sizzle | 2 +-\n,  1 file changed, 1 inse...
# ff2d1d3dcd99f7bd45fa312ba91bb1248cb6d55  [ Gruntfile.js | 5 ++++-\n,  1 file changed, 4...
# a49ef98d51e8a79ee70d5339a662dead5711165  [ src/manipulation.js | 4 ++--\n,  1 file chan...
# e6c1ba92faf830d40cafe7a4deb4ad5ab9045f
# 0cc33e27beb56e41bea1274bc3b51b1c59af9af         0
# 6278d40ae86ecd45786eebcb20b72564f2bb53f         0
# cc06af007ad2f85b52ee757296d235fcf93337a         0
# 8cbbd3615d714bdb20fc5c817c0519bb226694c         0
# 7a2e3c72f0c9833214b17ca81f76e0a9da62495         0
# 48e1a75c87d13a0c87c6cc58b82bf9746e7eb9c         0
# ff59f97ac63dd723b6932e7c6e2186735315401         0
# 8ad408f824492cd36a04d7c16df9df6c357ddb4         0
# 1b95797155077e4e670c0bbb2c57815f89769a1         0
# e486684e3df1988080fd41c97d5f6ab8e6171ed         0
# 75b9ef8d030b0dbf247e826bfbf9585c7dbf98b         0
# 76723436460c928b0eaf88fe36b575f36049a17         0
# a71737fb424a43b9f705098c5be06b1c40f29b6         0
# 0c1bdde6099a3fa1c16014be090aa6bf1fca8ca         0
# ad229c53e50ae9e34ae3bd8ddf1737c538416f6         0
# aba2102b2f62d8a92f262fe6611f9df45088b3a         0
# 1a59f78c26eed95f4ad5d69d00578e63754713d         0
# ff2d1d3dcd99f7bd45fa312ba91bb1248cb6d55         0
# a49ef98d51e8a79ee70d5339a662dead5711165         0
# e6c1ba92faf830d40cafe7a4deb4ad5ab9045fe         0
#
# [1191 rows x 18 columns]

# %%
from pandas.tools.plotting import scatter_matrix

scatter_matrix(dfComplete, alpha=0.2, figsize=(10, 10), diagonal='kde')
plt.show()

# %%
clf = GaussianNB()
clf.fit(X_train, y_train)
accuracy = clf.score(X_test, y_test)
"accuracy: %.1f percent"%(100*accuracy)
# Out:
# 'accuracy: 61.1 percent'

# %%
clf = KNeighborsClassifier()
clf.fit(X_train, y_train)
accuracy = clf.score(X_test, y_test)
"accuracy: %.1f percent"%(100*accuracy)
# Out:
# 'accuracy: 54.7 percent'

# %%
scaler = StandardScaler().fit(X_train)
X_train_sc = scaler.transform(X_train)
X_test_sc = scaler.transform(X_test)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
clf = KNeighborsClassifier()
clf.fit(X_train_sc, y_train)
accuracy = clf.score(X_test_sc, y_test)
"accuracy: %.1f percent"%(100*accuracy)
# Out:
# 'accuracy: 87.4 percent'

# %%
clf = LogisticRegression()
clf.fit(X_train, y_train)
accuracy = clf.score(X_test, y_test)
"accuracy: %.1f percent"%(100*accuracy)
# Out:
# 'accuracy: 85.3 percent'

# %%
def accuracy_dist(clfs, X, y, n=10):
    accuracy = np.zeros((n,len(clfs)))
    columns = [clf.__class__.__name__ for clf in clfs]
    for i in range(n):
        X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, random_state=31*i)
        for j in range(len(clfs)):
            clf = clfs[j]
            clf.fit(X_train,y_train)
            accuracy[i][j] = clf.score(X_test,y_test)
    return pd.DataFrame(accuracy, columns=columns, index=range(n))

# %%
accuracy_df = accuracy_dist([GaussianNB(),LinearDiscriminantAnalysis(),LogisticRegression()], X, y)
accuracy_df = pd.concat(
    (accuracy_df, accuracy_dist([KNeighborsClassifier()], StandardScaler().fit_transform(X), y)), axis=1)
accuracy_df.plot(kind='kde', ylim=[0,25])
plt.show()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:387: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\utils\validation.py:420: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
y = {'Count': pd.Series(df.author.value_counts())
     }
author_count = pd.DataFrame(y)
author_count.head()
# Out:
#                           Count
# timmywillisn@gmail.com      245
# m.goleb@gmail.com           221
# markelog@gmail.com          179
# richard.gibson@gmail.com    145
# dave.methvin@gmail.com      135

# %%
plt.figure(figsize=(18,10))
author_count.query('Count > 5').plot(kind='bar', color="blue", alpha=.75)
plt.title("User vs. Number of Activities")
plt.show()

# %%
for index, row in df.iterrows(): 
    textblob = TextBlob(row['text'])
    df.set_value(index, 'polarity', textblob.sentiment.polarity) 
    df.set_value(index, 'subjectivity', textblob.sentiment.subjectivity) 
df.head()
