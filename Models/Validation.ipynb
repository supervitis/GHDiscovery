# %%
import sys
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import urllib
from threading import Thread
from queue import Queue
import math
import requests
import time 
from datetime import timedelta
import pickle
from datetime import datetime

# %%
df = pd.read_csv('Voted/backbone100.csv', index_col=0, encoding="utf-8", delimiter=";")

# %%
df
# Out:
#                                                                                    activity  \
# 4719659298ca50a8c7a19889d90ed8f5c54687d6  Fixes #841, adding upgrading jquery, classname...
# 7e8653905124d878827dc588b3d5e3881090c78e                Merge branch 'master' of github.com
# c84c0f7a63125a739ba413d189c74d35b2b5691c  Shim for AMD underscore test dependency to exp...
# b993441e5e521a03b7cfa86d9a4c741e3c1dd708        Tiny spelling error, no functional changes.
# 232fb0d40bf2d1ec951cd5da95072b2aa43e17a4  change "overriden" to "overridden" in two places.
# 934aba4c6e94ce619cdb7104d8c3491df3d817eb      hasChanged/set should use the same comparison
# 84fc093a2619a8f2f34107f620743e316c3983bd     Allow Collection.at to accept negative indexes
# cb8a12fe162ee28e8d8cd2a7f24ad81bf22a6f27  Merge pull request #1129 from r00k/allow-conte...
# 1675e76cb77a461cf1a609e83349385f4cf5af8a                Merge branch 'master' of github.com
# c644866b4fe6586503f382a4b3d08007548e75e2                      Merge branch 'zepto' of https
# 4138b581950426993d86fe2ed3de5b3ce7f11f20       Merge pull request #430 from reconbot/master
# 4286e0c5ecb01c9a2f8ec7383dddc90f3c3f58a4        Fix #1403 - Trigger "sync" unconditionally.
# ae903628645954921f4fb1d221d7bad4499b8163  Merge pull request #2058 from gsamokovarov/pat...
# 0cdc525961d3fa98e810ffae6bcc8e3838e36d93                          Fixed escapeHTML function
# 7b51c224bc0c10fcc968e6ace3f8fc1b19159215      Merge pull request #1836 from Ore4444/patch-1
# 517624db111cbf3e392a73ae91e590a0cd73c77d    Merge pull request #2681 from carldanley/master
# dba0faad09d40818fb85dcf84c1e7b97543d3108         Collection#invoke should collect arguments
# 9c55b4b3498329eb413bafc737fc1a711fafda98  finished with the simple case for models ... h...
# 716764dc24ec5929abc9ce12e7704a2fa7f11e8e            Add alternative help channels to README
# d7e3d5bf4ad8ebf8482c873d3742a7b21580a59e               Updated to apply on the 0.5.0 branch
# 05089f659595fd2c6514a6fd3fc77fbbc6431f41          Fixing documentation for Collection#fetch
# 4d70b87185db58b3011fd07cee998cfce85e1765                    Declare variable when it's used
# 78b55f7e0ff3eaf68841d19ff4a995da52d4fd02   also tested noevents and eventsAPI code branches
# 744dbafaf8699050d43f53376dfd555d30794010  Fix #2554 - adding clarification about route b...
# 96b20d070751f6ef5e5434c119cc6caef1bad080    Merge pull request #3710 from elgubenis/patch-2
# d04b0f793b95ea1e4c50ac30b76bf65b8630be91  Revert "Fix fetch success callback to not rese...
# 4ab05ad5ff7791504ffafe703f0d8c96e66169d1  check for onpopstate in window instead of wind...
# 7ff4b3a212d50bc24d7826dd8c6a4b1116d0743c        Merge pull request #3602 from megawac/globs
# 3fa14be5a15554c4c02fd31270f0e1bd61203031      one more bound routes example for the road...
# a79f7ac830c0931076b1184378aa5218b710328a        History#atRoot handles params without path.
# ...                                                                                     ...
# 6bb43c1b81c3890548baa23dfefbc7859105e698  fixes #244 -- allow View#events to be defined ...
# 4b4c58f495884ded351b1e3f042044e565ade97e  Merge pull request #3678 from jdalton/not-any-...
# 66d57adb51f1f1a7a29f3d18ac6e820e3abb0d3e        Add comment about overriding _createElement
# 810c535dc076b5366b1e19145682506d7659534e         Only sort when a model is changed or added
# 99eea63c4d36bd57b59e62a06685aa0e651a834e  Merge pull request #2381 from wookiehangover/m...
# 68292f8c78df52b9d8e5a5a3137bbefecca69a45  Merge pull request #3626 from jridgewell/model...
# 16eb3f3d87d547616946d0532425c9e8130d4ff3                                    Minor doc typos
# 21fa0aa6a276fcced53fba384d926c13aa00d6a9  change hashStrip regex to strip bang as well, ...
# 6fb8e7af33d960cf65fc872ae7541a6b7c60d0d7     Query string now parsed if Backbone.qs defined
# f12518ec5c57da6c4b0cc457ae2710d098c306f3                                  bumping to 0.9.10
# ad2ae8e162106c174ddf1b798d39d352511b853b     Pass Collection#fetch options along to refresh
# 9c681906a45d4ec553b1dbe92ae30e7fd3942b53                                              Tests
# 8429118984af34d8728af3a44cce5979316dcd88                ignore favicon.ico in bower package
# 245acb08213c5cbdac8c6f860cdf6883c9720fc8                                 removed unused var
# 01014168004a490f2c89fc6b190a659de1ff8bd6  cleanup oldIE sniff code and iframe creation p...
# 7af332917518ba46152467cc9b81c72bf8b51687       Ensure a search test fails when appropriate.
# 884e4eee55994f9e6f4ff5777d6d30592ff31663  Fixes #1931 -- document Backbone mixing in Events
# be1f2a87c5a66fe8e6733b28869ba5c772969cc7                                    Add ESLint rule
# cdceabe6c469a827333f4611327e3aa9f4edc899  shorter defaults in model ctor, shorter extend...
# edafdebaab14a196bd353eaf99cedbf187aecdfa      Merge pull request #898 from ckorhonen/master
# 4104cada6675bf41deba2540e607255ad6e50088  Merge pull request #3819 from captbaritone/sem...
# 321e2f227252ea17650bd8e9694caf6a3e08eb50  Merge pull request #3127 from alexanderGugel/p...
# 6d880672d11b484793ae3779445400e45dcc5150  Merge pull request #1493 from braddunbar/consi...
# cdce75ef76c3171d8474676060fe29e8c247f6e5                                     fix wrong test
# 5b8f794272a63355b230a9fd960783906581077f            Remove the redundant documentation bits
# a72700921f654407f6cccc3fbbd82cffcdf45493                     Add favicon to test/index.html
# f4cc17e990eac3224350d263e75c623aa1c0a87b                                         Fixed typo
# 315d67b6024a82cdfb3e5be2e120c3d2aaadfaea  Merge pull request #1119 from braddunbar/colle...
# 54c4d7cd47ac93adee24335d6710df764603a026  adds documentation for the automatic nested co...
# 617fc7d056d4b0e2c472b807b62726acc6385485       Merge pull request #887 from nhajratw/master
#
#                                          predicted predicted2   EREN MIRELLA  \
# 4719659298ca50a8c7a19889d90ed8f5c54687d6      Docs       Docs   Core    Core
# 7e8653905124d878827dc588b3d5e3881090c78e      Docs       Docs  Build   build
# c84c0f7a63125a739ba413d189c74d35b2b5691c     Tests      Tests  Tests   Tests
# b993441e5e521a03b7cfa86d9a4c741e3c1dd708      Core       Core   Docs    Core
# 232fb0d40bf2d1ec951cd5da95072b2aa43e17a4      Core       Core   Docs    Core
# 934aba4c6e94ce619cdb7104d8c3491df3d817eb      Core       Core  Build    Core
# 84fc093a2619a8f2f34107f620743e316c3983bd      Core       Core   Core    Core
# cb8a12fe162ee28e8d8cd2a7f24ad81bf22a6f27      Core       Core  Build   build
# 1675e76cb77a461cf1a609e83349385f4cf5af8a      Docs       Docs  Build   build
# c644866b4fe6586503f382a4b3d08007548e75e2      Core       Core  Build   build
# 4138b581950426993d86fe2ed3de5b3ce7f11f20     Tests      Tests  Build   build
# 4286e0c5ecb01c9a2f8ec7383dddc90f3c3f58a4      Core       Core   Core    Core
# ae903628645954921f4fb1d221d7bad4499b8163      Core       Core  Build   build
# 0cdc525961d3fa98e810ffae6bcc8e3838e36d93      Core       Core   Core    Core
# 7b51c224bc0c10fcc968e6ace3f8fc1b19159215      Core       Core  Build   build
# 517624db111cbf3e392a73ae91e590a0cd73c77d      Docs       Docs  Build   build
# dba0faad09d40818fb85dcf84c1e7b97543d3108      Core       Core   Core    Core
# 9c55b4b3498329eb413bafc737fc1a711fafda98      Core       Core   Core    Core
# 716764dc24ec5929abc9ce12e7704a2fa7f11e8e      Core       Core   Docs    Docs
# d7e3d5bf4ad8ebf8482c873d3742a7b21580a59e      Core       Core   Core    Core
# 05089f659595fd2c6514a6fd3fc77fbbc6431f41      Docs       Docs   Docs    Docs
# 4d70b87185db58b3011fd07cee998cfce85e1765      Core       Core   Core    Core
# 78b55f7e0ff3eaf68841d19ff4a995da52d4fd02     Tests      Tests  Tests   Tests
# 744dbafaf8699050d43f53376dfd555d30794010      Core       Core   Docs    Docs
# 96b20d070751f6ef5e5434c119cc6caef1bad080      Core       Core  Build   build
# d04b0f793b95ea1e4c50ac30b76bf65b8630be91      Core       Core   Core    Core
# 4ab05ad5ff7791504ffafe703f0d8c96e66169d1      Core       Core   Core    Core
# 7ff4b3a212d50bc24d7826dd8c6a4b1116d0743c      Core       Core  Build   build
# 3fa14be5a15554c4c02fd31270f0e1bd61203031      Core       Core   Core    Core
# a79f7ac830c0931076b1184378aa5218b710328a      Core       Core   Core    Core
# ...                                            ...        ...    ...     ...
# 6bb43c1b81c3890548baa23dfefbc7859105e698      Core       Core  Build   build
# 4b4c58f495884ded351b1e3f042044e565ade97e      Core       Core   Docs    Docs
# 66d57adb51f1f1a7a29f3d18ac6e820e3abb0d3e      Core       Core   Core    Core
# 810c535dc076b5366b1e19145682506d7659534e      Core      tools  Build   build
# 99eea63c4d36bd57b59e62a06685aa0e651a834e     Tests      Tests  Build   build
# 68292f8c78df52b9d8e5a5a3137bbefecca69a45      Core       Core   Docs    Docs
# 16eb3f3d87d547616946d0532425c9e8130d4ff3      Docs       Docs   Core    Core
# 21fa0aa6a276fcced53fba384d926c13aa00d6a9      Core       Core   Core    Core
# 6fb8e7af33d960cf65fc872ae7541a6b7c60d0d7      Core       Core  Build    Core
# f12518ec5c57da6c4b0cc457ae2710d098c306f3      Core       Core   Core    Core
# ad2ae8e162106c174ddf1b798d39d352511b853b      Core       Core  Tests   Tests
# 9c681906a45d4ec553b1dbe92ae30e7fd3942b53     Tests      Tests   Core    Core
# 8429118984af34d8728af3a44cce5979316dcd88      Core       Core   Core    Core
# 245acb08213c5cbdac8c6f860cdf6883c9720fc8      Core       Core   Core    Core
# 01014168004a490f2c89fc6b190a659de1ff8bd6      Core       Core   Core    Core
# 7af332917518ba46152467cc9b81c72bf8b51687     Tests      Tests   Docs    Docs
# 884e4eee55994f9e6f4ff5777d6d30592ff31663      Docs       Docs  Build    Core
# be1f2a87c5a66fe8e6733b28869ba5c772969cc7      Core       Core   Core    Core
# cdceabe6c469a827333f4611327e3aa9f4edc899      Core       Core  Build   build
# edafdebaab14a196bd353eaf99cedbf187aecdfa      Docs       Docs  Build   build
# 4104cada6675bf41deba2540e607255ad6e50088     Tests      Tests  Build   build
# 321e2f227252ea17650bd8e9694caf6a3e08eb50      Core       Core  Build   build
# 6d880672d11b484793ae3779445400e45dcc5150      Core       Core  Tests   Tests
# cdce75ef76c3171d8474676060fe29e8c247f6e5     Tests      Tests   Docs    Docs
# 5b8f794272a63355b230a9fd960783906581077f      Docs       Docs  Tests   Tests
# a72700921f654407f6cccc3fbbd82cffcdf45493     Tests      Tests   Docs    Docs
# f4cc17e990eac3224350d263e75c623aa1c0a87b      Core       Core  Build   build
# 315d67b6024a82cdfb3e5be2e120c3d2aaadfaea      Core       Core   Core    Core
# 54c4d7cd47ac93adee24335d6710df764603a026      Docs       Docs  Build   build
# 617fc7d056d4b0e2c472b807b62726acc6385485      Core       Core  Build  build
#
#                                             SANJA
# 4719659298ca50a8c7a19889d90ed8f5c54687d6     Core
# 7e8653905124d878827dc588b3d5e3881090c78e    merge
# c84c0f7a63125a739ba413d189c74d35b2b5691c    Tests
# b993441e5e521a03b7cfa86d9a4c741e3c1dd708     Docs
# 232fb0d40bf2d1ec951cd5da95072b2aa43e17a4     Docs
# 934aba4c6e94ce619cdb7104d8c3491df3d817eb     Core
# 84fc093a2619a8f2f34107f620743e316c3983bd     Core
# cb8a12fe162ee28e8d8cd2a7f24ad81bf22a6f27    merge
# 1675e76cb77a461cf1a609e83349385f4cf5af8a    merge
# c644866b4fe6586503f382a4b3d08007548e75e2    merge
# 4138b581950426993d86fe2ed3de5b3ce7f11f20    merge
# 4286e0c5ecb01c9a2f8ec7383dddc90f3c3f58a4     Core
# ae903628645954921f4fb1d221d7bad4499b8163    merge
# 0cdc525961d3fa98e810ffae6bcc8e3838e36d93     Core
# 7b51c224bc0c10fcc968e6ace3f8fc1b19159215    merge
# 517624db111cbf3e392a73ae91e590a0cd73c77d    merge
# dba0faad09d40818fb85dcf84c1e7b97543d3108     Core
# 9c55b4b3498329eb413bafc737fc1a711fafda98     Core
# 716764dc24ec5929abc9ce12e7704a2fa7f11e8e     Docs
# d7e3d5bf4ad8ebf8482c873d3742a7b21580a59e     Core
# 05089f659595fd2c6514a6fd3fc77fbbc6431f41     Docs
# 4d70b87185db58b3011fd07cee998cfce85e1765     Core
# 78b55f7e0ff3eaf68841d19ff4a995da52d4fd02    Tests
# 744dbafaf8699050d43f53376dfd555d30794010     Docs
# 96b20d070751f6ef5e5434c119cc6caef1bad080    merge
# d04b0f793b95ea1e4c50ac30b76bf65b8630be91     Core
# 4ab05ad5ff7791504ffafe703f0d8c96e66169d1     Core
# 7ff4b3a212d50bc24d7826dd8c6a4b1116d0743c    merge
# 3fa14be5a15554c4c02fd31270f0e1bd61203031     Core
# a79f7ac830c0931076b1184378aa5218b710328a     Core
# ...                                           ...
# 6bb43c1b81c3890548baa23dfefbc7859105e698    merge
# 4b4c58f495884ded351b1e3f042044e565ade97e     Docs
# 66d57adb51f1f1a7a29f3d18ac6e820e3abb0d3e     Core
# 810c535dc076b5366b1e19145682506d7659534e    merge
# 99eea63c4d36bd57b59e62a06685aa0e651a834e    merge
# 68292f8c78df52b9d8e5a5a3137bbefecca69a45     Docs
# 16eb3f3d87d547616946d0532425c9e8130d4ff3     Core
# 21fa0aa6a276fcced53fba384d926c13aa00d6a9     Core
# 6fb8e7af33d960cf65fc872ae7541a6b7c60d0d7  compile
# f12518ec5c57da6c4b0cc457ae2710d098c306f3     Core
# ad2ae8e162106c174ddf1b798d39d352511b853b    Tests
# 9c681906a45d4ec553b1dbe92ae30e7fd3942b53     Core
# 8429118984af34d8728af3a44cce5979316dcd88     Core
# 245acb08213c5cbdac8c6f860cdf6883c9720fc8     Core
# 01014168004a490f2c89fc6b190a659de1ff8bd6     Core
# 7af332917518ba46152467cc9b81c72bf8b51687     Docs
# 884e4eee55994f9e6f4ff5777d6d30592ff31663     Core
# be1f2a87c5a66fe8e6733b28869ba5c772969cc7     Core
# cdceabe6c469a827333f4611327e3aa9f4edc899    merge
# edafdebaab14a196bd353eaf99cedbf187aecdfa    merge
# 4104cada6675bf41deba2540e607255ad6e50088    merge
# 321e2f227252ea17650bd8e9694caf6a3e08eb50    merge
# 6d880672d11b484793ae3779445400e45dcc5150    Tests
# cdce75ef76c3171d8474676060fe29e8c247f6e5     Docs
# 5b8f794272a63355b230a9fd960783906581077f    Tests
# a72700921f654407f6cccc3fbbd82cffcdf45493     Docs
# f4cc17e990eac3224350d263e75c623aa1c0a87b    merge
# 315d67b6024a82cdfb3e5be2e120c3d2aaadfaea     Core
# 54c4d7cd47ac93adee24335d6710df764603a026    merge
# 617fc7d056d4b0e2c472b807b62726acc6385485    merge
#
# [100 rows x 6 columns]

# %%
df = pd.read_csv('Voted/backbone100.csv', index_col=0, encoding="utf-8", delimiter=";")
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('test', 'Tests')
df[['EREN']] = df[['EREN']].replace('Test', 'Tests')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('doc', 'Docs')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('docs', 'Docs')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('documentation', 'Docs')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('src', 'Core')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('core', 'Core')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('development', 'Core')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('build', 'Build')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('build ', 'Build')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('compile', 'Build')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('tools', 'Build')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('merge', 'Build')
df.head()

# %%
df['vote'] = np.where((df.EREN == df.MIRELLA) & (df.EREN != df.SANJA), df.EREN, df.vote)
df['vote'] = np.where((df.SANJA == df.MIRELLA) & (df.EREN != df.SANJA), df.SANJA, df.vote)
df['vote'] = np.where((df.SANJA == df.EREN) & (df.EREN != df.MIRELLA), df.SANJA, df.vote)
df['vote'] = np.where((df.EREN == df.MIRELLA) & (df.EREN == df.SANJA), df.EREN, df.vote)
df['check'] = np.where((df.EREN != df.MIRELLA) & (df.EREN != df.SANJA) & (df.MIRELLA != df.SANJA),"true","false" )
for i in range(1,10):
    classCount = df.check.value_counts()
print(classCount)
# Out:
# false    100
# Name: check, dtype: int64

# %%
def accuracy_dist(name, x, y, df, dfX, dfY):
    print("----")
    print(name)
    correct = len(df[dfX.isin([x])][dfY.isin([y])])
    wrong = len(df[dfX.isin([x])][~dfY.isin([y])]) + len(df[~dfX.isin([x])][dfY.isin([y])])
    print(correct/(correct + wrong))
    print("Same")
    print(correct)
    print("Different")
    print(wrong)
    print("----")
print("AGAINST FIRST MODEL")
accuracy_dist("CORE",  "Core", "Core", df, df.predicted, df.vote)
accuracy_dist("BUILD", "Build", "Build", df, df.predicted, df.vote)
accuracy_dist("DOCS",  "Docs", "Docs", df, df.predicted, df.vote)
accuracy_dist("TEST", "Tests", "Tests",  df, df.predicted, df.vote)
print("AGAINST SECOND MODEL")
accuracy_dist("CORE",  "Core", "Core", df, df.predicted2, df.vote)
accuracy_dist("BUILD", "Build", "Build", df, df.predicted2, df.vote)
accuracy_dist("DOCS",  "Docs", "Docs", df, df.predicted2, df.vote)
accuracy_dist("TEST", "Tests", "Tests",  df, df.predicted2, df.vote)

# %%
# Out:
# AGAINST FIRST MODEL
# ----
# CORE
# 0.48
# Same
# 36
# Different
# 39
# ----
# ----
# BUILD
# 0.030303030303030304
# Same
# 1
# Different
# 32
# ----
# ----
# DOCS
# 0.15625
# Same
# 5
# Different
# 27
# ----
# ----
# TEST
# 0.2
# Same
# 3
# Different
# 12
# ----
# AGAINST SECOND MODEL
# ----
# CORE
# 0.47297297297297297
# Same
# 35
# Different
# 39
# ----
# ----
# BUILD
# 0.029411764705882353
# Same
# 1
# Different
# 33
# ----
# ----
# DOCS
# 0.15151515151515152
# Same
# 5
# Different
# 28
# ----
# ----
# TEST
# 0.2
# Same
# 3
# Different
# 12
# ----
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
df = pd.read_csv('Voted/bootstrap100.csv', index_col=0, encoding="utf-8", delimiter=",")
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('test', 'Tests')
df[['EREN']] = df[['EREN']].replace('Test', 'Tests')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('doc', 'Docs')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('docs', 'Docs')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('documentation', 'Docs')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('src', 'Core')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('core', 'Core')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('development', 'Core')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('develop', 'Core')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('build', 'Build')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('build ', 'Build')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('compile', 'Build')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('tools', 'Build')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('merge', 'Build')
df.head()
# Out:
#                                                                                    activity  \
# 3c2f82f469be4792e85eb73fd1e3b882dcadd48d  recomment out the moz stuff for progress bars ...
# 892f6e35b855211b28a0f68354dec16f94ad2167                Merge branch 'master' of github.com
# 3ad9febe04c9ded7a1beb6fda578a4db6c444ba8                        Edited README.md via GitHub
# 1759569dbe8d9ebbcfc4bc1b7f87c3fe3e79e4d1                                             Travis
# 50df64797c3931b8bf3f289e23b107936663ff41                                              https
#
#                                          predicted predicted2   EREN MIRELLA  \
# 3c2f82f469be4792e85eb73fd1e3b882dcadd48d      Core       Core   Docs    Docs
# 892f6e35b855211b28a0f68354dec16f94ad2167      Core       Core  Build   Build
# 3ad9febe04c9ded7a1beb6fda578a4db6c444ba8      Core       Core   Docs    Docs
# 1759569dbe8d9ebbcfc4bc1b7f87c3fe3e79e4d1      Core       Core   Core    Core
# 50df64797c3931b8bf3f289e23b107936663ff41      Core       Core   Docs    Docs
#
#                                           SANJA
# 3c2f82f469be4792e85eb73fd1e3b882dcadd48d   Docs
# 892f6e35b855211b28a0f68354dec16f94ad2167  Build
# 3ad9febe04c9ded7a1beb6fda578a4db6c444ba8   Docs
# 1759569dbe8d9ebbcfc4bc1b7f87c3fe3e79e4d1   Core
# 50df64797c3931b8bf3f289e23b107936663ff41   Docs

# %%
df['vote'] = "false"
df['vote'] = np.where((df.EREN == df.MIRELLA) & (df.EREN != df.SANJA), df.EREN, df.vote)
df['vote'] = np.where((df.SANJA == df.MIRELLA) & (df.EREN != df.SANJA), df.SANJA, df.vote)
df['vote'] = np.where((df.SANJA == df.EREN) & (df.EREN != df.MIRELLA), df.SANJA, df.vote)
df['vote'] = np.where((df.EREN == df.MIRELLA) & (df.EREN == df.SANJA), df.EREN, df.vote)
df['check'] = np.where((df.EREN != df.MIRELLA) & (df.EREN != df.SANJA) & (df.MIRELLA != df.SANJA),"true","false" )
for i in range(1,10):
    classCount = df.check.value_counts()
print(classCount)
# Out:
# false    100
# Name: check, dtype: int64

# %%
for i in range(1,10):
    classCount = df.EREN.value_counts()
print(classCount)
for i in range(1,10):
    classCount = df.MIRELLA.value_counts()
print(classCount)
for i in range(1,10):
    classCount = df.SANJA.value_counts()
print(classCount)
# Out:
# Core     48
# Docs     25
# Build    25
# Tests     2
# Name: EREN, dtype: int64
# Core     59
# Docs     22
# Build    17
# Tests     2
# Name: MIRELLA, dtype: int64
# Core     50
# Docs     25
# Build    23
# Tests     2
# Name: SANJA, dtype: int64

# %%
df
# Out:
#                                                                                    activity  \
# 3c2f82f469be4792e85eb73fd1e3b882dcadd48d  recomment out the moz stuff for progress bars ...
# 892f6e35b855211b28a0f68354dec16f94ad2167                Merge branch 'master' of github.com
# 3ad9febe04c9ded7a1beb6fda578a4db6c444ba8                        Edited README.md via GitHub
# 1759569dbe8d9ebbcfc4bc1b7f87c3fe3e79e4d1                                             Travis
# 50df64797c3931b8bf3f289e23b107936663ff41                                              https
# e589cdbfe9421d58f6c3ff4d2820056983df6def  Put that new var to use to match form group ad...
# 31ab07b32aeabd8df3c7430dbb31d03b474360f5             Merge branch '3.0.0-wip' of github.com
# 444973e54d56b7d722978ea398f2910fbbfe6b69                                        Fixes #8605
# b9aad573f9400693f6bcbf9af5374a93228dbe6f                                             Travis
# 1b8f00b3893cdb503decc87802440df495f4d3cb  Merge pull request #15292 from twbs/customize-...
# 57b59fcfd02799915d9bf4fc19f30cfa71b2d66c  Merge pull request #10353 from rwillrich/ignor...
# f9db33d7dbc464a71d2143e3dd323fd7db47773b                               automatic grunt dist
# ddafa9a0bbc9cd89376a642ba9746ec668f6ce21                              Attempts to fix #8645
# 57fe8ac84cda0f6e361b0d6a29e86c3adf87f83d                                   Fixed minor typo
# ed06fd0936ba2c03ecb052eb65a89c5be94b1b8d  Merge pull request #13820 from twbs/bump-load-...
# a3cba92edd6f778c061ff40dc34a5e939342d31c                     rejigger the customizer layout
# 3b3dbd7229f53eb71759def4eca90dfd7a2699f8                    Merge branch '2.0-wip' of https
# 1e9f0ab99ea07bab6b66b4fd36b5814c61b3c0e6                                              grunt
# 732e4196fb9dc76ce2250edcdc6c1b45bcbe5d2e                           Remove commented out CSS
# 4b6e1b6754b8732fd71497997a43a5f92f0c8bcf                                         grunt dist
# c9597b1c540c472dea82a7edd91ffb356b0d327f    Fix doc for tooltips and popover method dispose
# 1f329f8f17aa989eabc6e94bdcab93e69ef0e463  the justified nav bug is still present in Safa...
# b4895a0d6dc493f17fe9092db4debe44182d42ac  Merge pull request #14336 from michaeljayt/pat...
# 245ebda651fcdbc9687c1a436e8bbe3916354da6                                      nuke the .col
# a9b86cbfde788b2ffc066353b4f77c45345c0e78                            Merge branch 'pr/11138'
# 0cbffb3bcbc60582e90711e0b5ac36e2df51f7d8                             Delete glphyicons.less
# e21b6459ad162296f94b2d9aeaf8807a153d3c8a                            fixes tooltip('toggle')
# daa21c36348308367d3616a1374363ebcaaeac0c                            start in on new headers
# 5c803b656ce1dcc2a6335b949b0566a50d74c32d                               update docs to match
# 7872ca69bee17010942ca61bed753651446b5f41  Merge pull request #15890 from StevenBlack/hea...
# ...                                                                                     ...
# 6aa15eb01f2e50e394ae172ff41e5bc0583de6da         Support for left-opening dropdown submenus
# 6c221d65e3b73a8ad0270ee2876260177df68620             Merge branch '2.0.3-wip' of github.com
# 46a524f302ab8bff724ae8d93fe4c5d4beaf1840    Merge pull request #17058 from kkirsche/patch-6
# 5f35ce2095f03bc97c5200d10615666c86fe345f                       .page>{a,span => .page-link}
# ba202d77baa35125a521224d9a55ec013fc3ccfa   Merge pull request #3104 from iamnirav/2.0.3-wip
# f76c222089551c64f24d54cfb2888db454d0006c                 Update examples after grid changes
# 01361951e695d4313131ba85c9517cbc50000439                       address #10343 more directly
# c7ffe6edc894b00db16bc4386f421a3d8efadd50                         Add space on navbar button
# 3fb41d240065d40c084ff9cc5c9f856d2d947577                             link to Uglify-js repo
# 30d8eb3ed572f2a91c0d4de1326779dec88cd911  Merge branch 'blakeembrey-dropdown-selectors' ...
# b67cba2b4d1fe2b7a9685bb5c80eb77ee64e6ab1  make WP8 device-width hack code fully consiste...
# a87ea9345beced2cea2009362c9aead9a2510e09                               Add IDs, adjust text
# 21a7de7a18707a7cec559cb419fac251feea405d                            patch highlighting hint
# 880f43221d0f0820d208afcb05f295c6a0afa27a             tweak Gruntfile.js so it passes jshint
# fc96bc8bba0687fb5845bffc72eb048535583499                                        rebuild doi
# 5663833bfc3ea815ee9fa82a53e1bd3e3f14f585                                  Restore .btn-info
# d4b1bfd667631f1d96a0b6ec4e734338e5b8811d                                              grunt
# 6fb81f155b8e16a16e49b3fb2c0d38d516883f55                 more space below links on homepage
# 2c1c885ed4978900fb2a5e3310a428fd72b89c12                               automatic grunt dist
# 0cb2866409c674f834f8e0f4e204c3c3331abbcd  fix reponsive 1200+ media query to resolve mis...
# 8d806b0ae5f618065a466cdfc9853020fb72cd9d  Document .alert-dismissible .close restriction...
# b5bf4334caed20615e0f2c0ab9753bd83fd4199d                   Add aria-pressed=true to example
# f6831e4d4f146b97c5a7047f1ae170b4f2dea1d1         Merge pull request #19089 from Quy/patch-5
# b9c572184f18a5c228dedd41e3b93b94c8d71b7b                  add .btn-xs to .btn-group example
# b7ac009a527869dc381b9e4c2272c822d85d2b1c  Remove #8350's reset for number inputs since N...
# 98df9495cc92bd710a6d55c4d535da7aaf730031                             remove dupe border-box
# abdf41f5f3ad682e57a60f662e7a6ed56b4e3e54                       Add a local jQuery fallback.
# 7b06538c911f40c46ae67b0c0df7afdfbcb5d00a        Merge pull request #11723 from stof/patch-1
# 74a516a9b10affa77e17344753d7aba94e260170    Merge branch 'v4-dev' into v4-modal-footer-btns
# 9234bb630bd02a306f1f22d06ce33826a40480e6                     Bump year in jumbotron example
#
#                                          predicted predicted2   EREN MIRELLA  \
# 3c2f82f469be4792e85eb73fd1e3b882dcadd48d      Core       Core   Docs    Docs
# 892f6e35b855211b28a0f68354dec16f94ad2167      Core       Core  Build   Build
# 3ad9febe04c9ded7a1beb6fda578a4db6c444ba8      Core       Core   Docs    Docs
# 1759569dbe8d9ebbcfc4bc1b7f87c3fe3e79e4d1      Core       Core   Core    Core
# 50df64797c3931b8bf3f289e23b107936663ff41      Core       Core   Docs    Docs
# e589cdbfe9421d58f6c3ff4d2820056983df6def      Core       Core   Core    Core
# 31ab07b32aeabd8df3c7430dbb31d03b474360f5      Core       Core  Build   Build
# 444973e54d56b7d722978ea398f2910fbbfe6b69      Core       Core   Core    Core
# b9aad573f9400693f6bcbf9af5374a93228dbe6f      Core      Tests  Tests   Tests
# 1b8f00b3893cdb503decc87802440df495f4d3cb      Core       Core  Build   Build
# 57b59fcfd02799915d9bf4fc19f30cfa71b2d66c      Docs       Docs  Build   Build
# f9db33d7dbc464a71d2143e3dd323fd7db47773b      Core       Core  Build    Core
# ddafa9a0bbc9cd89376a642ba9746ec668f6ce21      Core       Core   Docs    Docs
# 57fe8ac84cda0f6e361b0d6a29e86c3adf87f83d      Core       Core   Docs    Docs
# ed06fd0936ba2c03ecb052eb65a89c5be94b1b8d      Core       Core  Build   Build
# a3cba92edd6f778c061ff40dc34a5e939342d31c      Core       Core   Docs    Docs
# 3b3dbd7229f53eb71759def4eca90dfd7a2699f8      Docs       Docs  Build   Build
# 1e9f0ab99ea07bab6b66b4fd36b5814c61b3c0e6      Core       Core   Core    Core
# 732e4196fb9dc76ce2250edcdc6c1b45bcbe5d2e      Core       Core   Docs    Docs
# 4b6e1b6754b8732fd71497997a43a5f92f0c8bcf      Core       Core  Build    Core
# c9597b1c540c472dea82a7edd91ffb356b0d327f      Docs       Docs   Core    Core
# 1f329f8f17aa989eabc6e94bdcab93e69ef0e463      Core       Core   Core    Core
# b4895a0d6dc493f17fe9092db4debe44182d42ac      Core       Core  Build   Build
# 245ebda651fcdbc9687c1a436e8bbe3916354da6   Release       Core   Core    Core
# a9b86cbfde788b2ffc066353b4f77c45345c0e78      Docs       Docs   Core    Core
# 0cbffb3bcbc60582e90711e0b5ac36e2df51f7d8      Core       Core   Docs    Core
# e21b6459ad162296f94b2d9aeaf8807a153d3c8a      Core       Core   Core    Core
# daa21c36348308367d3616a1374363ebcaaeac0c      Core       Core   Core    Core
# 5c803b656ce1dcc2a6335b949b0566a50d74c32d      Docs       Docs   Docs    Docs
# 7872ca69bee17010942ca61bed753651446b5f41      Docs       Docs  Build   Build
# ...                                            ...        ...    ...     ...
# 6aa15eb01f2e50e394ae172ff41e5bc0583de6da      Core       Core   Docs    Docs
# 6c221d65e3b73a8ad0270ee2876260177df68620      Docs       Docs  Build   Build
# 46a524f302ab8bff724ae8d93fe4c5d4beaf1840      Core       Core  Build   Build
# 5f35ce2095f03bc97c5200d10615666c86fe345f      Core       Core   Core    Core
# ba202d77baa35125a521224d9a55ec013fc3ccfa      Core       Core  Build   Build
# f76c222089551c64f24d54cfb2888db454d0006c      Core       Core   Core    Core
# 01361951e695d4313131ba85c9517cbc50000439      Core       Core   Core    Core
# c7ffe6edc894b00db16bc4386f421a3d8efadd50      Core       Core   Core    Core
# 3fb41d240065d40c084ff9cc5c9f856d2d947577      Core       Core   Docs    Docs
# 30d8eb3ed572f2a91c0d4de1326779dec88cd911      Core       Core  Build   Build
# b67cba2b4d1fe2b7a9685bb5c80eb77ee64e6ab1      Docs       Docs   Core    Core
# a87ea9345beced2cea2009362c9aead9a2510e09      Core       Core   Docs    Docs
# 21a7de7a18707a7cec559cb419fac251feea405d      Core       Core   Docs    Docs
# 880f43221d0f0820d208afcb05f295c6a0afa27a      Core       Core   Core    Core
# fc96bc8bba0687fb5845bffc72eb048535583499      Core       Core   Core    Core
# 5663833bfc3ea815ee9fa82a53e1bd3e3f14f585      Core       Core   Core    Core
# d4b1bfd667631f1d96a0b6ec4e734338e5b8811d      Core       Core   Core    Core
# 6fb81f155b8e16a16e49b3fb2c0d38d516883f55      Core       Core   Core    Core
# 2c1c885ed4978900fb2a5e3310a428fd72b89c12      Core       Core  Build    Core
# 0cb2866409c674f834f8e0f4e204c3c3331abbcd      Core       Core   Core    Core
# 8d806b0ae5f618065a466cdfc9853020fb72cd9d      Docs       Docs   Docs    Docs
# b5bf4334caed20615e0f2c0ab9753bd83fd4199d      Core       Core   Core    Core
# f6831e4d4f146b97c5a7047f1ae170b4f2dea1d1      Core       Core  Build   Build
# b9c572184f18a5c228dedd41e3b93b94c8d71b7b      Core       Core   Core    Core
# b7ac009a527869dc381b9e4c2272c822d85d2b1c      Core       Core   Core    Core
# 98df9495cc92bd710a6d55c4d535da7aaf730031      Core       Core   Core    Core
# abdf41f5f3ad682e57a60f662e7a6ed56b4e3e54     Tests       Core   Core    Core
# 7b06538c911f40c46ae67b0c0df7afdfbcb5d00a      Core       Core  Build   Build
# 74a516a9b10affa77e17344753d7aba94e260170      Core       Core  Build   Build
# 9234bb630bd02a306f1f22d06ce33826a40480e6      Core       Core   Docs    Docs
#
#                                           SANJA   vote  check
# 3c2f82f469be4792e85eb73fd1e3b882dcadd48d   Docs   Docs  false
# 892f6e35b855211b28a0f68354dec16f94ad2167  Build  Build  false
# 3ad9febe04c9ded7a1beb6fda578a4db6c444ba8   Docs   Docs  false
# 1759569dbe8d9ebbcfc4bc1b7f87c3fe3e79e4d1   Core   Core  false
# 50df64797c3931b8bf3f289e23b107936663ff41   Docs   Docs  false
# e589cdbfe9421d58f6c3ff4d2820056983df6def   Core   Core  false
# 31ab07b32aeabd8df3c7430dbb31d03b474360f5  Build  Build  false
# 444973e54d56b7d722978ea398f2910fbbfe6b69   Core   Core  false
# b9aad573f9400693f6bcbf9af5374a93228dbe6f  Tests  Tests  false
# 1b8f00b3893cdb503decc87802440df495f4d3cb  Build  Build  false
# 57b59fcfd02799915d9bf4fc19f30cfa71b2d66c  Build  Build  false
# f9db33d7dbc464a71d2143e3dd323fd7db47773b  Build  Build  false
# ddafa9a0bbc9cd89376a642ba9746ec668f6ce21   Docs   Docs  false
# 57fe8ac84cda0f6e361b0d6a29e86c3adf87f83d   Docs   Docs  false
# ed06fd0936ba2c03ecb052eb65a89c5be94b1b8d  Build  Build  false
# a3cba92edd6f778c061ff40dc34a5e939342d31c   Docs   Docs  false
# 3b3dbd7229f53eb71759def4eca90dfd7a2699f8  Build  Build  false
# 1e9f0ab99ea07bab6b66b4fd36b5814c61b3c0e6   Core   Core  false
# 732e4196fb9dc76ce2250edcdc6c1b45bcbe5d2e   Docs   Docs  false
# 4b6e1b6754b8732fd71497997a43a5f92f0c8bcf  Build  Build  false
# c9597b1c540c472dea82a7edd91ffb356b0d327f   Core   Core  false
# 1f329f8f17aa989eabc6e94bdcab93e69ef0e463   Core   Core  false
# b4895a0d6dc493f17fe9092db4debe44182d42ac  Build  Build  false
# 245ebda651fcdbc9687c1a436e8bbe3916354da6   Core   Core  false
# a9b86cbfde788b2ffc066353b4f77c45345c0e78   Core   Core  false
# 0cbffb3bcbc60582e90711e0b5ac36e2df51f7d8   Docs   Docs  false
# e21b6459ad162296f94b2d9aeaf8807a153d3c8a   Core   Core  false
# daa21c36348308367d3616a1374363ebcaaeac0c   Core   Core  false
# 5c803b656ce1dcc2a6335b949b0566a50d74c32d   Docs   Docs  false
# 7872ca69bee17010942ca61bed753651446b5f41  Build  Build  false
# ...                                         ...    ...    ...
# 6aa15eb01f2e50e394ae172ff41e5bc0583de6da   Docs   Docs  false
# 6c221d65e3b73a8ad0270ee2876260177df68620  Build  Build  false
# 46a524f302ab8bff724ae8d93fe4c5d4beaf1840  Build  Build  false
# 5f35ce2095f03bc97c5200d10615666c86fe345f   Core   Core  false
# ba202d77baa35125a521224d9a55ec013fc3ccfa  Build  Build  false
# f76c222089551c64f24d54cfb2888db454d0006c   Core   Core  false
# 01361951e695d4313131ba85c9517cbc50000439   Core   Core  false
# c7ffe6edc894b00db16bc4386f421a3d8efadd50   Core   Core  false
# 3fb41d240065d40c084ff9cc5c9f856d2d947577   Docs   Docs  false
# 30d8eb3ed572f2a91c0d4de1326779dec88cd911  Build  Build  false
# b67cba2b4d1fe2b7a9685bb5c80eb77ee64e6ab1   Core   Core  false
# a87ea9345beced2cea2009362c9aead9a2510e09   Docs   Docs  false
# 21a7de7a18707a7cec559cb419fac251feea405d   Docs   Docs  false
# 880f43221d0f0820d208afcb05f295c6a0afa27a   Core   Core  false
# fc96bc8bba0687fb5845bffc72eb048535583499   Core   Core  false
# 5663833bfc3ea815ee9fa82a53e1bd3e3f14f585   Core   Core  false
# d4b1bfd667631f1d96a0b6ec4e734338e5b8811d   Core   Core  false
# 6fb81f155b8e16a16e49b3fb2c0d38d516883f55   Core   Core  false
# 2c1c885ed4978900fb2a5e3310a428fd72b89c12  Build  Build  false
# 0cb2866409c674f834f8e0f4e204c3c3331abbcd   Core   Core  false
# 8d806b0ae5f618065a466cdfc9853020fb72cd9d   Docs   Docs  false
# b5bf4334caed20615e0f2c0ab9753bd83fd4199d   Core   Core  false
# f6831e4d4f146b97c5a7047f1ae170b4f2dea1d1  Build  Build  false
# b9c572184f18a5c228dedd41e3b93b94c8d71b7b   Core   Core  false
# b7ac009a527869dc381b9e4c2272c822d85d2b1c   Core   Core  false
# 98df9495cc92bd710a6d55c4d535da7aaf730031   Core   Core  false
# abdf41f5f3ad682e57a60f662e7a6ed56b4e3e54   Core   Core  false
# 7b06538c911f40c46ae67b0c0df7afdfbcb5d00a  Build  Build  false
# 74a516a9b10affa77e17344753d7aba94e260170  Build  Build  false
# 9234bb630bd02a306f1f22d06ce33826a40480e6   Docs   Docs  false
#
# [100 rows x 8 columns]

# %%
def accuracy_dist(name, x, y, df, dfX, dfY):
    print("----")
    print(name)
    correct = len(df[dfX.isin([x])][dfY.isin([y])])
    wrong = len(df[dfX.isin([x])][~dfY.isin([y])]) + len(df[~dfX.isin([x])][dfY.isin([y])])
    print(correct/(correct + wrong))
    print("Same")
    print(correct)
    print("Different")
    print(wrong)
    print("----")
print("AGAINST FIRST MODEL")
accuracy_dist("CORE",  "Core", "Core", df, df.predicted, df.vote)
accuracy_dist("BUILD", "Build", "Build", df, df.predicted, df.vote)
accuracy_dist("DOCS",  "Docs", "Docs", df, df.predicted, df.vote)
accuracy_dist("TEST", "Tests", "Tests",  df, df.predicted, df.vote)
print("AGAINST SECOND MODEL")
accuracy_dist("CORE",  "Core", "Core", df, df.predicted2, df.vote)
accuracy_dist("BUILD", "Build", "Build", df, df.predicted2, df.vote)
accuracy_dist("DOCS",  "Docs", "Docs", df, df.predicted2, df.vote)
accuracy_dist("TEST", "Tests", "Tests",  df, df.predicted2, df.vote)
# Out:
# AGAINST FIRST MODEL
# ----
# CORE
# 0.40217391304347827
# Same
# 37
# Different
# 55
# ----
# ----
# BUILD
# 0.0
# Same
# 0
# Different
# 24
# ----
# ----
# DOCS
# 0.05405405405405406
# Same
# 2
# Different
# 35
# ----
# ----
# TEST
# 0.16666666666666666
# Same
# 1
# Different
# 5
# ----
# AGAINST SECOND MODEL
# ----
# CORE
# 0.42857142857142855
# Same
# 39
# Different
# 52
# ----
# ----
# BUILD
# 0.0
# Same
# 0
# Different
# 25
# ----
# ----
# DOCS
# 0.05405405405405406
# Same
# 2
# Different
# 35
# ----
# ----
# TEST
# 0.5
# Same
# 2
# Different
# 2
# ----
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
df = pd.read_csv('Voted/codemirror100.csv', index_col=0, encoding="utf-8", delimiter=",")
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('test', 'Tests')
df[['EREN']] = df[['EREN']].replace('Test', 'Tests')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('doc', 'Docs')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('docs', 'Docs')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('documentation', 'Docs')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('src', 'Core')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('core', 'Core')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('development', 'Core')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('develop', 'Core')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('build', 'Build')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('build ', 'Build')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('compile', 'Build')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('tools', 'Build')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('merge', 'Build')
df.head()
# Out:
#                                                                                    activity  \
# d3e8160274f1b4662ce9f7052651d8e4af836372                               Amend previous patch
# 78aba6492cb31e1b3ab680af47896e1a0b8a2156  [javascript mode] Allow expressions after fat ...
# de575f2609be31897f3ff560c3e83162f3c23137  [sql mode] Add comments with links to supporte...
# 4cedb7e56ad865ac5825a18de2ddae65def32cce                Add lib/codemirror.js to .gitignore
# 5f738c32163e3eddd36bd7b3877f905618c3530b                      less consing in the JS parser
#
#                                          predicted predicted2  EREN MIRELLA  \
# d3e8160274f1b4662ce9f7052651d8e4af836372      Core       Core  Core    Core
# 78aba6492cb31e1b3ab680af47896e1a0b8a2156      Core       Core  Core    Core
# de575f2609be31897f3ff560c3e83162f3c23137      Docs       Docs  Docs    Docs
# 4cedb7e56ad865ac5825a18de2ddae65def32cce      Core       Core  Core    Core
# 5f738c32163e3eddd36bd7b3877f905618c3530b      Core       Core  Core    Core
#
#                                          SANJA
# d3e8160274f1b4662ce9f7052651d8e4af836372  Core
# 78aba6492cb31e1b3ab680af47896e1a0b8a2156  Core
# de575f2609be31897f3ff560c3e83162f3c23137  Docs
# 4cedb7e56ad865ac5825a18de2ddae65def32cce  Core
# 5f738c32163e3eddd36bd7b3877f905618c3530b  Core

# %%
for i in range(1,10):
    classCount = df.EREN.value_counts()
print(classCount)
for i in range(1,10):
    classCount = df.MIRELLA.value_counts()
print(classCount)
for i in range(1,10):
    classCount = df.SANJA.value_counts()
print(classCount)
# Out:
# Core     82
# Docs     10
# Tests     5
# Build     3
# Name: EREN, dtype: int64
# Core     83
# Docs      9
# Tests     8
# Name: MIRELLA, dtype: int64
# Core     85
# Docs     10
# Tests     5
# Name: SANJA, dtype: int64

# %%
df['vote'] = "false"
df['vote'] = np.where((df.EREN == df.MIRELLA) & (df.EREN != df.SANJA), df.EREN, df.vote)
df['vote'] = np.where((df.SANJA == df.MIRELLA) & (df.EREN != df.SANJA), df.SANJA, df.vote)
df['vote'] = np.where((df.SANJA == df.EREN) & (df.EREN != df.MIRELLA), df.SANJA, df.vote)
df['vote'] = np.where((df.EREN == df.MIRELLA) & (df.EREN == df.SANJA), df.EREN, df.vote)
df['check'] = np.where((df.EREN != df.MIRELLA) & (df.EREN != df.SANJA) & (df.MIRELLA != df.SANJA),"true","false" )
for i in range(1,10):
    classCount = df.check.value_counts()
print(classCount)
# Out:
# false    100
# Name: check, dtype: int64

# %%
def accuracy_dist(name, x, y, df, dfX, dfY):
    print("----")
    print(name)
    correct = len(df[dfX.isin([x])][dfY.isin([y])])
    wrong = len(df[dfX.isin([x])][~dfY.isin([y])]) + len(df[~dfX.isin([x])][dfY.isin([y])])
    print(correct/(correct + wrong))
    print("Same")
    print(correct)
    print("Different")
    print(wrong)
    print("----")
print("AGAINST FIRST MODEL")
accuracy_dist("CORE",  "Core", "Core", df, df.predicted, df.vote)
accuracy_dist("BUILD", "Build", "Build", df, df.predicted, df.vote)
accuracy_dist("DOCS",  "Docs", "Docs", df, df.predicted, df.vote)
accuracy_dist("TEST", "Tests", "Tests",  df, df.predicted, df.vote)
print("AGAINST SECOND MODEL")
accuracy_dist("CORE",  "Core", "Core", df, df.predicted2, df.vote)
accuracy_dist("BUILD", "Build", "Build", df, df.predicted2, df.vote)
accuracy_dist("DOCS",  "Docs", "Docs", df, df.predicted2, df.vote)
accuracy_dist("TEST", "Tests", "Tests",  df, df.predicted2, df.vote)
# Out:
# AGAINST FIRST MODEL
# ----
# CORE
# 0.8709677419354839
# Same
# 81
# Different
# 12
# ----
# ----
# BUILD
# 0.0
# Same
# 0
# Different
# 1
# ----
# ----
# DOCS
# 0.25
# Same
# 3
# Different
# 9
# ----
# ----
# TEST
# 0.42857142857142855
# Same
# 3
# Different
# 4
# ----
# AGAINST SECOND MODEL
# ----
# CORE
# 0.8279569892473119
# Same
# 77
# Different
# 16
# ----
# ----
# BUILD
# 0.0
# Same
# 0
# Different
# 3
# ----
# ----
# DOCS
# 0.25
# Same
# 3
# Different
# 9
# ----
# ----
# TEST
# 0.42857142857142855
# Same
# 3
# Different
# 4
# ----
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
df = pd.read_csv('Voted/less100.csv', index_col=0, encoding="utf-8", delimiter=",")
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('test', 'Tests')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('Test', 'Tests')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('Test ', 'Tests')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('doc', 'Docs')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('docs', 'Docs')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('documentation', 'Docs')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('src', 'Core')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('core', 'Core')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('development', 'Core')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('develop', 'Core')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('build', 'Build')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('build ', 'Build')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('compile', 'Build')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('tools', 'Build')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('merge', 'Build')
for i in range(1,10):
    classCount = df.EREN.value_counts()
print(classCount)
for i in range(1,10):
    classCount = df.MIRELLA.value_counts()
print(classCount)
for i in range(1,10):
    classCount = df.SANJA.value_counts()
print(classCount)
# Out:
# Core     70
# Build    16
# Tests    10
# Docs      4
# Name: EREN, dtype: int64
# Core     68
# Build    17
# Tests    11
# Docs      4
# Name: MIRELLA, dtype: int64
# Core     70
# Build    16
# Tests     9
# Docs      5
# Name: SANJA, dtype: int64

# %%
df['vote'] = "false"
df['vote'] = np.where((df.EREN == df.MIRELLA) & (df.EREN != df.SANJA), df.EREN, df.vote)
df['vote'] = np.where((df.SANJA == df.MIRELLA) & (df.EREN != df.SANJA), df.SANJA, df.vote)
df['vote'] = np.where((df.SANJA == df.EREN) & (df.EREN != df.MIRELLA), df.SANJA, df.vote)
df['vote'] = np.where((df.EREN == df.MIRELLA) & (df.EREN == df.SANJA), df.EREN, df.vote)
df['check'] = np.where((df.EREN != df.MIRELLA) & (df.EREN != df.SANJA) & (df.MIRELLA != df.SANJA),"true","false" )
for i in range(1,10):
    classCount = df.check.value_counts()
print(classCount)
# Out:
# false    100
# Name: check, dtype: int64

# %%
def accuracy_dist(name, x, y, df, dfX, dfY):
    print("----")
    print(name)
    correct = len(df[dfX.isin([x])][dfY.isin([y])])
    wrong = len(df[dfX.isin([x])][~dfY.isin([y])]) + len(df[~dfX.isin([x])][dfY.isin([y])])
    print(correct/(correct + wrong))
    print("Same")
    print(correct)
    print("Different")
    print(wrong)
    print("----")
print("AGAINST FIRST MODEL")
accuracy_dist("CORE",  "Core", "Core", df, df.predicted, df.vote)
accuracy_dist("BUILD", "Build", "Build", df, df.predicted, df.vote)
accuracy_dist("DOCS",  "Docs", "Docs", df, df.predicted, df.vote)
accuracy_dist("TEST", "Tests", "Tests",  df, df.predicted, df.vote)
print("AGAINST SECOND MODEL")
accuracy_dist("CORE",  "Core", "Core", df, df.predicted2, df.vote)
accuracy_dist("BUILD", "Build", "Build", df, df.predicted2, df.vote)
accuracy_dist("DOCS",  "Docs", "Docs", df, df.predicted2, df.vote)
accuracy_dist("TEST", "Tests", "Tests",  df, df.predicted2, df.vote)
# Out:
# AGAINST FIRST MODEL
# ----
# CORE
# 0.7241379310344828
# Same
# 63
# Different
# 24
# ----
# ----
# BUILD
# 0.11764705882352941
# Same
# 2
# Different
# 15
# ----
# ----
# DOCS
# 0.5
# Same
# 2
# Different
# 2
# ----
# ----
# TEST
# 0.3888888888888889
# Same
# 7
# Different
# 11
# ----
# AGAINST SECOND MODEL
# ----
# CORE
# 0.7241379310344828
# Same
# 63
# Different
# 24
# ----
# ----
# BUILD
# 0.10526315789473684
# Same
# 2
# Different
# 17
# ----
# ----
# DOCS
# 0.5
# Same
# 2
# Different
# 2
# ----
# ----
# TEST
# 0.4375
# Same
# 7
# Different
# 9
# ----
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
df = pd.read_csv('Voted/reveal100.csv', index_col=0, encoding="utf-8", delimiter=",")
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('test', 'Tests')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('Test', 'Tests')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('Test ', 'Tests')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('doc', 'Docs')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('docs', 'Docs')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('documentation', 'Docs')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('src', 'Core')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('core', 'Core')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('development', 'Core')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('develop', 'Core')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('build', 'Build')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('build ', 'Build')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('compile', 'Build')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('tools', 'Build')
df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']] = df[['predicted2', 'EREN', 'MIRELLA', 'SANJA']].replace('merge', 'Build')
for i in range(1,10):
    classCount = df.EREN.value_counts()
print(classCount)
for i in range(1,10):
    classCount = df.MIRELLA.value_counts()
print(classCount)
for i in range(1,10):
    classCount = df.SANJA.value_counts()
print(classCount)
# Out:
# Core     63
# Build    25
# Docs      8
# Tests     4
# Name: EREN, dtype: int64
# Core     63
# Build    24
# Docs      8
# Tests     5
# Name: MIRELLA, dtype: int64
# Core     68
# Build    21
# Docs      7
# Tests     4
# Name: SANJA, dtype: int64

# %%
df['vote'] = "false"
df['vote'] = np.where((df.EREN == df.MIRELLA) & (df.EREN != df.SANJA), df.EREN, df.vote)
df['vote'] = np.where((df.SANJA == df.MIRELLA) & (df.EREN != df.SANJA), df.SANJA, df.vote)
df['vote'] = np.where((df.SANJA == df.EREN) & (df.EREN != df.MIRELLA), df.SANJA, df.vote)
df['vote'] = np.where((df.EREN == df.MIRELLA) & (df.EREN == df.SANJA), df.EREN, df.vote)
df['check'] = np.where((df.EREN != df.MIRELLA) & (df.EREN != df.SANJA) & (df.MIRELLA != df.SANJA),"true","false" )
for i in range(1,10):
    classCount = df.check.value_counts()
print(classCount)
# Out:
# false    100
# Name: check, dtype: int64

# %%
def accuracy_dist(name, x, y, df, dfX, dfY):
    print("----")
    print(name)
    correct = len(df[dfX.isin([x])][dfY.isin([y])])
    wrong = len(df[dfX.isin([x])][~dfY.isin([y])]) + len(df[~dfX.isin([x])][dfY.isin([y])])
    print(correct/(correct + wrong))
    print("Same")
    print(correct)
    print("Different")
    print(wrong)
    print("----")
print("AGAINST FIRST MODEL")
accuracy_dist("CORE",  "Core", "Core", df, df.predicted, df.vote)
accuracy_dist("BUILD", "Build", "Build", df, df.predicted, df.vote)
accuracy_dist("DOCS",  "Docs", "Docs", df, df.predicted, df.vote)
accuracy_dist("TEST", "Tests", "Tests",  df, df.predicted, df.vote)
print("AGAINST SECOND MODEL")
accuracy_dist("CORE",  "Core", "Core", df, df.predicted2, df.vote)
accuracy_dist("BUILD", "Build", "Build", df, df.predicted2, df.vote)
accuracy_dist("DOCS",  "Docs", "Docs", df, df.predicted2, df.vote)
accuracy_dist("TEST", "Tests", "Tests",  df, df.predicted2, df.vote)
# Out:
# AGAINST FIRST MODEL
# ----
# CORE
# 0.63
# Same
# 63
# Different
# 37
# ----
# ----
# BUILD
# 0.0
# Same
# 0
# Different
# 24
# ----
# ----
# DOCS
# 0.0
# Same
# 0
# Different
# 8
# ----
# ----
# TEST
# 0.0
# Same
# 0
# Different
# 5
# ----
# AGAINST SECOND MODEL
# ----
# CORE
# 0.5959595959595959
# Same
# 59
# Different
# 40
# ----
# ----
# BUILD
# 0.0
# Same
# 0
# Different
# 28
# ----
# ----
# DOCS
# 0.0
# Same
# 0
# Different
# 8
# ----
# ----
# TEST
# 0.2
# Same
# 1
# Different
# 4
# ----
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
